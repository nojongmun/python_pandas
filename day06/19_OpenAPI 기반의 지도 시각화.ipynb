# %% [markdown]
# # 19_OpenAPI 기반의 지도 시각화

# %%
# %%html
# <h1>
# 위도 : <span id="lat"></span>, 경도 : <span id="lng"></span>
# </h1>
#
# <script>
# navigator.geolocation.getCurrentPosition(function(position){
#     document.getElementById("lat").innerHTML = position.coords.latitude;
#     document.getElementById("lng").innerHTML = position.coords.longitude;
# });
# </script>
# Out:
# <h1>
# 위도 : <span id="lat"></span>, 경도 : <span id="lng"></span>
# </h1>
#
# <script>
# navigator.geolocation.getCurrentPosition(function(position){
#     document.getElementById("lat").innerHTML = position.coords.latitude;
#     document.getElementById("lng").innerHTML = position.coords.longitude;
# });
# </script>

# %% [markdown]
# ## #01. 기본 준비 단계
#
# ### 1) 필요한 패키지 가져오기

# %%
import folium
import requests
import json
import pandas as pd
from pandas import DataFrame
import numpy

# %% [markdown]
# ### 2) 위도, 경도 변수 준비하기

# %%
lat = 37.4923615
lng = 127.02928809999999
m = 5000    #반경 5km

# %% [markdown]
# ### 3) 세션 생성

# %%
user_agent = "Mozilla/5.0 (Linux; Android 5.0; SM-G900P Build/LRX21T) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Mobile Safari/537.36"
session = requests.Session()
session.headers.update({'User-agent':user_agent, 'referer':None})

# %% [markdown]
# ## #02. 특정 위치 부근의 공정 마스크 판매 정보
#
# 공공 데이터 포털에서 공적 마스크 판매 정보와 관련된 OpenAPI를 제공한다.
#
# > https://www.data.go.kr/dataset/15043025/openapi.do <br>
# > https://app.swaggerhub.com/apis-docs/Promptech/public-mask-info/20200307-oas3#/

# %% [markdown]
# ### 1) 접속 주소 준비하기
#
# #### 변수가 치환될 주소 템플릿

# %%
url_tpl = "https://8oi9s0nnth.apigw.ntruss.com/corona19-masks/v1/storesByGeo/json?lat={lat}&lng={lng}&m={m}"

# %% [markdown]
# #### 최종 주소 확인하기

# %%
url = url_tpl.format(lat=lat, lng=lng, m=m)
url
# Out:
# 'https://8oi9s0nnth.apigw.ntruss.com/corona19-masks/v1/storesByGeo/json?lat=37.4923615&lng=127.02928809999999&m=5000'

# %% [markdown]
# ### 2) API를 통한 JSON 테이터 가져오기
#
# #### OpenAPI를 통한 JSON 가져오기

# %%
r = session.get(url)
r.text
# Out:
# '{\n  "count": 723,\n  "stores": [{\n    "addr": "서울특별시 관악구 남부순환로 2054 1층 (남현동)",\n    "code": "12868957",\n    "created_at": "2020/03/28 09:40:00",\n    "lat": 37.476344,\n    "lng": 126.9769436,\n    "name": "워너비사랑약국",\n    "remain_stat": "few",\n    "stock_at": "2020/03/27 12:18:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 관악구 남부순환로 2056 태림빌딩 지하1층 (남현동)",\n    "code": "12869538",\n    "created_at": "2020/03/28 09:40:00",\n    "lat": 37.4763242,\n    "lng": 126.9772094,\n    "name": "아이봄약국",\n    "remain_stat": "break",\n    "stock_at": "2020/03/27 09:56:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 동작구 남부순환로 2055 (사당동)",\n    "code": "12830925",\n    "created_at": "2020/03/28 09:40:00",\n    "lat": 37.4768791,\n    "lng": 126.9771081,\n    "name": "팜프라자약국",\n    "remain_stat": "few",\n    "stock_at": "2020/03/27 13:02:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 관악구 남현길 7 한일프라자 1층 (남현동)",\n    "code": "12869228",\n    "created_at": "2020/03/28 09:45:00",\n    "lat": 37.4760703,\n    "lng": 126.9776837,\n    "name": "마음약국",\n    "remain_stat": "empty",\n    "stock_at": "2020/03/27 10:03:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 관악구 남부순환로 2062 (남현동)",\n    "code": "11810629",\n    "created_at": "2020/03/28 09:40:00",\n    "lat": 37.4763977,\n    "lng": 126.9777939,\n    "name": "신한성약국",\n    "remain_stat": "empty",\n    "stock_at": "2020/03/27 11:54:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 동작구 남부순환로 2057 3층 (사당동)",\n    "code": "12805386",\n    "created_at": "2020/03/28 09:40:00",\n    "lat": 37.4769407,\n    "lng": 126.9773807,\n    "name": "파란약국",\n    "remain_stat": "plenty",\n    "stock_at": "2020/03/28 09:11:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 동작구 남부순환로 2059 1층 (사당동)",\n    "code": "11824824",\n    "created_at": "2020/03/28 09:45:00",\n    "lat": 37.4769192,\n    "lng": 126.9775136,\n    "name": "평화약국",\n    "remain_stat": "empty",\n    "stock_at": "2020/03/27 13:00:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 동작구 동작대로7길 84 (사당동)",\n    "code": "11824883",\n    "created_at": "2020/03/28 09:40:00",\n    "lat": 37.4777602,\n    "lng": 126.9781039,\n    "name": "온누리세종약국",\n    "remain_stat": "empty",\n    "stock_at": "2020/03/27 12:28:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 관악구 과천대로 909 남현프라자 지하2층 (남현동)",\n    "code": "12867764",\n    "created_at": "2020/03/28 09:45:00",\n    "lat": 37.4715201,\n    "lng": 126.9824756,\n    "name": "사랑찬약국",\n    "remain_stat": "empty",\n    "stock_at": "2020/03/27 10:16:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 관악구 과천대로 939 르메이에르강남타운2 3층 (남현동)",\n    "code": "12865753",\n    "created_at": "2020/03/28 09:40:00",\n    "lat": 37.4743938,\n    "lng": 126.9814601,\n    "name": "사당미소약국",\n    "remain_stat": "some",\n    "stock_at": "2020/03/27 14:47:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 관악구 남부순환로 2082-33 (남현동)",\n    "code": "12863777",\n    "created_at": "2020/03/28 09:40:00",\n    "lat": 37.476161,\n    "lng": 126.9803937,\n    "name": "사랑약국",\n    "remain_stat": "few",\n    "stock_at": "2020/03/27 10:26:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 관악구 과천대로 955 1층 (남현동)",\n    "code": "12841790",\n    "created_at": "2020/03/28 09:40:00",\n    "lat": 37.4759484,\n    "lng": 126.9811803,\n    "name": "사당365약국",\n    "remain_stat": "empty",\n    "stock_at": "2020/03/27 10:54:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 동작구 동작대로 7 1층 (사당동)",\n    "code": "12809721",\n    "created_at": "2020/03/28 09:40:00",\n    "lat": 37.4771747,\n    "lng": 126.9811278,\n    "name": "사당소화약국",\n    "remain_stat": "break",\n    "stock_at": "2020/03/27 13:11:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 서초구 방배천로 5-3 1층 (방배동, 도양빌딩)",\n    "code": "12838101",\n    "created_at": "2020/03/28 09:45:00",\n    "lat": 37.4770623,\n    "lng": 126.9822612,\n    "name": "사당13번약국",\n    "remain_stat": "empty",\n    "stock_at": "2020/03/27 08:58:00",\n    "type": "01"\n  }, {\n    "addr": "서울특별시 동작구 동작대로 25 4층 (사당동)",\n     ...

# %% [markdown]
# #### JSON을 딕셔너리로 변환

# %%
mask_dict = json.loads(r.text)
mask_dict
# Out:
# {'count': 723,
#  'stores': [{'addr': '서울특별시 관악구 남부순환로 2054 1층 (남현동)',
#    'code': '12868957',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.476344,
#    'lng': 126.9769436,
#    'name': '워너비사랑약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/27 12:18:00',
#    'type': '01'},
#   {'addr': '서울특별시 관악구 남부순환로 2056 태림빌딩 지하1층 (남현동)',
#    'code': '12869538',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4763242,
#    'lng': 126.9772094,
#    'name': '아이봄약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 09:56:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 남부순환로 2055 (사당동)',
#    'code': '12830925',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4768791,
#    'lng': 126.9771081,
#    'name': '팜프라자약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/27 13:02:00',
#    'type': '01'},
#   {'addr': '서울특별시 관악구 남현길 7 한일프라자 1층 (남현동)',
#    'code': '12869228',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4760703,
#    'lng': 126.9776837,
#    'name': '마음약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:03:00',
#    'type': '01'},
#   {'addr': '서울특별시 관악구 남부순환로 2062 (남현동)',
#    'code': '11810629',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4763977,
#    'lng': 126.9777939,
#    'name': '신한성약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 11:54:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 남부순환로 2057 3층 (사당동)',
#    'code': '12805386',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4769407,
#    'lng': 126.9773807,
#    'name': '파란약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:11:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 남부순환로 2059 1층 (사당동)',
#    'code': '11824824',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4769192,
#    'lng': 126.9775136,
#    'name': '평화약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 13:00:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로7길 84 (사당동)',
#    'code': '11824883',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4777602,
#    'lng': 126.9781039,
#    'name': '온누리세종약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 12:28:00',
#    'type': '01'},
#   {'addr': '서울특별시 관악구 과천대로 909 남현프라자 지하2층 (남현동)',
#    'code': '12867764',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4715201,
#    'lng': 126.9824756,
#    'name': '사랑찬약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:16:00',
#    'type': '01'},
#   {'addr': '서울특별시 관악구 과천대로 939 르메이에르강남타운2 3층 (남현동)',
#    'code': '12865753',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4743938,
#    'lng': 126.9814601,
#    'name': '사당미소약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/27 14:47:00',
#    'type': '01'},
#   {'addr': '서울특별시 관악구 남부순환로 2082-33 (남현동)',
#    'code': '12863777',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.476161,
#    'lng': 126.9803937,
#    'name': '사랑약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/27 10:26:00',
#    'type': '01'},
#   {'addr': '서울특별시 관악구 과천대로 955 1층 (남현동)',
#    'code': '12841790',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4759484,
#    'lng': 126.9811803,
#    'name': '사당365약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:54:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로 7 1층 (사당동)',
#    'code': '12809721',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4771747,
#    'lng': 126.9811278,
#    'name': '사당소화약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 13:11:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배천로 5-3 1층 (방배동, 도양빌딩)',
#    'code': '12838101',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4770623,
#    'lng': 126.9822612,
#    'name': '사당13번약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 08:58:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로 25 4층 (사당동)',
#    'code': '11816678',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.47875,
#    'lng': 126.9813575,
#    'name': '새미약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/27 13:24:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 효령로2길 4 (방배동)',
#    'code': '12833771',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4763378,
#    'lng': 126.9865321,
#    'name': '메디팜메트로약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 효령로 12 1층 (방배동)',
#    'code': '12843636',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4768774,
#    'lng': 126.9867478,
#    'name': '강남사랑약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/28 08:30:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 남부순환로287길 9-1 (방배동)',
#    'code': '12843504',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4762829,
#    'lng': 126.9875282,
#    'name': '나은약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:49:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 57 1층 (방배동)',
#    'code': '12855685',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4797056,
#    'lng': 126.9984853,
#    'name': '경희정산한약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 11:09:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 32 2층 2호 (방배동, 방배쇼핑센터)',
#    'code': '12844152',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4778415,
#    'lng': 127.0003899,
#    'name': '비타민약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:51:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 39 1층 (방배동)',
#    'code': '11855207',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4781622,
#    'lng': 126.999425,
#    'name': '주앙약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 09:15:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 36 (방배동)',
#    'code': '11855185',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4781182,
#    'lng': 127.0001766,
#    'name': '한영온누리약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:51:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 사당로 244 1호 (사당동, 사당시장 점포)',
#    'code': '12816566',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4830336,
#    'lng': 126.9748808,
#    'name': '전원약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 07:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 사당로22길 3 602호 (사당동)',
#    'code': '12863181',
#    'created_at': None,
#    'lat': 37.4833374,
#    'lng': 126.9768015,
#    'name': '동의보감 한약국',
#    'remain_stat': None,
#    'stock_at': None,
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로29길 69 201호 (사당동)',
#    'code': '12862568',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4884377,
#    'lng': 126.9781018,
#    'name': '엄마손약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 08:40:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로29길 69 금강산보석불가마사우나 303호 (사당동)',
#    'code': '12833916',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4884496,
#    'lng': 126.978131,
#    'name': '오약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:36:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로29길 69 120,121호 (사당동)',
#    'code': '12814351',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4885263,
#    'lng': 126.9781125,
#    'name': '옵티마다정약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:22:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동작대로 38 (방배동)',
#    'code': '11856220',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.479828,
#    'lng': 126.9822163,
#    'name': '세계로약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 09:09:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로 43 (사당동)',
#    'code': '12827541',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4804853,
#    'lng': 126.9814439,
#    'name': '조은약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 11:28:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로 65 1층 (사당동)',
#    'code': '11870435',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4823778,
#    'lng': 126.9815964,
#    'name': '수온누리약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 13:55:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로17길 3 (사당동)',
#    'code': '12845051',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4826983,
#    'lng': 126.9813406,
#    'name': '솔약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 12:48:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 사당로 300 222호 (사당동, 이수자이)',
#    'code': '12809934',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4843925,
#    'lng': 126.9805813,
#    'name': '이수사랑약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 11:58:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로 89 504호 (사당동, 골든시네마타워)',
#    'code': '12832685',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.484648,
#    'lng': 126.9817,
#    'name': '골드약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:21:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로 89 107,108,S-12,S-13호 (사당동, 골든시네마타워)',
#    'code': '12800821',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4847428,
#    'lng': 126.9814908,
#    'name': '제중당건강약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/27 12:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 사당로 308 (사당동, 화인빌딩)',
#    'code': '12860182',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4849196,
#    'lng': 126.9815815,
#    'name': '행복한오늘이수약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 08:33:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 사당로 297 (사당동)',
#    'code': '12804754',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4851381,
#    'lng': 126.9805261,
#    'name': '신세계약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:23:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로25길 39 (사당동)',
#    'code': '11824468',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4854002,
#    'lng': 126.9804039,
#    'name': '세브란스약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:25:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 사당로 301 사당동빌딩 3층 (사당동)',
#    'code': '12830267',
#    'created_at': '2020/03/08 13:35:00',
#    'lat': 37.4853103,
#    'lng': 126.9808096,
#    'name': '한라약국',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 사당로 303 (사당동)',
#    'code': '12818518',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4854183,
#    'lng': 126.9811511,
#    'name': '사랑약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 08:46:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동작대로 108 304호 (방배동, 디오슈페리움2차)',
#    'code': '12800031',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4861159,
#    'lng': 126.9826348,
#    'name': '이수온누리약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:34:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로25길 6 (사당동)',
#    'code': '11824671',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4865235,
#    'lng': 126.9815937,
#    'name': '화천약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동작대로 114 1층 (방배동, (재)원불교 유문빌딩)',
#    'code': '12858536',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4868002,
#    'lng': 126.9827042,
#    'name': '방배세명약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 13:05:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로 121 지하1층 (사당동, 경원빌딩)',
#    'code': '12813664',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4874684,
#    'lng': 126.9818694,
#    'name': '조이온누리약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 09:08:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동광로12가길 42 1층 (방배동)',
#    'code': '12867063',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4875211,
#    'lng': 126.9826143,
#    'name': '동해물약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:43:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 3-4 1층 101-3호 (방배동, 방배디오슈페리움)',
#    'code': '11868201',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4860933,
#    'lng': 126.9829747,
#    'name': '푸른약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:50:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 24 1층 (방배동)',
#    'code': '11887184',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4854712,
#    'lng': 126.985056,
#    'name': '홈케어방배약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:38:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동작대로 118 107호 (방배동, 방배예다인)',
#    'code': '12818917',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4870229,
#    'lng': 126.9828023,
#    'name': '방배대한약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:50:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로27길 22 (사당동)',
#    'code': '11824654',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4877046,
#    'lng': 126.980672,
#    'name': '대일약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 11:19:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로29길 17 (사당동)',
#    'code': '12818291',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4879691,
#    'lng': 126.9809385,
#    'name': '시장약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 12:34:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로29길 24 101호 (사당동, 정현빌딩)',
#    'code': '12826081',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4882228,
#    'lng': 126.9807015,
#    'name': '이수약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 13:16:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로 127 1층 (사당동)',
#    'code': '12868841',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4879721,
#    'lng': 126.9819529,
#    'name': '광주약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 09:10:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동작대로 130 1층 (방배동)',
#    'code': '12801160',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4880188,
#    'lng': 126.9826525,
#    'name': '열린약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:43:00',
#    'type': '01'},
#   {'addr': '서울특별시 동작구 동작대로 129 (사당동)',
#    'code': '11824522',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4882965,
#    'lng': 126.9818938,
#    'name': '동광약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 12:57:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동작대로 132 지하2층 (방배동, 안석빌딩)',
#    'code': '12805327',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4882676,
#    'lng': 126.9827781,
#    'name': '스마일약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 12:37:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동작대로 134 5층 (방배동, 가나안빌딩)',
#    'code': '11872209',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4886136,
#    'lng': 126.9827975,
#    'name': '수약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 12:07:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로13길 31 (방배동)',
#    'code': '11855053',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4825235,
#    'lng': 126.9948552,
#    'name': '방일약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:56:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 95 2층 (방배동)',
#    'code': '12865516',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4826852,
#    'lng': 126.9964077,
#    'name': '서경약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:26:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로13길 7 (방배동)',
#    'code': '11855045',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.48297,
#    'lng': 126.9959656,
#    'name': '보현약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 09:11:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 111 1층 (방배동, 근복빌딩)',
#    'code': '12820431',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4839058,
#    'lng': 126.9956497,
#    'name': '서초제일약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:01:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 108 1층 (방배동)',
#    'code': '12843181',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4838342,
#    'lng': 126.9964441,
#    'name': '바른온누리약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:00:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 115 1층 (방배동, 방배메디칼빌딩)',
#    'code': '12851833',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.484401,
#    'lng': 126.9954182,
#    'name': '메디칼약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 09:40:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 87 1층 1호 (방배동)',
#    'code': '11803126',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4821718,
#    'lng': 126.9969232,
#    'name': '소화약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:00:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 88 1층 (방배동)',
#    'code': '11802090',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.482364,
#    'lng': 126.9973977,
#    'name': '영보서초프라자약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 13:05:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 76 1층 (방배동)',
#    'code': '12824780',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4811196,
#    'lng': 126.9983011,
#    'name': '에이스온누리약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:58:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 125 2층 2호 (방배동, 영신빌딩)',
#    'code': '12808733',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4850956,
#    'lng': 126.9949469,
#    'name': '내방약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:44:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로25길 4 1층 (방배동)',
#    'code': '12846538',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4888558,
#    'lng': 126.9925653,
#    'name': '녹십자약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 09:00:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 177 (방배동, 레마빌딩)',
#    'code': '12858838',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4892973,
#    'lng': 126.9922868,
#    'name': '뿌리약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 07:21:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 174 1층 (방배동, 태창빌딩)',
#    'code': '11833190',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4891828,
#    'lng': 126.9930611,
#    'name': '강남메디칼약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:26:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 114 102호 (방배동)',
#    'code': '11874708',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4877484,
#    'lng': 126.9948034,
#    'name': '숨온누리약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:10:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동작대로 194 (방배동)',
#    'code': '11854855',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4938353,
#    'lng': 126.9832127,
#    'name': '온누리동성약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 09:35:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동광로3길 70 (방배동)',
#    'code': '11854766',
#    'created_at': None,
#    'lat': 37.4940739,
#    'lng': 126.9845834,
#    'name': '구심약국',
#    'remain_stat': None,
#    'stock_at': None,
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배중앙로23길 1 (방배동)',
#    'code': '11854731',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.492594,
#    'lng': 126.9857965,
#    'name': '시스템약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:43:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배중앙로 140 1층 (방배동)',
#    'code': '11854928',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4916462,
#    'lng': 126.9870712,
#    'name': '정은약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:42:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 211 2층 (방배동)',
#    'code': '12865745',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4920013,
#    'lng': 126.9906595,
#    'name': '곰돌이스타약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 09:01:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동광로 65 (방배동)',
#    'code': '11854812',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4927391,
#    'lng': 126.9896986,
#    'name': '수도약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:16:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배중앙로 167 (방배동)',
#    'code': '11854723',
#    'created_at': None,
#    'lat': 37.493928,
#    'lng': 126.9860986,
#    'name': '유경약국',
#    'remain_stat': None,
#    'stock_at': None,
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 223 1층 1호 (방배동)',
#    'code': '12866962',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4930421,
#    'lng': 126.9899521,
#    'name': '온새미약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 225 1층 (방배동, 성은빌딩)',
#    'code': '12808881',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4931756,
#    'lng': 126.9897944,
#    'name': '메디컬제일약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:39:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동광로 75 1층 (방배동)',
#    'code': '11809868',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4930534,
#    'lng': 126.9906663,
#    'name': '남영약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/27 13:47:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 232 1층 (방배동)',
#    'code': '12861057',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4939257,
#    'lng': 126.9900089,
#    'name': '서래비비약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:14:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 244 1층 (방배동)',
#    'code': '12817589',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4948851,
#    'lng': 126.9894965,
#    'name': '임마누엘온누리약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 09:19:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배중앙로29길 3 1층 (방배동)',
#    'code': '11855789',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4964722,
#    'lng': 126.9853016,
#    'name': '방배프라자약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:51:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동광로1길 112 206호 (방배동)',
#    'code': '11854740',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4968205,
#    'lng': 126.9845952,
#    'name': '즐거운약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:31:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 268 103호 (방배동, 삼호상가)',
#    'code': '11854791',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4966615,
#    'lng': 126.9883974,
#    'name': '성지약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:34:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 방배로 196 (방배동)',
#    'code': '11854898',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4910419,
#    'lng': 126.9918915,
#    'name': '정신약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:52:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서래로5길 3 (반포동)',
#    'code': '11879751',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4977269,
#    'lng': 126.9981356,
#    'name': '행복을여는서래약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:57:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서래로8길 1 (반포동)',
#    'code': '12833177',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4987479,
#    'lng': 126.9985894,
#    'name': '신명성약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:43:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서래로 46 1층 (반포동)',
#    'code': '12866954',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4991169,
#    'lng': 126.9986055,
#    'name': '오약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 08:25:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 신반포로 22 H-33호 (반포동)',
#    'code': '11855649',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.501096,
#    'lng': 126.987091,
#    'name': '아주약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:55:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 신반포로 38 1층 10호 (반포동)',
#    'code': '12856401',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5015073,
#    'lng': 126.9888151,
#    'name': '약원한약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/27 13:05:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 신반포로 41 1층 (반포동)',
#    'code': '12818259',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.501925,
#    'lng': 126.98885,
#    'name': '은혜약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/28 08:41:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 신반포로 41 K동 12호 (반포동)',
#    'code': '12848395',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.501993,
#    'lng': 126.989231,
#    'name': '다솜약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:28:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 신반포로 100 406호 (반포동, 래미안퍼스티지신반포역상가)',
#    'code': '12849634',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5030323,
#    'lng': 126.9955162,
#    'name': '세화약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:33:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 신반포로 100 래미안 퍼스티지 신반포역상가 2층 210호 (반포동)',
#    'code': '12842800',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.503137,
#    'lng': 126.995885,
#    'name': '사랑약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:59:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 신반포로15길 29 2층 (반포동, 신반포상가)',
#    'code': '11886269',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5054719,
#    'lng': 126.9947131,
#    'name': '버클리약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:48:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 반포대로 287 311호 (반포동, 래미안퍼스티지중심상가)',
#    'code': '11884835',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.50440748,
#    'lng': 127.0010481,
#    'name': '3층한사랑약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:11:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 반포대로 287 125호 (반포동, 래미안퍼스티지중심상가)',
#    'code': '11855762',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.50450395,
#    'lng': 127.0005993,
#    'name': '금화온누리약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:06:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 반포대로 287 138호 (반포동)',
#    'code': '12852481',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5045721,
#    'lng': 127.0006446,
#    'name': '반포다정약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 신반포로 157 405호 (잠원동, 일동빌딩)',
#    'code': '11896043',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5055124,
#    'lng': 127.0014772,
#    'name': '메디케어약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/26 09:05:00',
#    'type': '01'},
#   {'addr': '서울특별시 용산구 이촌로 352 103호 (용산동6가, 신동아쇼핑)',
#    'code': '12857181',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5173888,
#    'lng': 126.9851878,
#    'name': '예사랑약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 17:54:00',
#    'type': '01'},
#   {'addr': '서울특별시 용산구 장문로 66-1 (보광동)',
#    'code': '11837551',
#    'created_at': None,
#    'lat': 37.5260123,
#    'lng': 126.9969499,
#    'name': '동광약국',
#    'remain_stat': None,
#    'stock_at': None,
#    'type': '01'},
#   {'addr': '서울특별시 용산구 장문로 94 (보광동)',
#    'code': '12813681',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5260203,
#    'lng': 126.9999592,
#    'name': '신세계약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:50:00',
#    'type': '01'},
#   {'addr': '서울특별시 용산구 보광로 18 (보광동)',
#    'code': '11888512',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5263754,
#    'lng': 127.0009916,
#    'name': '동오약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:52:00',
#    'type': '01'},
#   {'addr': '서울특별시 용산구 보광로 35 (보광동)',
#    'code': '12813524',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5272717,
#    'lng': 126.9996506,
#    'name': '보광프라자약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/27 10:57:00',
#    'type': '01'},
#   {'addr': '서울특별시 용산구 보광로 30 2층 (보광동)',
#    'code': '12809772',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5271965,
#    'lng': 127.0003047,
#    'name': '코끼리약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/27 10:06:00',
#    'type': '01'},
#   {'addr': '서울특별시 용산구 보광로 46 (보광동)',
#    'code': '11837632',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5282859,
#    'lng': 126.9992101,
#    'name': '알파약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:50:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 태봉로 62 105호 (우면동, 네이처프라자)',
#    'code': '12833924',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4640396,
#    'lng': 127.0250144,
#    'name': '우면메디칼약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:42:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 매헌로 34 한일빌딩 (양재동)',
#    'code': '11854391',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4640419,
#    'lng': 127.0348038,
#    'name': '양재신세계약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:29:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 태봉로 70 우면프라자Ι 110호 (우면동)',
#    'code': '12860417',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4645488,
#    'lng': 127.0255942,
#    'name': '연두약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 12:31:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 성촌길 34 지하1층 (우면동, (주)삼성전자서울R&D캠퍼스)',
#    'code': '12858064',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4661983,
#    'lng': 127.0242881,
#    'name': '모아약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 16:11:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 청계산로 10 1층 (양재동)',
#    'code': '12861171',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4632288,
#    'lng': 127.0435302,
#    'name': '하나로약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:32:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 강남대로 27 지하1층 (양재동, AT센터)',
#    'code': '12848131',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4682596,
#    'lng': 127.0389985,
#    'name': '에이티약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 09:25:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 강남대로 48-6 1층 101호 (양재동)',
#    'code': '12858277',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4691346,
#    'lng': 127.0400425,
#    'name': '양재로하스약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/28 08:25:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 바우뫼로 23 101,102호 (우면동, 선일상가)',
#    'code': '11810459',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4704214,
#    'lng': 127.0252675,
#    'name': '고명약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:17:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 바우뫼로7길 8 501호 (우면동, 세신상가)',
#    'code': '12851434',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4708599,
#    'lng': 127.0253951,
#    'name': '초록약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:52:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 마방로2길 57 101호 (양재동)',
#    'code': '12837962',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4710797,
#    'lng': 127.0394792,
#    'name': '양재시민의숲수약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 07:50:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 강남대로10길 60-1 101호 (양재동)',
#    'code': '12851949',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4697225,
#    'lng': 127.0425255,
#    'name': '신원약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:48:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동산로6길 38 (양재동)',
#    'code': '11866977',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4694722,
#    'lng': 127.0445049,
#    'name': '이오당약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:27:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동산로 60 1층 (양재동)',
#    'code': '12868639',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.471705,
#    'lng': 127.045438,
#    'name': '남부장수약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 08:38:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 동산로 64 (양재동)',
#    'code': '12839728',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4718182,
#    'lng': 127.0457816,
#    'name': '양재메디칼약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/28 08:46:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 언남1길 3 1층 102호 (양재동)',
#    'code': '12866253',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4722051,
#    'lng': 127.0407553,
#    'name': '양재소망약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:59:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 바우뫼로35길 28 1층 (양재동, 고원빌딩)',
#    'code': '12814695',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4797458,
#    'lng': 127.0388381,
#    'name': '푸른온누리약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 17:55:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 논현로 67 1층 (양재동)',
#    'code': '12832936',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4760709,
#    'lng': 127.04586,
#    'name': '수정약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 08:54:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 논현로 88 3층 (개포동, 노엘빌딩)',
#    'code': '11800283',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4778221,
#    'lng': 127.0451614,
#    'name': '다나약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 14:38:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 개포로 207 (개포동)',
#    'code': '12804835',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4785782,
#    'lng': 127.0453158,
#    'name': '명심약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 13:42:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 효령로 177 1층 (서초동)',
#    'code': '12865001',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4827963,
#    'lng': 127.0033891,
#    'name': '유킹스파머시메디바움약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 07:57:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 효령로 200 1층 (서초동)',
#    'code': '12839507',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4828508,
#    'lng': 127.0061556,
#    'name': '늘기쁜약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/28 09:02:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 효령로46길 14 (서초동)',
#    'code': '11822821',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4828549,
#    'lng': 127.008763,
#    'name': '메디팜유일약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:49:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 남부순환로315길 104 (서초동)',
#    'code': '11823283',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4831118,
#    'lng': 127.0075409,
#    'name': '서광약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:54:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 효령로 229 서울빌딩 1층 (서초동)',
#    'code': '11870907',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4838807,
#    'lng': 127.0091164,
#    'name': '다나약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:44:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 명달로 106 원영빌딩 1층 (서초동)',
#    'code': '12861405',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4866165,
#    'lng': 127.0044612,
#    'name': '나무약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:52:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로38길 12 지하2층 (서초동, 마제스타시티,힐스테이트서리풀)',
#    'code': '12861201',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4901238,
#    'lng': 127.0059896,
#    'name': '서초늘봄약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 12:50:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 반포대로 58 201동 12호 (서초동, 서초아트자이상가)',
#    'code': '12842290',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4856543,
#    'lng': 127.0113905,
#    'name': '서초아트약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:02:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로40길 77 101호 (서초동)',
#    'code': '11854201',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4882498,
#    'lng': 127.00875,
#    'name': '다보약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 12:46:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로40길 77 102호 (서초동)',
#    'code': '12841170',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4884085,
#    'lng': 127.0088282,
#    'name': '에스약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/28 08:05:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 효령로 292 서울남부터미널 117호 (서초동)',
#    'code': '12864242',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4835466,
#    'lng': 127.0151108,
#    'name': '엔티약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 13:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 효령로 279 1층 (서초동, 상경빌딩)',
#    'code': '11808390',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4849497,
#    'lng': 127.0147775,
#    'name': '서초백화점약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:52:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 15 106호 (서초동, 현대슈퍼빌상가동)',
#    'code': '11835851',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4828044,
#    'lng': 127.0160719,
#    'name': '슈퍼빌온누리약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:36:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 45 1층 102호 (서초동, 서초레몬)',
#    'code': '12809012',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4857896,
#    'lng': 127.0154596,
#    'name': '바른약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:04:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 39 21세기 병원 1층 (서초동)',
#    'code': '11852810',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4852908,
#    'lng': 127.0157273,
#    'name': '서초로하스약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 07:48:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 38 정원빌딩 1층 (서초동)',
#    'code': '12804916',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.485459,
#    'lng': 127.0163019,
#    'name': '장수알파약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 07:15:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 36 1층 (서초동, 준영빌딩)',
#    'code': '12854450',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4855763,
#    'lng': 127.0162228,
#    'name': '원약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 09:27:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 42 블루핀타워 B110호 (서초동)',
#    'code': '12869660',
#    'created_at': None,
#    'lat': 37.4858725,
#    'lng': 127.0162758,
#    'name': '소망약국',
#    'remain_stat': None,
#    'stock_at': None,
#    'type': '01'},
#   {'addr': '서울특별시 서초구 사임당로 38 큐브플러스 2층 202-2호 (서초동)',
#    'code': '12864749',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4880847,
#    'lng': 127.0142926,
#    'name': '샘약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:52:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 사임당로 39 한성빌딩 (서초동)',
#    'code': '12812170',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4884264,
#    'lng': 127.0141123,
#    'name': '더블유스토어하이약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:36:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 효령로68길 114 (서초동)',
#    'code': '11853964',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4852246,
#    'lng': 127.0186682,
#    'name': '자연약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 08:36:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서리풀길 1 102호 (서초동, 자연빌딩)',
#    'code': '11848391',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4865092,
#    'lng': 127.0209709,
#    'name': '서리풀약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:38:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 남부순환로339길 53 1층 (서초동)',
#    'code': '11854022',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4853822,
#    'lng': 127.0215079,
#    'name': '십자당약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 08:36:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로38길 12 103호 (서초동, 마제스타시티타워원)',
#    'code': '12861901',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.490495,
#    'lng': 127.0053816,
#    'name': '사랑손약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:03:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 반포대로 114 지하1층 102호 (서초동)',
#    'code': '12822922',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4904873,
#    'lng': 127.0087491,
#    'name': '늘푸른약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 10:19:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 240 지하1층 B02호 (서초동, 서초동 동일하이빌)',
#    'code': '12851884',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4914975,
#    'lng': 127.0082712,
#    'name': '세븐약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 13:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 반포대로 138 양진빌딩 (서초동)',
#    'code': '12857947',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4924204,
#    'lng': 127.0079825,
#    'name': '위드팜서초역약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 09:13:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 법원로 15 지하1층 (서초동, 정곡빌딩 서관)',
#    'code': '11870966',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4941711,
#    'lng': 127.0100149,
#    'name': '한일약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/27 08:56:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 반포대로 217 지하1층 (반포동, 조달청사별관동)',
#    'code': '12853372',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4994114,
#    'lng': 127.0033334,
#    'name': '신청사구내약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:27:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 107 (서초동, 삼화빌딩)',
#    'code': '11873426',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4914591,
#    'lng': 127.0137966,
#    'name': '서초당약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/28 09:13:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 113 영한빌딩 1층 (서초동)',
#    'code': '12868787',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4918747,
#    'lng': 127.0137428,
#    'name': '구슬약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:49:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 반포대로30길 82 우서빌딩 1층 102호 (서초동)',
#    'code': '12868108',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4925781,
#    'lng': 127.0129955,
#    'name': '새봄약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:40:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 125 로이어즈타워 8층 803호 (서초동)',
#    'code': '12869414',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4929935,
#    'lng': 127.0134514,
#    'name': '8층약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:16:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 125 1층 105호 (서초동, 로이어즈타워)',
#    'code': '12838322',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.493098,
#    'lng': 127.013494,
#    'name': '세진약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 124 1층 (서초동, 한림빌딩)',
#    'code': '12811068',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4928604,
#    'lng': 127.0141471,
#    'name': '드림약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:17:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 302 102호 (서초동, 인앤인빌딩 )',
#    'code': '12841528',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4937277,
#    'lng': 127.0147172,
#    'name': '진약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:33:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 304 6층 (서초동)',
#    'code': '11867558',
#    'created_at': '2020/03/15 23:55:00',
#    'lat': 37.4938049,
#    'lng': 127.0149613,
#    'name': '현약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/14 09:59:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 306 1층 (서초동, 진영빌딩)',
#    'code': '11853948',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4938614,
#    'lng': 127.0151597,
#    'name': '일이약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 10:34:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 310 지하1층 (서초동, 소망빌딩)',
#    'code': '12839167',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4939941,
#    'lng': 127.0155606,
#    'name': '서초온누리약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:44:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 법원로2길 23 101호 (서초동, 한성빌딩)',
#    'code': '11854359',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4944451,
#    'lng': 127.0132771,
#    'name': '하나약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:42:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 138 3층 (서초동, 우림빌딩)',
#    'code': '12860026',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4942515,
#    'lng': 127.0139865,
#    'name': '나을약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:19:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 307 (서초동)',
#    'code': '11883847',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4944061,
#    'lng': 127.0151321,
#    'name': '건강과행복이열리는약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:19:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로22길 40 (서초동)',
#    'code': '11854014',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4932316,
#    'lng': 127.016205,
#    'name': '팜메이트대학당약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:52:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 317 1층 (서초동, 건원빌딩)',
#    'code': '12816388',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.49476,
#    'lng': 127.016321,
#    'name': '푸른솔약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 08:56:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 323 삼풍프라자 1층 6호 (서초동)',
#    'code': '12824950',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4948927,
#    'lng': 127.0168286,
#    'name': '제이약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/27 10:44:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 334 1층 105호 (서초동, 브라운스톤)',
#    'code': '12850110',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4947301,
#    'lng': 127.0183064,
#    'name': '브라운스톤약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:28:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 331 1층 (서초동)',
#    'code': '11882492',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4951577,
#    'lng': 127.0176552,
#    'name': '빛샘온누리약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/28 08:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 335 (서초동, 서흥빌딩)',
#    'code': '12846627',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4952553,
#    'lng': 127.0180081,
#    'name': '교대사랑약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/28 08:07:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 사임당로 105 (서초동)',
#    'code': '11854031',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4905531,
#    'lng': 127.0212546,
#    'name': '대림약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:10:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로24길 27 226호 (서초동, G5센트럴프라자)',
#    'code': '12825930',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4954178,
#    'lng': 127.0164171,
#    'name': '샛별약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:49:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로 188 지하1층 지하에이-132호 (서초동, 아크로비스타)',
#    'code': '12829544',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.49867,
#    'lng': 127.0130325,
#    'name': '아크로비스타약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:29:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 고무래로 90-7 서초쇼핑 (서초동)',
#    'code': '12858293',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4999342,
#    'lng': 127.0174825,
#    'name': '미래약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:49:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초중앙로24길 55 306호 (서초동, 중앙서초플라자)',
#    'code': '12850713',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4961123,
#    'lng': 127.0194059,
#    'name': '평강약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:37:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서초대로 389 1층 105,106호 (서초동, 진흥상가)',
#    'code': '12861413',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4970821,
#    'lng': 127.0237071,
#    'name': '진흥온누리약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 11:25:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서운로 184 333호 (서초동, 영동프라자)',
#    'code': '11803011',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4997906,
#    'lng': 127.0231824,
#    'name': '아란약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:59:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 강남대로 221 107호 (양재동, 양재역환승주차장)',
#    'code': '12808083',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.483329,
#    'lng': 127.034691,
#    'name': '환승약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:50:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 강남대로 221 양재역환승주차장 3층 303호 (양재동)',
#    'code': '12862908',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4834254,
#    'lng': 127.03433,
#    'name': '약사랑약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 09:58:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 남부순환로 2585 25호 (서초동, 양재역)',
#    'code': '12859591',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4839347,
#    'lng': 127.0345442,
#    'name': '뿌리본약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 11:50:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 강남대로 238 1층 101호 (도곡동)',
#    'code': '12844641',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4849717,
#    'lng': 127.0347727,
#    'name': '양재미소약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:58:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 서운로 39 1층 101호 (서초동, 원진빌딩)',
#    'code': '12857530',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4873985,
#    'lng': 127.0285135,
#    'name': '미소약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 09:04:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 효령로 394 102호 (서초동, 시범빌딩)',
#    'code': '11890576',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.4878655,
#    'lng': 127.0269083,
#    'name': '그린약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:40:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 효령로 396 1층 (서초동)',
#    'code': '12850047',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4879042,
#    'lng': 127.0272409,
#    'name': '기쁨약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:01:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 강남대로 242 1층 (도곡동, 크리스탈빌딩)',
#    'code': '12810380',
#    'created_at': '2020/03/28 09:40:00',
# ...
#   {'addr': '서울특별시 강남구 삼성로96길 11 1층 (삼성동)',
#    'code': '12836486',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5089594,
#    'lng': 127.0568255,
#    'name': '삼성수약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 13:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 삼성로 549 (삼성동, 정화빌딩)',
#    'code': '11800178',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5106027,
#    'lng': 127.0542916,
#    'name': '은약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:39:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 삼성로 352 1층 (대치동, 창진빌딩)',
#    'code': '11883600',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5030095,
#    'lng': 127.0590063,
#    'name': '프라임엠약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 11:16:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 역삼로 536 3층 (대치동, 동성빌딩)',
#    'code': '12842877',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5038257,
#    'lng': 127.0617184,
#    'name': '대치이화약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/27 12:36:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 테헤란로 504 지하층 (대치동, 해성빌딩)',
#    'code': '11848090',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5066302,
#    'lng': 127.0573587,
#    'name': '해성약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 09:02:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 테헤란로84길 17 (대치동)',
#    'code': '11870036',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5060956,
#    'lng': 127.0589612,
#    'name': '장생당약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 12:15:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 테헤란로 509 1층 일부호 (삼성동)',
#    'code': '12844691',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5077819,
#    'lng': 127.0582386,
#    'name': '삼성하나약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 12:03:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 테헤란로 514 5층 (대치동, 삼흥제2빌딩)',
#    'code': '12840378',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5074386,
#    'lng': 127.0597679,
#    'name': '미소약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 12:50:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 테헤란로 532 1층 105호 (대치동)',
#    'code': '12868663',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5082158,
#    'lng': 127.0622887,
#    'name': '허지웅약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 09:22:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 테헤란로87길 29 1층 (삼성동, 엠타워)',
#    'code': '11895152',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5096122,
#    'lng': 127.0580011,
#    'name': '이도건강약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 13:23:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 삼성로92길 27 지하1층 (삼성동)',
#    'code': '12813818',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5083801,
#    'lng': 127.0585572,
#    'name': '사랑온누리약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:24:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 테헤란로87길 13 1층 (삼성동, 서영빌딩)',
#    'code': '12812862',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5086361,
#    'lng': 127.0586131,
#    'name': '소망약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/28 08:31:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 테헤란로87길 17 103호 (삼성동, 마젤란21상가)',
#    'code': '11874783',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5087437,
#    'lng': 127.0583424,
#    'name': '참좋은약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 테헤란로87길 22 2층 D-1호 (삼성동)',
#    'code': '12849855',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5095508,
#    'lng': 127.0594693,
#    'name': '도심공항약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:35:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 테헤란로 534 지하1층 (대치동, 글라스타워빌딩)',
#    'code': '11896655',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5080512,
#    'lng': 127.0628172,
#    'name': '온누리타워약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 10:24:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 영동대로86길 10 1층 (대치동)',
#    'code': '11800461',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5078239,
#    'lng': 127.0649277,
#    'name': '메디칼희민약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 17:55:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 영동대로 416 케이티앤지 타워 지하1층 (대치동)',
#    'code': '12863530',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5065841,
#    'lng': 127.0653267,
#    'name': '연약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:55:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 테헤란로114길 16 1층 1호 (대치동)',
#    'code': '11861258',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5085851,
#    'lng': 127.0665666,
#    'name': '동호약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 11:02:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 봉은사로 465 (삼성동)',
#    'code': '11800038',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5124855,
#    'lng': 127.0504907,
#    'name': '신삼성약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:26:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 봉은사로 469 1층 (삼성동)',
#    'code': '12861294',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5126016,
#    'lng': 127.0508054,
#    'name': '삼성도담약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/27 11:27:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 봉은사로73길 5 1층 (삼성동)',
#    'code': '12835480',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5128053,
#    'lng': 127.0507105,
#    'name': '해오름약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 09:31:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 봉은사로 471 204-1호 (삼성동, 힐스테이트2단지상가동)',
#    'code': '12836605',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5127264,
#    'lng': 127.0512686,
#    'name': '희영온누리약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/28 09:01:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 봉은사로 474 105호 (삼성동)',
#    'code': '11894946',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5123688,
#    'lng': 127.0519533,
#    'name': '자연애약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:35:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 삼성로 620 블래스톤리조트 2층 (삼성동)',
#    'code': '12865796',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5149738,
#    'lng': 127.0526451,
#    'name': '아이조은약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:07:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 학동로 421 1층 일부호 (청담동, 원영빌딩)',
#    'code': '11847298',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5183992,
#    'lng': 127.0462942,
#    'name': '영진약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:55:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 학동로 423 102호 (청담동, 청우빌딩)',
#    'code': '12848816',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5184312,
#    'lng': 127.0466482,
#    'name': '청담수약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 12:45:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 삼성로 642 106호, 107호 (삼성동, 삼성빌딩)',
#    'code': '12824755',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5174072,
#    'lng': 127.0513431,
#    'name': '옵티마대영약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 11:31:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 학동로 433 1층 (청담동)',
#    'code': '11869917',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5187786,
#    'lng': 127.0483242,
#    'name': '생명샘약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:19:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 학동로 443 정한빌딩 1층 103호 (청담동)',
#    'code': '12865982',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5189469,
#    'lng': 127.0493939,
#    'name': '청담별빛약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/27 12:41:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 삼성로 707 1층 (청담동, 청담빌딩)',
#    'code': '12841625',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5192717,
#    'lng': 127.0496171,
#    'name': '타조약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/27 10:33:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 학동로 501 4층 일부호 (청담동)',
#    'code': '12853976',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5191636,
#    'lng': 127.0504815,
#    'name': '청담명약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/26 13:35:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 학동로 503 한성빌딩 1층 106호 (청담동)',
#    'code': '11861479',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.519184,
#    'lng': 127.0508086,
#    'name': '청담약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/28 08:26:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 삼성로 712 지하1층 (청담동)',
#    'code': '12837776',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5197323,
#    'lng': 127.0502063,
#    'name': '아이약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:34:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 학동로87길 9 (청담동, 진흥(아)상가 101호 일부)',
#    'code': '11800801',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5203862,
#    'lng': 127.0516919,
#    'name': '보리수약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/27 09:46:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 학동로 521 1층 (청담동)',
#    'code': '12866113',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5200321,
#    'lng': 127.0558075,
#    'name': '청담온누리약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:25:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 학동로97길 20 1층 일부호 (청담동)',
#    'code': '12815861',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5211496,
#    'lng': 127.0555135,
#    'name': '청담본약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:12:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 봉은사로 524 H112호 (삼성동, 코엑스몰)',
#    'code': '12811548',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5128784,
#    'lng': 127.0572911,
#    'name': '팜엑스약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:36:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 영동대로 602 5층 일부호 (삼성동)',
#    'code': '11838108',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5146257,
#    'lng': 127.0606035,
#    'name': '하늘온누리약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/27 10:15:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 영동대로112길 15 103호 (삼성동, 풍림아파트상가)',
#    'code': '11800011',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5155186,
#    'lng': 127.0615148,
#    'name': '부활약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 12:03:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 봉은사로114길 42 (삼성동)',
#    'code': '11800071',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5121721,
#    'lng': 127.0653425,
#    'name': '강남소화약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 10:14:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 봉은사로114길 12 지하 1층 (삼성동)',
#    'code': '12867616',
#    'created_at': None,
#    'lat': 37.5144324,
#    'lng': 127.0654871,
#    'name': '베어약국',
#    'remain_stat': None,
#    'stock_at': None,
#    'type': '01'},
#   {'addr': '서울특별시 강남구 영동대로114길 56 101-2호 (삼성동, 래미안 삼성1차)',
#    'code': '12842273',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5170204,
#    'lng': 127.0643054,
#    'name': '수라인 한약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 13:42:00',
#    'type': '01'},
#   {'addr': '서울특별시 송파구 올림픽로4길 48 (잠실동)',
#    'code': '12832421',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5064784,
#    'lng': 127.0742513,
#    'name': '쌍용약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/27 15:42:00',
#    'type': '01'},
#   {'addr': '서울특별시 송파구 올림픽로4길 42 109호 (잠실동, 프리마상가 109호)',
#    'code': '11871296',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.506698,
#    'lng': 127.074222,
#    'name': '프리마약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 09:08:00',
#    'type': '01'},
#   {'addr': '서울특별시 송파구 올림픽로4길 42 (잠실동, 우상나상가 3층)',
#    'code': '12833592',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.507218,
#    'lng': 127.074305,
#    'name': '우성약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 09:12:00',
#    'type': '01'},
#   {'addr': '서울특별시 송파구 올림픽로4길 17 (잠실동, 아시아선수촌상가 1-137호)',
#    'code': '11847603',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5086777,
#    'lng': 127.0771146,
#    'name': '선수촌약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 09:04:00',
#    'type': '01'},
#   {'addr': '서울특별시 송파구 백제고분로12길 17 (잠실동)',
#    'code': '11805714',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5046028,
#    'lng': 127.0807043,
#    'name': '온누리건강약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 10:32:00',
#    'type': '01'},
#   {'addr': '서울특별시 송파구 백제고분로 126 오룡빌딩 101호 (잠실동)',
#    'code': '12867004',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5061748,
#    'lng': 127.0807789,
#    'name': '바른삼성약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/27 19:26:00',
#    'type': '01'},
#   {'addr': '서울특별시 송파구 백제고분로 127 (잠실동)',
#    'code': '11847611',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5064655,
#    'lng': 127.0814485,
#    'name': '정선약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/27 10:26:00',
#    'type': '01'},
#   {'addr': '서울특별시 송파구 올림픽로8길 20 잠실아이파크 1층 A115호 (잠실동)',
#    'code': '12867870',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5100727,
#    'lng': 127.0800474,
#    'name': '라미약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:52:00',
#    'type': '01'},
#   {'addr': '서울특별시 송파구 올림픽로 76 1층 104-1호 (잠실동, J타워)',
#    'code': '11827815',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5115631,
#    'lng': 127.0792026,
#    'name': '다인약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:45:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 삼성로 772 105호 (청담동, 로데오프라자)',
#    'code': '12800643',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5236212,
#    'lng': 127.0480449,
#    'name': '청담메디웰약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 13:32:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 도산대로 507 1층 (청담동)',
#    'code': '12848794',
#    'created_at': None,
#    'lat': 37.5247587,
#    'lng': 127.0485533,
#    'name': '스템약국',
#    'remain_stat': None,
#    'stock_at': None,
#    'type': '01'},
#   {'addr': '서울특별시 강남구 압구정로 461 B104호 (청담동)',
#    'code': '12849677',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.525274,
#    'lng': 127.0472279,
#    'name': '청담와이약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/26 16:15:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 도산대로92길 6 1층 (청담동)',
#    'code': '11800909',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5240752,
#    'lng': 127.0503048,
#    'name': '영지약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 14:40:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 도산대로 522 (청담동)',
#    'code': '11801034',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5242895,
#    'lng': 127.0501554,
#    'name': '새생명약국',
#    'remain_stat': 'empty',
#    'stock_at': '2020/03/27 12:02:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 영동대로 722 풍양빌딩 1층 103호 (청담동)',
#    'code': '11822830',
#    'created_at': '2020/03/28 09:45:00',
#    'lat': 37.5223851,
#    'lng': 127.0564116,
#    'name': '정원약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 09:00:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 영동대로 722 (청담동, 풍양빌딩)',
#    'code': '12824691',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5223851,
#    'lng': 127.0564116,
#    'name': '청담제일약국',
#    'remain_stat': 'break',
#    'stock_at': '2020/03/28 09:12:00',
#    'type': '01'},
#   {'addr': '서울특별시 강남구 학동로101길 26 102호 (청담동, 삼익상가)',
#    'code': '11800721',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.5224875,
#    'lng': 127.0577062,
#    'name': '새휘정약국',
#    'remain_stat': 'some',
#    'stock_at': '2020/03/27 18:53:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 중앙로 582 103호 (우면동, 서초타워)',
#    'code': '11887982',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4571487,
#    'lng': 127.015332,
#    'name': '태평양약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/28 08:47:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 헌릉로8길 45 2층 203호 (내곡동, 서초 포레스타 2단지)',
#    'code': '12867110',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4555506,
#    'lng': 127.0609502,
#    'name': '봄약국',
#    'remain_stat': 'few',
#    'stock_at': '2020/03/28 08:42:00',
#    'type': '01'},
#   {'addr': '서울특별시 서초구 헌릉로8길 9-8 1층 108호 (내곡동)',
#    'code': '12860891',
#    'created_at': '2020/03/28 09:40:00',
#    'lat': 37.4566898,
#    'lng': 127.0599758,
#    'name': '늘픔약국',
#    'remain_stat': 'plenty',
#    'stock_at': '2020/03/28 08:59:00',
#    'type': '01'}]}

# %% [markdown]
# #### 딕셔너리를 데이터프레임으로 변환

# %%
mask_df = DataFrame(mask_dict['stores'])
mask_df
# Out:
#                                               addr      code  \
# 0                    서울특별시 관악구 남부순환로 2054 1층 (남현동)  12868957
# 1             서울특별시 관악구 남부순환로 2056 태림빌딩 지하1층 (남현동)  12869538
# 2                       서울특별시 동작구 남부순환로 2055 (사당동)  12830925
# 3                   서울특별시 관악구 남현길 7 한일프라자 1층 (남현동)  12869228
# 4                       서울특별시 관악구 남부순환로 2062 (남현동)  11810629
# ..                                             ...       ...
# 718                 서울특별시 강남구 영동대로 722 (청담동, 풍양빌딩)  12824691
# 719          서울특별시 강남구 학동로101길 26 102호 (청담동, 삼익상가)  11800721
# 720             서울특별시 서초구 중앙로 582 103호 (우면동, 서초타워)  11887982
# 721  서울특별시 서초구 헌릉로8길 45 2층 203호 (내곡동, 서초 포레스타 2단지)  12867110
# 722              서울특별시 서초구 헌릉로8길 9-8 1층 108호 (내곡동)  12860891
#
#               created_at        lat         lng     name remain_stat  \
# 0    2020/03/28 09:40:00  37.476344  126.976944  워너비사랑약국         few
# 1    2020/03/28 09:40:00  37.476324  126.977209    아이봄약국       break
# 2    2020/03/28 09:40:00  37.476879  126.977108   팜프라자약국         few
# 3    2020/03/28 09:45:00  37.476070  126.977684     마음약국       empty
# 4    2020/03/28 09:40:00  37.476398  126.977794    신한성약국       empty
# ..                   ...        ...         ...      ...         ...
# 718  2020/03/28 09:40:00  37.522385  127.056412   청담제일약국       break
# 719  2020/03/28 09:40:00  37.522487  127.057706    새휘정약국        some
# 720  2020/03/28 09:40:00  37.457149  127.015332    태평양약국         few
# 721  2020/03/28 09:40:00  37.455551  127.060950      봄약국         few
# 722  2020/03/28 09:40:00  37.456690  127.059976     늘픔약국      plenty
#
#                 stock_at type
# 0    2020/03/27 12:18:00   01
# 1    2020/03/27 09:56:00   01
# 2    2020/03/27 13:02:00   01
# 3    2020/03/27 10:03:00   01
# 4    2020/03/27 11:54:00   01
# ..                   ...  ...
# 718  2020/03/28 09:12:00   01
# 719  2020/03/27 18:53:00   01
# 720  2020/03/28 08:47:00   01
# 721  2020/03/28 08:42:00   01
# 722  2020/03/28 08:59:00   01
#
# [723 rows x 9 columns]

# %% [markdown]
# ## #03. 지도 시각화
#
# ### 1) 지도 객체 생성
#
# #### 지도의 중심이 되는 위도와 경도를 설정

# %%
# zoom_start : 배열 1-22
map_osm = folium.Map(location=[lat, lng], zoom_start=17)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 마스크 입고 상태 (재고 상태 )
conditions = [  (mask_df['remain_stat'] == 'plenty'), # 100개 이상
                (mask_df['remain_stat'] == 'some'),   # 30개이상 100개 미만
                (mask_df['remain_stat'] == 'few'),    # 2개이상 30개 미만
                (mask_df['remain_stat'] == 'empty'),  # 1개 이하
                (mask_df['remain_stat'] == 'break')]  # 판매중지

# 조건에 따라 부여될 학점
states = [ '100개 이상', '30개 이상 100개미만', '2개이상 30개 미만', '1개 이하', '판매중지']
colors = [ 'green', 'orange', 'red', 'gray', 'black']

# 조건에 따른 학점열 추가하기
mask_df['states'] = numpy.select(conditions, states)
mask_df['colors'] = numpy.select(conditions, colors)

mask_df
# Out:
#                                               addr      code  \
# 0                    서울특별시 관악구 남부순환로 2054 1층 (남현동)  12868957
# 1             서울특별시 관악구 남부순환로 2056 태림빌딩 지하1층 (남현동)  12869538
# 2                       서울특별시 동작구 남부순환로 2055 (사당동)  12830925
# 3                   서울특별시 관악구 남현길 7 한일프라자 1층 (남현동)  12869228
# 4                       서울특별시 관악구 남부순환로 2062 (남현동)  11810629
# ..                                             ...       ...
# 718                 서울특별시 강남구 영동대로 722 (청담동, 풍양빌딩)  12824691
# 719          서울특별시 강남구 학동로101길 26 102호 (청담동, 삼익상가)  11800721
# 720             서울특별시 서초구 중앙로 582 103호 (우면동, 서초타워)  11887982
# 721  서울특별시 서초구 헌릉로8길 45 2층 203호 (내곡동, 서초 포레스타 2단지)  12867110
# 722              서울특별시 서초구 헌릉로8길 9-8 1층 108호 (내곡동)  12860891
#
#               created_at        lat         lng     name remain_stat  \
# 0    2020/03/28 09:40:00  37.476344  126.976944  워너비사랑약국         few
# 1    2020/03/28 09:40:00  37.476324  126.977209    아이봄약국       break
# 2    2020/03/28 09:40:00  37.476879  126.977108   팜프라자약국         few
# 3    2020/03/28 09:45:00  37.476070  126.977684     마음약국       empty
# 4    2020/03/28 09:40:00  37.476398  126.977794    신한성약국       empty
# ..                   ...        ...         ...      ...         ...
# 718  2020/03/28 09:40:00  37.522385  127.056412   청담제일약국       break
# 719  2020/03/28 09:40:00  37.522487  127.057706    새휘정약국        some
# 720  2020/03/28 09:40:00  37.457149  127.015332    태평양약국         few
# 721  2020/03/28 09:40:00  37.455551  127.060950      봄약국         few
# 722  2020/03/28 09:40:00  37.456690  127.059976     늘픔약국      plenty
#
#                 stock_at type         states  colors
# 0    2020/03/27 12:18:00   01    2개이상 30개 미만     red
# 1    2020/03/27 09:56:00   01           판매중지   black
# 2    2020/03/27 13:02:00   01    2개이상 30개 미만     red
# 3    2020/03/27 10:03:00   01          1개 이하    gray
# 4    2020/03/27 11:54:00   01          1개 이하    gray
# ..                   ...  ...            ...     ...
# 718  2020/03/28 09:12:00   01           판매중지   black
# 719  2020/03/27 18:53:00   01  30개 이상 100개미만  orange
# 720  2020/03/28 08:47:00   01    2개이상 30개 미만     red
# 721  2020/03/28 08:42:00   01    2개이상 30개 미만     red
# 722  2020/03/28 08:59:00   01        100개 이상   green
#
# [723 rows x 11 columns]

# %% [markdown]
# ## 03. 지도 시각화

# %%
# zoom_start : 배열 1-22
map_osm = folium.Map(location=[lat, lng], zoom_start=17)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2)지도객체에 마커 추가
#
# 데이터프레임의 행 수 만큼 반복하면서 지정

# %%
for i in mask_df.index:
    x = mask_df.loc[i, 'lat']
    y = mask_df.loc[i, 'lng']
    name = mask_df.loc[i, 'name']
    state = mask_df.loc[i, 'states']
    color = mask_df.loc[i, 'colors']
    print(x, y, name, state, color)
    
    # HTML을 사용한 팝업
    tag_tpl = "<div style='white-space: nowrap'><b>%s</b><br>%s</div>"
    tag = tag_tpl % (name, state)
    popup_html = folium.Popup(tag, parse_html=False)

    # 마커 객체 생성
    mk = folium.Marker([x, y], popup=popup_html, icon=folium.Icon(color=color))

    mk.add_to(map_osm)  # 마커 객체를 지도에 추가함
# Out:
# 37.476344 126.9769436 워너비사랑약국 2개이상 30개 미만 red
# 37.4763242 126.9772094 아이봄약국 판매중지 black
# 37.4768791 126.9771081 팜프라자약국 2개이상 30개 미만 red
# 37.4760703 126.9776837 마음약국 1개 이하 gray
# 37.4763977 126.9777939 신한성약국 1개 이하 gray
# 37.4769407 126.9773807 파란약국 100개 이상 green
# 37.4769192 126.9775136 평화약국 1개 이하 gray
# 37.4777602 126.9781039 온누리세종약국 1개 이하 gray
# 37.4715201 126.9824756 사랑찬약국 1개 이하 gray
# 37.4743938 126.9814601 사당미소약국 30개 이상 100개미만 orange
# 37.476161 126.9803937 사랑약국 2개이상 30개 미만 red
# 37.4759484 126.9811803 사당365약국 1개 이하 gray
# 37.4771747 126.9811278 사당소화약국 판매중지 black
# 37.4770623 126.9822612 사당13번약국 1개 이하 gray
# 37.47875 126.9813575 새미약국 30개 이상 100개미만 orange
# 37.4763378 126.9865321 메디팜메트로약국 30개 이상 100개미만 orange
# 37.4768774 126.9867478 강남사랑약국 2개이상 30개 미만 red
# 37.4762829 126.9875282 나은약국 30개 이상 100개미만 orange
# 37.4797056 126.9984853 경희정산한약국 판매중지 black
# 37.4778415 127.0003899 비타민약국 30개 이상 100개미만 orange
# 37.4781622 126.999425 주앙약국 30개 이상 100개미만 orange
# 37.4781182 127.0001766 한영온누리약국 30개 이상 100개미만 orange
# 37.4830336 126.9748808 전원약국 판매중지 black
# 37.4833374 126.9768015 동의보감 한약국 0 0
# 37.4884377 126.9781018 엄마손약국 판매중지 black
# 37.4884496 126.978131 오약국 1개 이하 gray
# 37.4885263 126.9781125 옵티마다정약국 1개 이하 gray
# 37.479828 126.9822163 세계로약국 판매중지 black
# 37.4804853 126.9814439 조은약국 1개 이하 gray
# 37.4823778 126.9815964 수온누리약국 1개 이하 gray
# 37.4826983 126.9813406 솔약국 1개 이하 gray
# 37.4843925 126.9805813 이수사랑약국 판매중지 black
# 37.484648 126.9817 골드약국 100개 이상 green
# 37.4847428 126.9814908 제중당건강약국 30개 이상 100개미만 orange
# 37.4849196 126.9815815 행복한오늘이수약국 판매중지 black
# 37.4851381 126.9805261 신세계약국 100개 이상 green
# 37.4854002 126.9804039 세브란스약국 1개 이하 gray
# 37.4853103 126.9808096 한라약국 0 0
# 37.4854183 126.9811511 사랑약국 판매중지 black
# 37.4861159 126.9826348 이수온누리약국 100개 이상 green
# 37.4865235 126.9815937 화천약국 30개 이상 100개미만 orange
# 37.4868002 126.9827042 방배세명약국 1개 이하 gray
# 37.4874684 126.9818694 조이온누리약국 30개 이상 100개미만 orange
# 37.4875211 126.9826143 동해물약국 1개 이하 gray
# 37.4860933 126.9829747 푸른약국 30개 이상 100개미만 orange
# 37.4854712 126.985056 홈케어방배약국 1개 이하 gray
# 37.4870229 126.9828023 방배대한약국 100개 이상 green
# 37.4877046 126.980672 대일약국 1개 이하 gray
# 37.4879691 126.9809385 시장약국 판매중지 black
# 37.4882228 126.9807015 이수약국 판매중지 black
# 37.4879721 126.9819529 광주약국 1개 이하 gray
# 37.4880188 126.9826525 열린약국 30개 이상 100개미만 orange
# 37.4882965 126.9818938 동광약국 판매중지 black
# 37.4882676 126.9827781 스마일약국 판매중지 black
# 37.4886136 126.9827975 수약국 판매중지 black
# 37.4825235 126.9948552 방일약국 30개 이상 100개미만 orange
# 37.4826852 126.9964077 서경약국 100개 이상 green
# 37.48297 126.9959656 보현약국 1개 이하 gray
# 37.4839058 126.9956497 서초제일약국 100개 이상 green
# 37.4838342 126.9964441 바른온누리약국 100개 이상 green
# 37.484401 126.9954182 메디칼약국 1개 이하 gray
# 37.4821718 126.9969232 소화약국 100개 이상 green
# 37.482364 126.9973977 영보서초프라자약국 1개 이하 gray
# 37.4811196 126.9983011 에이스온누리약국 100개 이상 green
# 37.4850956 126.9949469 내방약국 100개 이상 green
# 37.4888558 126.9925653 녹십자약국 30개 이상 100개미만 orange
# 37.4892973 126.9922868 뿌리약국 1개 이하 gray
# 37.4891828 126.9930611 강남메디칼약국 1개 이하 gray
# 37.4877484 126.9948034 숨온누리약국 1개 이하 gray
# 37.4938353 126.9832127 온누리동성약국 판매중지 black
# 37.4940739 126.9845834 구심약국 0 0
# 37.492594 126.9857965 시스템약국 100개 이상 green
# 37.4916462 126.9870712 정은약국 100개 이상 green
# 37.4920013 126.9906595 곰돌이스타약국 30개 이상 100개미만 orange
# 37.4927391 126.9896986 수도약국 100개 이상 green
# 37.493928 126.9860986 유경약국 0 0
# 37.4930421 126.9899521 온새미약국 100개 이상 green
# 37.4931756 126.9897944 메디컬제일약국 100개 이상 green
# 37.4930534 126.9906663 남영약국 100개 이상 green
# 37.4939257 126.9900089 서래비비약국 100개 이상 green
# 37.4948851 126.9894965 임마누엘온누리약국 판매중지 black
# 37.4964722 126.9853016 방배프라자약국 30개 이상 100개미만 orange
# 37.4968205 126.9845952 즐거운약국 30개 이상 100개미만 orange
# 37.4966615 126.9883974 성지약국 100개 이상 green
# 37.4910419 126.9918915 정신약국 100개 이상 green
# 37.4977269 126.9981356 행복을여는서래약국 1개 이하 gray
# 37.4987479 126.9985894 신명성약국 1개 이하 gray
# 37.4991169 126.9986055 오약국 판매중지 black
# 37.501096 126.987091 아주약국 30개 이상 100개미만 orange
# 37.5015073 126.9888151 약원한약국 100개 이상 green
# 37.501925 126.98885 은혜약국 2개이상 30개 미만 red
# 37.501993 126.989231 다솜약국 100개 이상 green
# 37.5030323 126.9955162 세화약국 100개 이상 green
# 37.503137 126.995885 사랑약국 100개 이상 green
# 37.5054719 126.9947131 버클리약국 100개 이상 green
# 37.50440748 127.0010481 3층한사랑약국 100개 이상 green
# 37.50450395 127.0005993 금화온누리약국 100개 이상 green
# 37.5045721 127.0006446 반포다정약국 100개 이상 green
# 37.5055124 127.0014772 메디케어약국 100개 이상 green
# 37.5173888 126.9851878 예사랑약국 1개 이하 gray
# 37.5260123 126.9969499 동광약국 0 0
# 37.5260203 126.9999592 신세계약국 1개 이하 gray
# 37.5263754 127.0009916 동오약국 1개 이하 gray
# 37.5272717 126.9996506 보광프라자약국 2개이상 30개 미만 red
# 37.5271965 127.0003047 코끼리약국 100개 이상 green
# 37.5282859 126.9992101 알파약국 1개 이하 gray
# 37.4640396 127.0250144 우면메디칼약국 30개 이상 100개미만 orange
# 37.4640419 127.0348038 양재신세계약국 1개 이하 gray
# 37.4645488 127.0255942 연두약국 1개 이하 gray
# 37.4661983 127.0242881 모아약국 1개 이하 gray
# 37.4632288 127.0435302 하나로약국 100개 이상 green
# 37.4682596 127.0389985 에이티약국 판매중지 black
# 37.4691346 127.0400425 양재로하스약국 2개이상 30개 미만 red
# 37.4704214 127.0252675 고명약국 100개 이상 green
# 37.4708599 127.0253951 초록약국 30개 이상 100개미만 orange
# 37.4710797 127.0394792 양재시민의숲수약국 30개 이상 100개미만 orange
# 37.4697225 127.0425255 신원약국 30개 이상 100개미만 orange
# 37.4694722 127.0445049 이오당약국 100개 이상 green
# 37.471705 127.045438 남부장수약국 판매중지 black
# 37.4718182 127.0457816 양재메디칼약국 2개이상 30개 미만 red
# 37.4722051 127.0407553 양재소망약국 30개 이상 100개미만 orange
# 37.4797458 127.0388381 푸른온누리약국 1개 이하 gray
# 37.4760709 127.04586 수정약국 판매중지 black
# 37.4778221 127.0451614 다나약국 판매중지 black
# 37.4785782 127.0453158 명심약국 1개 이하 gray
# 37.4827963 127.0033891 유킹스파머시메디바움약국 30개 이상 100개미만 orange
# 37.4828508 127.0061556 늘기쁜약국 2개이상 30개 미만 red
# 37.4828549 127.008763 메디팜유일약국 100개 이상 green
# 37.4831118 127.0075409 서광약국 1개 이하 gray
# 37.4838807 127.0091164 다나약국 30개 이상 100개미만 orange
# 37.4866165 127.0044612 나무약국 100개 이상 green
# 37.4901238 127.0059896 서초늘봄약국 1개 이하 gray
# 37.4856543 127.0113905 서초아트약국 100개 이상 green
# 37.4882498 127.00875 다보약국 1개 이하 gray
# 37.4884085 127.0088282 에스약국 2개이상 30개 미만 red
# 37.4835466 127.0151108 엔티약국 판매중지 black
# 37.4849497 127.0147775 서초백화점약국 100개 이상 green
# 37.4828044 127.0160719 슈퍼빌온누리약국 100개 이상 green
# 37.4857896 127.0154596 바른약국 100개 이상 green
# 37.4852908 127.0157273 서초로하스약국 1개 이하 gray
# 37.485459 127.0163019 장수알파약국 1개 이하 gray
# 37.4855763 127.0162228 원약국 1개 이하 gray
# 37.4858725 127.0162758 소망약국 0 0
# 37.4880847 127.0142926 샘약국 100개 이상 green
# 37.4884264 127.0141123 더블유스토어하이약국 100개 이상 green
# 37.4852246 127.0186682 자연약국 1개 이하 gray
# 37.4865092 127.0209709 서리풀약국 1개 이하 gray
# 37.4853822 127.0215079 십자당약국 판매중지 black
# 37.490495 127.0053816 사랑손약국 1개 이하 gray
# 37.4904873 127.0087491 늘푸른약국 판매중지 black
# 37.4914975 127.0082712 세븐약국 1개 이하 gray
# 37.4924204 127.0079825 위드팜서초역약국 판매중지 black
# 37.4941711 127.0100149 한일약국 2개이상 30개 미만 red
# 37.4994114 127.0033334 신청사구내약국 100개 이상 green
# 37.4914591 127.0137966 서초당약국 2개이상 30개 미만 red
# 37.4918747 127.0137428 구슬약국 100개 이상 green
# 37.4925781 127.0129955 새봄약국 1개 이하 gray
# 37.4929935 127.0134514 8층약국 100개 이상 green
# 37.493098 127.013494 세진약국 100개 이상 green
# 37.4928604 127.0141471 드림약국 100개 이상 green
# 37.4937277 127.0147172 진약국 100개 이상 green
# 37.4938049 127.0149613 현약국 1개 이하 gray
# 37.4938614 127.0151597 일이약국 판매중지 black
# 37.4939941 127.0155606 서초온누리약국 100개 이상 green
# 37.4944451 127.0132771 하나약국 100개 이상 green
# 37.4942515 127.0139865 나을약국 100개 이상 green
# 37.4944061 127.0151321 건강과행복이열리는약국 1개 이하 gray
# 37.4932316 127.016205 팜메이트대학당약국 100개 이상 green
# 37.49476 127.016321 푸른솔약국 30개 이상 100개미만 orange
# 37.4948927 127.0168286 제이약국 2개이상 30개 미만 red
# 37.4947301 127.0183064 브라운스톤약국 100개 이상 green
# 37.4951577 127.0176552 빛샘온누리약국 2개이상 30개 미만 red
# 37.4952553 127.0180081 교대사랑약국 2개이상 30개 미만 red
# 37.4905531 127.0212546 대림약국 100개 이상 green
# 37.4954178 127.0164171 샛별약국 100개 이상 green
# 37.49867 127.0130325 아크로비스타약국 1개 이하 gray
# 37.4999342 127.0174825 미래약국 1개 이하 gray
# 37.4961123 127.0194059 평강약국 100개 이상 green
# 37.4970821 127.0237071 진흥온누리약국 판매중지 black
# 37.4997906 127.0231824 아란약국 100개 이상 green
# 37.483329 127.034691 환승약국 100개 이상 green
# 37.4834254 127.03433 약사랑약국 판매중지 black
# 37.4839347 127.0345442 뿌리본약국 1개 이하 gray
# 37.4849717 127.0347727 양재미소약국 100개 이상 green
# 37.4873985 127.0285135 미소약국 판매중지 black
# 37.4878655 127.0269083 그린약국 100개 이상 green
# 37.4879042 127.0272409 기쁨약국 100개 이상 green
# 37.485373 127.0341031 메디피아약국 1개 이하 gray
# 37.4852658 127.0344506 프리모약국 판매중지 black
# 37.4864916 127.0335456 메디팜정연약국 1개 이하 gray
# 37.4887143 127.0298492 서초메이플약국 0 0
# 37.4893844 127.0322141 강남맑은약국 1개 이하 gray
# 37.4898384 127.0335644 정성온누리약국 1개 이하 gray
# 37.4833001 127.0362334 양재팜24약국 판매중지 black
# 37.4840275 127.0351327 양재프라자약국 100개 이상 green
# 37.4843523 127.0352051 해맑은약국 100개 이상 green
# 37.4849802 127.0351301 메디칼하늘약국 100개 이상 green
# 37.4844777 127.0366827 다인약국 100개 이상 green
# 37.4843263 127.0379729 동우약국 1개 이하 gray
# 37.4849144 127.039029 이든약국 1개 이하 gray
# 37.4808718 127.0413113 구룡수약국 100개 이상 green
# 37.4825067 127.0404371 민들레약국 1개 이하 gray
# 37.4843405 127.0457226 코코약국 1개 이하 gray
# 37.485065 127.035841 스타약국 100개 이상 green
# 37.4851832 127.0358917 우리들약국 1개 이하 gray
# 37.4851776 127.0359346 강남굿모닝약국 판매중지 black
# 37.4854618 127.0372443 샛별약국 100개 이상 green
# 37.4863793 127.0360059 온누리새재원약국 0 0
# 37.4853732 127.0377779 강남조은약국 100개 이상 green
# 37.4860876 127.0377128 해맑은약국 100개 이상 green
# 37.4863727 127.0377461 양재소화약국 100개 이상 green
# 37.4899681 127.0371993 동보옵티마약국 1개 이하 gray
# 37.4862048 127.0440699 매봉약국 1개 이하 gray
# 37.4911287 127.0248258 햇살약국 판매중지 black
# 37.4920742 127.0257084 행복약국 1개 이하 gray
# 37.4924723 127.026839 메디팜 동양약국 100개 이상 green
# 37.4925885 127.0292834 두리약국 1개 이하 gray
# 37.4930451 127.0293404 알파약국 판매중지 black
# 37.4932705 127.0293874 모닝온누리약국 100개 이상 green
# 37.4934899 127.0286063 펜타약국 100개 이상 green
# 37.4943208 127.0282322 플러스엔약국 2개이상 30개 미만 red
# 37.49432455 127.0283868 스마트온누리약국 1개 이하 gray
# 37.4915781 127.0311872 라온약국 1개 이하 gray
# 37.4929925 127.0304818 바이올렛약국 1개 이하 gray
# 37.4939945 127.0337328 역삼약국 판매중지 black
# 37.4943305 127.0330783 여리약국 1개 이하 gray
# 37.4972231 127.0262314 늘편한약국 100개 이상 green
# 37.4979716 127.0259786 지티타워약국 1개 이하 gray
# 37.497897 127.02646 아라약국 1개 이하 gray
# 37.4979429 127.0265303 아라타워아이약국 1개 이하 gray
# 37.4956227 127.0271068 서초삼성약국 100개 이상 green
# 37.4966324 127.0269076 다사랑약국 100개 이상 green
# 37.4964225 127.0277765 현대영약국 100개 이상 green
# 37.4964468 127.0279546 초이스약국 100개 이상 green
# 37.4955498 127.0292939 아름약국 1개 이하 gray
# 37.4958654 127.0292292 큰길약국 1개 이하 gray
# 37.4960271 127.029122 화인약국 1개 이하 gray
# 37.4966716 127.0286835 엠플러스약국 100개 이상 green
# 37.496546 127.0287995 강남미약국 100개 이상 green
# 37.4966918 127.0277221 퍼스트케어약국 100개 이상 green
# 37.497901 127.028709 미진약국 30개 이상 100개미만 orange
# 37.4977508 127.0293433 강남역스타약국 1개 이하 gray
# 37.4990456 127.0259655 신오약국 판매중지 black
# 37.4995532 127.026354 영약국 판매중지 black
# 37.5002585 127.0258452 에이트약국 1개 이하 gray
# 37.5000183 127.0260094 굿약국 30개 이상 100개미만 orange
# 37.4990209 127.0276559 코코온누리약국 1개 이하 gray
# 37.4992268 127.0275554 와이약국 100개 이상 green
# 37.4981647 127.0283079 신분당약국 1개 이하 gray
# 37.4985929 127.028075 이즈타워약국 100개 이상 green
# 37.498605 127.028078 제이약국 0 0
# 37.4980644 127.0293858 캠브리지5층약국 판매중지 black
# 37.498646 127.0285428 에이타워약국 1개 이하 gray
# 37.498664 127.0287237 뉴욕약국 판매중지 black
# 37.4988358 127.0290056 유니팜서울약국 판매중지 black
# 37.4988903 127.0292963 플러스약국 판매중지 black
# 37.4998129 127.0271777 씨티약국 100개 이상 green
# 37.4955423 127.0304041 강남봄약국 100개 이상 green
# 37.4971626 127.0304165 일번지약국 1개 이하 gray
# 37.4986 127.0308733 모건약국 100개 이상 green
# 37.4987952 127.0317205 삼주약국 100개 이상 green
# 37.4993258 127.0306682 국기원약국 100개 이상 green
# 37.4996098 127.0316927 라라약국 1개 이하 gray
# 37.4990028 127.0345782 올리브온누리약국 1개 이하 gray
# 37.5004008 127.0343432 강남제일약국 1개 이하 gray
# 37.4917279 127.0397471 행복한온누리약국 1개 이하 gray
# 37.4944701 127.0396202 아름다운우리약국 1개 이하 gray
# 37.4947912 127.040068 동의온누리약국 30개 이상 100개미만 orange
# 37.4923731 127.043449 도곡명약국 0 0
# 37.4929277 127.0413818 다솜약국 30개 이상 100개미만 orange
# 37.4930404 127.043795 서울세연약국 2개이상 30개 미만 red
# 37.4951022 127.0457489 곰돌이약국 2개이상 30개 미만 red
# 37.4965317 127.0386103 신혜성약국 2개이상 30개 미만 red
# 37.495772 127.0396503 역삼이화약국 1개 이하 gray
# 37.4988038 127.0366283 역삼생생약국 1개 이하 gray
# 37.4989891 127.0368362 좋은아침약국 1개 이하 gray
# 37.4996461 127.0358567 역삼오늘약국 판매중지 black
# 37.5000263 127.0365456 해림온누리약국 판매중지 black
# 37.5000425 127.0393589 강남미소약국 1개 이하 gray
# 37.497866 127.0428326 아로마약국 판매중지 black
# 37.4979648 127.0431669 밝은약국 1개 이하 gray
# 37.4967404 127.045112 유진약국 100개 이상 green
# 37.4752188 127.0475934 강남세계로약국 1개 이하 gray
# 37.4746937 127.0505123 녹십자옵티마약국 1개 이하 gray
# 37.478549 127.0468174 소나무약국 1개 이하 gray
# 37.4789525 127.0472695 성심약국 100개 이상 green
# 37.4786577 127.0477248 기쁨약국 2개이상 30개 미만 red
# 37.4790142 127.0479597 행복온누리약국 100개 이상 green
# 37.4808633 127.0530052 맑은하늘약국 100개 이상 green
# 37.4824625 127.0544858 개포메디칼약국 100개 이상 green
# 37.4881971 127.0511464 메트로약국 1개 이하 gray
# 37.4873416 127.0515495 솔빛동양약국 100개 이상 green
# 37.4873316 127.0515695 123약국 판매중지 black
# 37.4888094 127.051637 도곡타워약국 1개 이하 gray
# 37.4887614 127.0532227 서이약국 1개 이하 gray
# 37.4833803 127.0600593 개포종로온누리약국 100개 이상 green
# 37.4824818 127.0611935 개포플러스약국 30개 이상 100개미만 orange
# 37.4846559 127.0672555 아너힐즈약국 2개이상 30개 미만 red
# 37.4886971 127.066869 메디팜보문약국 판매중지 black
# 37.4886971 127.066869 메디칼미래약국 100개 이상 green
# 37.4885648 127.0674601 삼우약국 30개 이상 100개미만 orange
# 37.4937596 127.0465625 연우약국 판매중지 black
# 37.49364579 127.0466251 도곡메디칼약국 1개 이하 gray
# 37.4907101 127.0561424 박약국 판매중지 black
# 37.490918 127.056341 은혜온누리약국 1개 이하 gray
# 37.4953203 127.0526153 한티약국 1개 이하 gray
# 37.4953203 127.0526153 사랑플러스약국 판매중지 black
# 37.4953009 127.0527051 도곡우리약국 2개이상 30개 미만 red
# 37.4977927 127.0504018 수약국 2개이상 30개 미만 red
# 37.4984403 127.0461337 정다운이화약국 100개 이상 green
# 37.4992649 127.0484171 개나리봄약국 100개 이상 green
# 37.499476 127.048333 한솔인유로온누리약국 100개 이상 green
# 37.495499 127.05273 렉슬약국 판매중지 black
# 37.495847 127.0527545 약손메디칼약국 1개 이하 gray
# 37.497171 127.0514558 스카이약국 100개 이상 green
# 37.4973384 127.052077 웰그린약국 100개 이상 green
# 37.4976136 127.0519545 자인한약국 100개 이상 green
# 37.4978272 127.0524003 이레약국 판매중지 black
# 37.4978503 127.0526565 동명온누리약국 100개 이상 green
# 37.4966282 127.05525 대치예스약국 판매중지 black
# 37.4973826 127.0547242 케이팜약국 2개이상 30개 미만 red
# 37.4978037 127.0544537 대치필리아약국 30개 이상 100개미만 orange
# 37.4973874 127.05518 정온누리약국 100개 이상 green
# 37.4976776 127.0563325 종로약국 100개 이상 green
# 37.497809 127.0567755 용모준수 한약국 1개 이하 gray
# 37.4978357 127.0568844 베스트약국 30개 이상 100개미만 orange
# 37.4990383 127.0519153 화일약국 판매중지 black
# 37.4998981 127.0515062 팜메이트수정약국 2개이상 30개 미만 red
# 37.4930574 127.0583169 우리온누리약국 판매중지 black
# 37.4931523 127.059201 메디칼청실약국 1개 이하 gray
# 37.4935668 127.0603963 바른약국 0 0
# 37.4936573 127.0603988 대치참약국 1개 이하 gray
# 37.4933467 127.0618627 우리대치약국 판매중지 black
# 37.4933406 127.0618783 윈플러스약국 1개 이하 gray
# 37.4939991 127.0613534 대치메디칼약국 2개이상 30개 미만 red
# 37.4942695 127.0619463 메타팜약국 판매중지 black
# 37.4939501 127.0629299 퍼스트약국 30개 이상 100개미만 orange
# 37.49533324 127.0638655 동성약국 100개 이상 green
# 37.49533324 127.0638655 건강온누리약국 1개 이하 gray
# 37.4949298 127.0664524 온누리구인당약국 100개 이상 green
# 37.494847 127.066547 수진약국 1개 이하 gray
# 37.4971924 127.06143 유정약국 판매중지 black
# 37.4979855 127.0588484 나리약국 판매중지 black
# 37.4981189 127.0595717 강남백세약국 1개 이하 gray
# 37.4988443 127.0595805 오늘약국 0 0
# 37.4980642 127.0609247 강남메디칼약국 100개 이상 green
# 37.4984331 127.0604425 정일약국 2개이상 30개 미만 red
# 37.4956122 127.0634731 은마수약국 1개 이하 gray
# 37.4977415 127.0650701 은마(銀馬)오행한약국 100개 이상 green
# 37.4991911 127.0630094 강남보선약국 판매중지 black
# 37.4997818 127.0626942 신한약국 판매중지 black
# 37.5000675 127.0636948 강남새천년온누리약국 1개 이하 gray
# 37.4887593 127.0681338 양월약국 1개 이하 gray
# 37.4886321 127.0704418 성모약국 2개이상 30개 미만 red
# 37.4840224 127.0844597 위드팜바른약국 판매중지 black
# 37.4840736 127.0844518 일원역약국 판매중지 black
# 37.4849981 127.0827122 샘터약국 1개 이하 gray
# 37.485676 127.083475 천사약국 30개 이상 100개미만 orange
# 37.485692 127.083467 참약국 100개 이상 green
# 37.4856929 127.0834678 삼성강남약국 2개이상 30개 미만 red
# 37.4857461 127.0834376 이대학약국 2개이상 30개 미만 red
# 37.4856552 127.0834938 삼성정문약국 1개 이하 gray
# 37.48566097 127.0836055 희망약국 30개 이상 100개미만 orange
# 37.4857606 127.0835254 독수리약국 100개 이상 green
# 37.4858151 127.0834039 열린약국 판매중지 black
# 37.489771 127.0815915 파랑새약국 30개 이상 100개미만 orange
# 37.4892734 127.0818266 이삼성약국 100개 이상 green
# 37.4896246 127.0816527 성균관약국 100개 이상 green
# 37.4926408 127.0755891 튼튼중앙약국 100개 이상 green
# 37.4926727 127.075589 조은온누리약국 판매중지 black
# 37.4926645 127.0756013 솔약국 1개 이하 gray
# 37.4926645 127.0756013 석탑이레약국 100개 이상 green
# 37.492626 127.075748 솔잎약국 100개 이상 green
# 37.49279 127.075769 사랑약국 100개 이상 green
# 37.4986677 127.0681377 지영온누리약국 판매중지 black
# 37.4903399 127.0813255 온누리우인약국 100개 이상 green
# 37.4906472 127.0811988 두리약국 2개이상 30개 미만 red
# 37.4909192 127.0810631 주민약국 1개 이하 gray
# 37.4943549 127.0796608 대청약국 판매중지 black
# 37.5006686 127.0032572 조달약국 판매중지 black
# 37.5030801 127.004145 위드팜솔약국 100개 이상 green
# 37.5031529 127.0043696 위드팜수약국 100개 이상 green
# 37.5049178 127.0032131 굿모닝약국 1개 이하 gray
# 37.5057266 127.0021903 사랑의약국 100개 이상 green
# 37.5049302 127.0049482 고연뿌리약국 100개 이상 green
# 37.50568 127.0058468 고속터미널약국 30개 이상 100개미만 orange
# 37.501898 127.0114788 반포소망약국 100개 이상 green
# 37.5021206 127.0113916 라임약국 100개 이상 green
# 37.5029914 127.0104564 티파니약국 판매중지 black
# 37.502144 127.011992 우리들약국 1개 이하 gray
# 37.50216885 127.0120781 샘터약국 판매중지 black
# 37.5021689 127.0120781 서초미소약국 판매중지 black
# 37.5022495 127.0120029 이층은약국 100개 이상 green
# 37.5024256 127.0122323 메딕스약국 100개 이상 green
# 37.5044879 127.0078625 천사약국 30개 이상 100개미만 orange
# 37.5032427 127.0108591 보람약국 100개 이상 green
# 37.5060987 127.0034174 연세온누리약국 100개 이상 green
# 37.5082154 127.0036767 반원온누리약국 100개 이상 green
# 37.506922 127.006405 한샘약국 30개 이상 100개미만 orange
# 37.5070108 127.006438 희망약국 100개 이상 green
# 37.508788 127.0035627 서초21세기약국 1개 이하 gray
# 37.5101489 127.0071056 킴스약국 30개 이상 100개미만 orange
# 37.5075097 127.0080778 신세기약국 30개 이상 100개미만 orange
# 37.50715923 127.0097898 자이프라자약국 30개 이상 100개미만 orange
# 37.5071118 127.0098751 행복나눔약국 100개 이상 green
# 37.5071118 127.0098751 반포자이중앙약국 100개 이상 green
# 37.5071118 127.0098751 기린약국 2개이상 30개 미만 red
# 37.5071118 127.0098751 보물섬약국 100개 이상 green
# 37.5104312 127.0100932 파스텔약국 30개 이상 100개미만 orange
# 37.5086203 127.011936 한성약국 1개 이하 gray
# 37.5015193 127.0217846 메디팜나리약국 30개 이상 100개미만 orange
# 37.5042077 127.0209329 삼미약국 1개 이하 gray
# 37.5032162 127.0235331 밝은약국 1개 이하 gray
# 37.5046399 127.0229534 도일약국 100개 이상 green
# 37.506631 127.013948 자이수약국 2개이상 30개 미만 red
# 37.5066094 127.0226368 조은약국 100개 이상 green
# 37.5076446 127.0224917 더하늘약국 100개 이상 green
# 37.5071711 127.0227046 신논현올리브약국 1개 이하 gray
# 37.5082743 127.0231572 센느약국 판매중지 black
# 37.5108022 127.0195244 반포프라자약국 30개 이상 100개미만 orange
# 37.5104079 127.0198206 반포사랑약국 0 0
# 37.510542 127.0211522 한약국 100개 이상 green
# 37.5085362 127.0222069 영동프라자약국 판매중지 black
# 37.5095804 127.0224836 영양과건강약국 판매중지 black
# 37.5086243 127.0229424 광성약국 2개이상 30개 미만 red
# 37.5091603 127.0227162 영동약국 0 0
# 37.5101931 127.021184 논현온누리약국 100개 이상 green
# 37.5099284 127.0233542 연세팜약국 100개 이상 green
# 37.5127259 127.0068701 한신메디칼약국 1개 이하 gray
# 37.5128156 127.0106598 잠원스타약국 100개 이상 green
# 37.513024 127.0127663 신우성약국 30개 이상 100개미만 orange
# 37.5144057 127.011511 서초늘푸른약국 1개 이하 gray
# 37.5117874 127.0205649 씨케이광생약국 100개 이상 green
# 37.5119318 127.0213994 현온누리약국 1개 이하 gray
# 37.5110167 127.0227 왕성약국 1개 이하 gray
# 37.5145482 127.0204374 민트약국 1개 이하 gray
# 37.5150433 127.0193368 씨티약국 1개 이하 gray
# 37.5157646 127.0192069 신사행복나눔약국 1개 이하 gray
# 37.5150269 127.020372 신사웰약국 30개 이상 100개미만 orange
# 37.5151992 127.0203715 미플러스약국 판매중지 black
# 37.5154265 127.0201502 신사온누리약국 100개 이상 green
# 37.5160775 127.0203412 강남퍼스트약국 판매중지 black
# 37.5178106 127.0154112 대영약국 100개 이상 green
# 37.5178526 127.0154234 메디팜은강약국 100개 이상 green
# 37.5166301 127.0190008 메디칼허브약국 100개 이상 green
# 37.5171234 127.0187945 신사스타약국 판매중지 black
# 37.5171485 127.0197123 싱싱온누리약국 판매중지 black
# 37.5173114 127.0196503 순수약국 100개 이상 green
# 37.5161887 127.0206793 트리플약국 판매중지 black
# 37.5162749 127.0210472 코끼리약국 100개 이상 green
# 37.5168437 127.0198235 오월애약국 100개 이상 green
# 37.5168631 127.0201484 타워약국 100개 이상 green
# 37.5168691 127.0205249 신사약국 100개 이상 green
# 37.5169652 127.020708 에스약국 100개 이상 green
# 37.5170222 127.0208674 가나안약국 100개 이상 green
# 37.5166692 127.0217379 포인트약국 1개 이하 gray
# 37.5167404 127.021882 신사굿약국 100개 이상 green
# 37.516854 127.0221405 에메랄드약국 2개이상 30개 미만 red
# c:\users\ezen\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:15: UserWarning: color argument of Icon should be one of: {'black', 'lightred', 'blue', 'lightgreen', 'darkblue', 'gray', 'cadetblue', 'beige', 'white', 'green', 'orange', 'darkred', 'pink', 'lightblue', 'red', 'darkpurple', 'lightgray', 'purple', 'darkgreen'}.
#   from ipykernel import kernelapp as app
# 37.5169298 127.0223189 오렌지약국 1개 이하 gray
# 37.5011826 127.0255738 새드림약국 판매중지 black
# 37.5013657 127.0255201 스타약국 판매중지 black
# 37.5015461 127.0254021 아임약국 2개이상 30개 미만 red
# 37.501235 127.0266249 강남웰약국 1개 이하 gray
# 37.5020128 127.0244608 아이약국 1개 이하 gray
# 37.5023687 127.0248894 새열린약국 1개 이하 gray
# 37.502832 127.0245612 메디안약국 0 0
# 37.5024003 127.0259642 행복한수약국 1개 이하 gray
# 37.5034826 127.024458 강남약국 100개 이상 green
# 37.5038061 127.0241492 가온약국 2개이상 30개 미만 red
# 37.5041598 127.0251636 더블유약국 100개 이상 green
# 37.5043479 127.0250552 레이첼약국 100개 이상 green
# 37.5049158 127.0248029 신논현비비약국 100개 이상 green
# 37.5049634 127.0250571 고은약국 판매중지 black
# 37.5051136 127.0246963 제일그랜드약국 1개 이하 gray
# 37.5045463 127.0256122 영원약국 100개 이상 green
# 37.5050767 127.0255834 신논현약국 100개 이상 green
# 37.5051313 127.0253462 웰스약국 판매중지 black
# 37.5053198 127.0264873 별하약국 100개 이상 green
# 37.5010881 127.0342169 경희자연한약국 판매중지 black
# 37.504318 127.0341902 역삼라이프약국 판매중지 black
# 37.50591 127.0242904 건강한세상행복한약국 판매중지 black
# 37.5062114 127.0241192 블루밍약국 판매중지 black
# 37.507009 127.0262268 종원약국 1개 이하 gray
# 37.5059195 127.028339 거평원온누리약국 2개이상 30개 미만 red
# 37.5074895 127.0272657 노바약국 판매중지 black
# 37.5091939 127.0239878 중외약국 100개 이상 green
# 37.5085003 127.0271867 예주약국 100개 이상 green
# 37.5089717 127.0267236 유한약국 100개 이상 green
# 37.5088851 127.0270957 논현연세약국 100개 이상 green
# 37.5100801 127.0272193 갤러리약국 100개 이상 green
# 37.5082883 127.032087 우창약국 1개 이하 gray
# 37.5061371 127.0340773 비타약국 30개 이상 100개미만 orange
# 37.5063354 127.0346621 역삼태평양약국 판매중지 black
# 37.5077609 127.0333814 선한약국 판매중지 black
# 37.5076529 127.0340669 논현천사약국 100개 이상 green
# 37.5071359 127.0342994 옵티마미소약국 1개 이하 gray
# 37.5097418 127.0324367 파낙스약국 30개 이상 100개미만 orange
# 37.5015031 127.0362475 성지프라자약국 100개 이상 green
# 37.50158473 127.0361824 참좋은선약국 1개 이하 gray
# 37.50127 127.0363876 세코아약국 100개 이상 green
# 37.5019299 127.036116 팜스약국 100개 이상 green
# 37.5022404 127.0360084 다정온누리약국 판매중지 black
# 37.502783 127.035473 역삼다인약국 2개이상 30개 미만 red
# 37.5019949 127.0373364 다래약국 1개 이하 gray
# 37.5007722 127.0388458 샬롬온누리약국 100개 이상 green
# 37.5010791 127.0388899 테헤란한서약국 2개이상 30개 미만 red
# 37.501434 127.0401789 수온누리약국 1개 이하 gray
# 37.5037183 127.0361414 초원약국 1개 이하 gray
# 37.5009284 127.0407513 역삼우주약국 판매중지 black
# 37.5016641 127.040788 행복한약국 1개 이하 gray
# 37.5028561 127.0447712 누리약국 1개 이하 gray
# 37.5039653 127.0427681 상록약국 1개 이하 gray
# 37.5064634 127.035473 온누리기쁜약국 0 0
# 37.5079982 127.0352111 센트럴약국 1개 이하 gray
# 37.5088657 127.0377994 늘푸른약국 1개 이하 gray
# 37.5098079 127.0399697 희병약국 판매중지 black
# 37.5085412 127.0405205 호원약국 1개 이하 gray
# 37.5101956 127.0426534 선정릉약국 1개 이하 gray
# 37.5102889 127.0429841 정약국 1개 이하 gray
# 37.5093737 127.0437708 선능약국 판매중지 black
# 37.5090876 127.0440696 싱싱약국 2개이상 30개 미만 red
# 37.5122594 127.0243422 준약국 1개 이하 gray
# 37.5115889 127.0322915 온정약국 100개 이상 green
# 37.5132272 127.0347787 민생약국 100개 이상 green
# 37.5144327 127.0312001 학동약국 100개 이상 green
# 37.5149534 127.0299718 청아약국 판매중지 black
# 37.5159635 127.0295561 드림약국 30개 이상 100개미만 orange
# 37.5149988 127.0309323 논현동약국 30개 이상 100개미만 orange
# 37.514462 127.0335294 장약국 0 0
# 37.5148748 127.0325683 르씨엘약국 100개 이상 green
# 37.5175117 127.0244441 리본약국 1개 이하 gray
# 37.519033 127.0256588 바른약국 1개 이하 gray
# 37.5195098 127.0288636 에이엔씨약국 100개 이상 green
# 37.5209513 127.0278614 혜린약국 100개 이상 green
# 37.519992 127.0323587 인터팜이화약국 1개 이하 gray
# 37.5200967 127.0337064 트리스약국 2개이상 30개 미만 red
# 37.5136165 127.0349599 강남정성약국 판매중지 black
# 37.5161365 127.0396693 논현약국 판매중지 black
# 37.511524 127.0437495 청담밝은약국 1개 이하 gray
# 37.5137633 127.0423077 논현필리아약국 100개 이상 green
# 37.515084 127.0423767 국풍당약국 1개 이하 gray
# 37.515984 127.0433374 청담이화약국 판매중지 black
# 37.5162232 127.0350108 행복한미래약국 판매중지 black
# 37.5162518 127.037436 논현사랑약국 판매중지 black
# 37.51658 127.0383546 강남프라자약국 100개 이상 green
# 37.5165684 127.0401763 소망온누리약국 100개 이상 green
# 37.5179871 127.0402998 노벨약국 100개 이상 green
# 37.5193597 127.0367435 동현당약국 100개 이상 green
# 37.5166739 127.0405659 미네랄약국 100개 이상 green
# 37.5166742 127.0405662 웰팜약국 100개 이상 green
# 37.5166379 127.041237 올리브약국 100개 이상 green
# 37.516703 127.0417196 삼성건강약국 100개 이상 green
# 37.51688938 127.0410534 강남허브약국 30개 이상 100개미만 orange
# 37.517959 127.0407761 논현수약국 100개 이상 green
# 37.5181016 127.044728 세명약국 100개 이상 green
# 37.5181798 127.0451947 가온약국 100개 이상 green
# 37.5189081 127.0404201 굿케어약국 100개 이상 green
# 37.5266681 127.0022624 문화약국 판매중지 black
# 37.5228904 127.0206138 가로수길약국 30개 이상 100개미만 orange
# 37.524755 127.019656 미성약국 100개 이상 green
# 37.5241491 127.0229421 압구정길약국 100개 이상 green
# 37.5321216 127.0054498 부자약국 100개 이상 green
# 37.5324403 127.0056822 옵티마찬미약국 100개 이상 green
# 37.5338781 127.0081684 문약국 1개 이하 gray
# 37.5338878 127.0081714 시온약국 2개이상 30개 미만 red
# 37.5228334 127.0262805 경희서울한약국 판매중지 black
# 37.522913 127.0266474 늘봄약국 100개 이상 green
# 37.5216344 127.0278945 마리약국 100개 이상 green
# 37.521937 127.0279673 루비약국 100개 이상 green
# 37.5219996 127.0285577 비원약국 100개 이상 green
# 37.5231164 127.0273583 메디팜무지개약국 100개 이상 green
# 37.523104 127.0279657 그린약국 판매중지 black
# 37.5232635 127.0277277 압구정웰약국 100개 이상 green
# 37.523368 127.0274507 밝은온누리약국 100개 이상 green
# 37.5236581 127.0279574 비타민약국 100개 이상 green
# 37.5230746 127.0286162 행운약국 판매중지 black
# 37.5227638 127.0291249 메디팜압구정약국 100개 이상 green
# 37.5243704 127.0240267 양성심약국 0 0
# 37.5244761 127.0242006 압구정원약국 100개 이상 green
# 37.5249808 127.0246049 팜팜약국 판매중지 black
# 37.5248723 127.0253986 압구정스타약국 판매중지 black
# 37.525422 127.0244457 금강약국 100개 이상 green
# 37.5256895 127.025041 신현대약국 100개 이상 green
# 37.5253704 127.0253504 태양약국 100개 이상 green
# 37.5254436 127.0266599 압구정미약국 30개 이상 100개미만 orange
# 37.5255661 127.0260696 새봄약국 100개 이상 green
# 37.5240057 127.0277428 하늘약국 100개 이상 green
# 37.524127 127.027749 제이비미소약국 100개 이상 green
# 37.524478 127.0277477 여기애가까운약국 0 0
# 37.5247742 127.0275307 신사수약국 100개 이상 green
# 37.5248319 127.0278537 압구정영약국 100개 이상 green
# 37.5241694 127.0280894 밝은마음약국 100개 이상 green
# 37.5240509 127.0287459 생생온누리약국 판매중지 black
# 37.5245705 127.0288588 소호약국 100개 이상 green
# 37.5250914 127.0281445 압구정퀸약국 100개 이상 green
# 37.5254936 127.0271419 압구정제이약국 100개 이상 green
# 37.5256731 127.0278588 압구정엘약국 100개 이상 green
# 37.5262658 127.0272414 서울해나약국 0 0
# 37.5263327 127.0274689 드림케어약국 100개 이상 green
# 37.5253553 127.0281157 압구정프라자온누리약국 100개 이상 green
# 37.5260958 127.028912 뽀빠이약국 1개 이하 gray
# 37.5234364 127.0294742 이즈약국 100개 이상 green
# 37.5259308 127.02943 성일온누리약국 100개 이상 green
# 37.5259555 127.0294773 압구정화이트약국 판매중지 black
# 37.5239772 127.0324346 한양약국 100개 이상 green
# 37.5265322 127.0276588 압구정온누리약국 100개 이상 green
# 37.5266107 127.029393 다현약국 2개이상 30개 미만 red
# 37.526711 127.0290968 굿윌압구정약국 2개이상 30개 미만 red
# 37.5274785 127.0309168 건강한온누리약국 100개 이상 green
# 37.5274022 127.0309965 채움약국 1개 이하 gray
# 37.5276422 127.0313377 세진약국 2개이상 30개 미만 red
# 37.5278531 127.0304776 명옥약국 판매중지 black
# 37.5278757 127.0319141 압구정소망약국 100개 이상 green
# 37.5285688 127.0321634 하나약국 100개 이상 green
# 37.5272292 127.0330923 하이약국 100개 이상 green
# 37.5285704 127.0333541 호산나약국 100개 이상 green
# 37.5288635 127.0347606 압구정늘푸른온누리약국 판매중지 black
# 37.5217443 127.0376648 소은약국 1개 이하 gray
# 37.5220267 127.0391948 인선약국 30개 이상 100개미만 orange
# 37.5233586 127.0383812 청담케이팜약국 30개 이상 100개미만 orange
# 37.5239003 127.0396632 건영약국 100개 이상 green
# 37.5240581 127.0382819 만약국 30개 이상 100개미만 orange
# 37.524811 127.039264 중앙약국 판매중지 black
# 37.524803 127.039429 창현약국 30개 이상 100개미만 orange
# 37.5256156 127.0393899 로데오약국 100개 이상 green
# 37.5237755 127.0409346 유니팜약국 판매중지 black
# 37.5232223 127.0449509 라이프약국 1개 이하 gray
# 37.5287057 127.0360462 더블유수약국 100개 이상 green
# 37.5274594 127.0397709 압구정드림약국 2개이상 30개 미만 red
# 37.5272801 127.0402905 갤러리아온누리약국 100개 이상 green
# 37.5275634 127.0403991 압구정약국 100개 이상 green
# 37.5280262 127.0384898 감마약국 판매중지 black
# 37.5317799 127.0269754 압구정예주약국 100개 이상 green
# 37.5320562 127.0284897 도움약국 판매중지 black
# 37.532288 127.028402 봄약국 판매중지 black
# 37.5029975 127.0465038 샘약국 1개 이하 gray
# 37.5008073 127.0510334 우주약국 판매중지 black
# 37.5009718 127.0510148 나무약국 100개 이상 green
# 37.5011571 127.0508521 강남온누리약국 100개 이상 green
# 37.5020673 127.0504163 청아토한약국 2개이상 30개 미만 red
# 37.5029179 127.0500875 진선약국 1개 이하 gray
# 37.5035425 127.0470436 선릉타워약국 1개 이하 gray
# 37.5037151 127.0476984 다온약국 1개 이하 gray
# 37.5047001 127.048034 선릉코코약국 판매중지 black
# 37.5047776 127.0484885 테헤란약국 0 0
# 37.5048189 127.0486102 약사랑약국 1개 이하 gray
# 37.505111 127.0483205 킴다나약국 1개 이하 gray
# 37.5055601 127.0477358 상지온누리약국 1개 이하 gray
# 37.5052789 127.0483291 한사랑약국 0 0
# 37.5034574 127.0491411 타임약국 판매중지 black
# 37.5035623 127.05109 테헤란건강약국 30개 이상 100개미만 orange
# 37.5050919 127.0495325 강남우리온누리약국 1개 이하 gray
# 37.5051717 127.0489654 선릉수정약국 1개 이하 gray
# 37.5006133 127.0516616 서울메디약국 30개 이상 100개미만 orange
# 37.5013599 127.0527126 대치약국 0 0
# 37.5042024 127.0520244 골드로즈약국 2개이상 30개 미만 red
# 37.5044976 127.051631 펜타약국 0 0
# 37.5039541 127.0559781 서울온누리약국 판매중지 black
# 37.5056306 127.0552512 7층애약국 1개 이하 gray
# 37.5059949 127.0525555 삼성일신약국 1개 이하 gray
# 37.5086989 127.0559332 삼성해든약국 30개 이상 100개미만 orange
# 37.5089594 127.0568255 삼성수약국 판매중지 black
# 37.5106027 127.0542916 은약국 1개 이하 gray
# 37.5030095 127.0590063 프라임엠약국 1개 이하 gray
# 37.5038257 127.0617184 대치이화약국 100개 이상 green
# 37.5066302 127.0573587 해성약국 1개 이하 gray
# 37.5060956 127.0589612 장생당약국 1개 이하 gray
# 37.5077819 127.0582386 삼성하나약국 1개 이하 gray
# 37.5074386 127.0597679 미소약국 1개 이하 gray
# 37.5082158 127.0622887 허지웅약국 1개 이하 gray
# 37.5096122 127.0580011 이도건강약국 판매중지 black
# 37.5083801 127.0585572 사랑온누리약국 1개 이하 gray
# 37.5086361 127.0586131 소망약국 2개이상 30개 미만 red
# 37.5087437 127.0583424 참좋은약국 1개 이하 gray
# 37.5095508 127.0594693 도심공항약국 1개 이하 gray
# 37.5080512 127.0628172 온누리타워약국 판매중지 black
# 37.5078239 127.0649277 메디칼희민약국 1개 이하 gray
# 37.5065841 127.0653267 연약국 100개 이상 green
# 37.5085851 127.0665666 동호약국 1개 이하 gray
# 37.5124855 127.0504907 신삼성약국 100개 이상 green
# 37.5126016 127.0508054 삼성도담약국 30개 이상 100개미만 orange
# 37.5128053 127.0507105 해오름약국 판매중지 black
# 37.5127264 127.0512686 희영온누리약국 30개 이상 100개미만 orange
# 37.5123688 127.0519533 자연애약국 1개 이하 gray
# 37.5149738 127.0526451 아이조은약국 100개 이상 green
# 37.5183992 127.0462942 영진약국 100개 이상 green
# 37.5184312 127.0466482 청담수약국 1개 이하 gray
# 37.5174072 127.0513431 옵티마대영약국 1개 이하 gray
# 37.5187786 127.0483242 생명샘약국 100개 이상 green
# 37.5189469 127.0493939 청담별빛약국 100개 이상 green
# 37.5192717 127.0496171 타조약국 2개이상 30개 미만 red
# 37.5191636 127.0504815 청담명약국 30개 이상 100개미만 orange
# 37.519184 127.0508086 청담약국 1개 이하 gray
# 37.5197323 127.0502063 아이약국 100개 이상 green
# 37.5203862 127.0516919 보리수약국 30개 이상 100개미만 orange
# 37.5200321 127.0558075 청담온누리약국 100개 이상 green
# 37.5211496 127.0555135 청담본약국 100개 이상 green
# 37.5128784 127.0572911 팜엑스약국 1개 이하 gray
# 37.5146257 127.0606035 하늘온누리약국 100개 이상 green
# 37.5155186 127.0615148 부활약국 판매중지 black
# 37.5121721 127.0653425 강남소화약국 판매중지 black
# 37.5144324 127.0654871 베어약국 0 0
# 37.5170204 127.0643054 수라인 한약국 판매중지 black
# 37.5064784 127.0742513 쌍용약국 2개이상 30개 미만 red
# 37.506698 127.074222 프리마약국 100개 이상 green
# 37.507218 127.074305 우성약국 판매중지 black
# 37.5086777 127.0771146 선수촌약국 판매중지 black
# 37.5046028 127.0807043 온누리건강약국 1개 이하 gray
# 37.5061748 127.0807789 바른삼성약국 100개 이상 green
# 37.5064655 127.0814485 정선약국 판매중지 black
# 37.5100727 127.0800474 라미약국 100개 이상 green
# 37.5115631 127.0792026 다인약국 100개 이상 green
# 37.5236212 127.0480449 청담메디웰약국 1개 이하 gray
# 37.5247587 127.0485533 스템약국 0 0
# 37.525274 127.0472279 청담와이약국 판매중지 black
# 37.5240752 127.0503048 영지약국 1개 이하 gray
# 37.5242895 127.0501554 새생명약국 1개 이하 gray
# 37.5223851 127.0564116 정원약국 판매중지 black
# 37.5223851 127.0564116 청담제일약국 판매중지 black
# 37.5224875 127.0577062 새휘정약국 30개 이상 100개미만 orange
# 37.4571487 127.015332 태평양약국 2개이상 30개 미만 red
# 37.4555506 127.0609502 봄약국 2개이상 30개 미만 red
# 37.4566898 127.0599758 늘픔약국 100개 이상 green

# %%
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
