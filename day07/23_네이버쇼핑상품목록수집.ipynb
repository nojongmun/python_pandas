# %% [markdown]
# # 23_네이버 쇼핑 상품 목록 수집
#
# 네이버 쇼핑에서 특정 키워드로 검색된 내용을 엑셀로 수집하기
#
# ## #01. 필요한 모듈 참조

# %%
import requests
import urllib      
from bs4 import BeautifulSoup     
from pandas import DataFrame

# %% [markdown]
# ## #02. 수집 준비
#
# ### 1) 접속을 수행하기 위한 session 객체 생성
#
# > 웹 페이지에서 데이터를 수집할 때 가장 처음에 위치해야 하는 코드 입니다.

# %%
# 접속 세션 만들기 
user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.149 Safari/537.36"
session = requests.Session()
session.headers.update({'User-agent':user_agent, 'referer':None})

# %% [markdown]
# ### 2) 접근할 페이지 주소(네이버 쇼핑 검색 결과 주소 패턴)
#
# #### 필요한 변수들 정의

# %%
keyword ="카메라"
max_page = 5

# %% [markdown]
# #### 기본 URL
#
# 브라우저에 표시되는 검색 결과 URL에서 `?`전 까지만 지정

# %%
base_url = "https://search.shopping.naver.com/search/all.nhn"

# %% [markdown]
# ####  파라미터 구조
#
# 2페이지부터 3~4 페이지 정도 직접 이동하여 주소를 확인한 후 패턴을 찾는다.
#
# > origQuery=검색어&pagingIndex=2&pagingSize=40&viewType=list&sort=rel&frm=NVSHPAG&query=검색어

# %%
base_param = {"origQuery":keyword,"pagingIndex":1, "pagingSize":40, "viewType":"list", "sort":"rel","frm" :"NVSHPAG", "query":keyword}

# %% [markdown]
# ## #03. 반복 수행으로 데이터 수집하기
#
# 개별 상품 정보들을 딕셔너리 형태로 수집한 다음 미리 준비한 빈 리스트에 추가한다.

# %%
# 수집 결과를 누적할 빈 리스트 
data_list = []

# 원하는 페이지 수 만큼 반복
for page in range(1, max_page+1):
  
    # 1) 접속할 주소 준비하기 
    #  파라미터에서 접근할 페이지 번호 설정
    base_param['pagingIndex'] = page
    
    # URLEncoding
    query = urllib.parse.urlencode(base_param)
    
    # 접속할 주소 확정
    content_url = base_url + "?" + query

    # 출력으로 5줄 url이 나오는지 확인하기 
    # print(content_url)
    
    # 2) 페이지에 접속하여 상품정보 박스 가져오기 
    # 세션을 통해서 주소에 접속
    r = session.get(content_url)
    
    if r.status_code != 200:
        print("%d 에러가 발생했습니다." % r.status-conde)
        continue
        
    # 인코딩 설정        
    r.encoding="utf-8"      
    
    # 웹 페이지의 소스코드 HTML 분석 객체로 생성
    soup = BeautifulSoup(r.text, 'html.parser')
    
    # 상품 정보 박스 추출
    # 클래스 속성값은 앞에 점(.)을 붙여서 접근 ->  동일한 구조를 갖는 영역이 여러 개라는 의미
    info_list = soup.select(".info")
    # print("%d 페이지의 상품 수: %d" % (page, len(info_list)) )
    
    # 3) 현제 페이지에서 추출된 상품 정보의 수 만큼 반복
    for info in info_list:
        #  하나의 삳품 정보를 보관할 디셔너리 
        item_dict = {}
        
        # 3-1) 상품명 추출
        # -> class 이름으로 상품명 영역 추출
        title_list = info.select('.tit')
        # -> 상품명은 하나만 존재하므로 0번째에 직접 접근하여 텍스트 추출
        item_dict['제품명'] = title_list[0].text.strip()
        
        # 3-2) 가격 추출
        # -> class 이름으로 가격 영역 추출
        price_list = info.select('.num')
        # 가격은 하나만 존재하므로 0번째에 직접 접근하여 텍스트 추출
        price = price_list[0].text.strip()
        # -> 상품가격에 포함된 콤마를 빈 분자열로 변경
        price = price.replace(",","")
        # -> 정수형으로 변환된 결과를 빈 딕셔너리에 추가 
        item_dict['가격'] = int(price)
        
        # 3-3) 스팩 정보 추출
        # a 태그의 경우 한단계 위에서 찾기 
        spec_list = info.select('.detail > a')
        
        # -> 제품별로 스팩항목이 여러개 이므로 추출된 결과만큼 반복
        for v in spec_list :
            v = v.text.strip()         # 텍스트 추출
            tmp = v.split(":")         # 콜론으로 분리 ( ex:디스플레이 : 1920X1080 )
            
            if len(tmp) == 2 :         # 길이가 2라면 key와 value로 분리하여 딕셔너리에 추가 
                key = tmp[0].strip()
                value = tmp[1].strip()
                item_dict[key] = value
        
        # 3-4) 리스트에 추가
        data_list.append(item_dict)
         
            
data_list
# Out:
# [{'제품명': '파나소닉 루믹스 DC-S1H',
#   '가격': 6069990,
#   '용도별': '전문가용',
#   '유효화소': '2420만화소',
#   'ISO': '100~51200',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': '6K',
#   '저장매체': 'SD',
#   '프레임': '24프레임',
#   '특징': '스위블(회전)',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당6장',
#   '손떨림보정': '바디',
#   '화면크기': '3.2인치(8.1cm)',
#   '화면화소': '233만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   '확장': '50~204800',
#   '메모리카드': '듀얼슬롯',
#   '최대촬영': '약400장(사진)',
#   '부피': '1,894cc',
#   '이미지센서 부가기능': '로우패스필터제거',
#   '무게(배터리제외)': '1052g',
#   '무게': '1164g',
#   '인터페이스': 'HDMI',
#   '부가기능': '방진방적',
#   '품목': '미러리스',
#   '뷰파인더 형태': '내장뷰파인더'},
#  {'제품명': '후지필름 XF10',
#   '가격': 482160,
#   '최소셔터스피드': '1/4000초',
#   '최대조리개': 'F2.8',
#   'ISO': 'ISO 51200',
#   '최대연속촬영속도': '초당6매',
#   '저장매체': 'SD',
#   '부가기능': '얼굴인식AF'},
#  {'제품명': '후지필름 X-A7',
#   '가격': 839990,
#   '용도별': '입문자용',
#   '유효화소': '2420만화소',
#   'ISO': '200~12800',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '특징': '스위블(회전)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당6장',
#   '초점방식': '위상차AF',
#   '초점영역': '256개',
#   '플래시': '팝업플래시',
#   '화면크기': '3.5인치(8.8cm)',
#   '화면화소': '276만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': '블루투스',
#   '촬영기능': '필름시뮬레이션',
#   '확장': '100~51200',
#   '최대촬영': '약270장(사진),약55분(동영상)',
#   '이미지센서 부가기능': '초음파방진필터',
#   '무게(배터리제외)': '271g',
#   '무게': '320g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스'},
#  {'제품명': '후지필름 X-T200',
#   '가격': 943040,
#   '용도별': '중급자용',
#   '유효화소': '2420만화소',
#   'ISO': '200~12800',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '특징': '틸트+플립(셀카)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당8장',
#   '초점영역': '225개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3.5인치(8.8cm)',
#   '화면화소': '276만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': '블루투스',
#   '촬영기능': '필름시뮬레이션',
#   '확장': '100~51200',
#   '동영상부가기능': '전자식IS',
#   '최대촬영': '약270장(사진),약55분(동영상)',
#   '부피': '559cc',
#   '이미지센서 부가기능': '초음파방진필터',
#   '무게(배터리제외)': '321g',
#   '무게': '370g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '캐논 EOS M50',
#   '가격': 622420,
#   '용도별': '중급자용',
#   '유효화소': '2410만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/4000초',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '10매',
#   '동영상프레임': '24프레임',
#   '저장매체': 'SD',
#   '프레임': '24프레임',
#   '특징': '스위블(회전)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당10장',
#   '초점방식': '듀얼픽셀AF',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': '블루투스4.1',
#   '스마트': '무선전송(WiFi)',
#   'AF기능': '터치&드래그',
#   '촬영기능': '필터효과',
#   '확장': '51200',
#   '화질엔진': 'DIGIC 8',
#   '메모리카드': 'UHS-I호환',
#   '동영상AF': '동영상서보AF',
#   '동영상부가기능': '전자식IS',
#   '최대촬영': '약235장(사진),85분(동영상)',
#   '두께': '5.9cm',
#   '무게': '387g',
#   '인터페이스': 'HDMI',
#   '부가기능': '먼지제거',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더'},
#  {'제품명': '캐논 EOS M100',
#   '가격': 404380,
#   '용도별': '입문자용',
#   '유효화소': '2420만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '초당6.1매',
#   '동영상프레임': '60프레임',
#   '저장매체': 'SD',
#   '프레임': '60프레임',
#   '특징': '플립(셀카)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당6.1장',
#   '초점방식': '듀얼픽셀AF',
#   '초점영역': '49개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': '블루투스4.1',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': 'HDR',
#   '화질엔진': 'DIGIC 7',
#   '메모리카드': 'UHS-I호환',
#   '동영상부가기능': '전자식IS',
#   '최대촬영': '약410장(사진),약125분(동영상)',
#   '두께': '3.5cm',
#   '부피': '253cc',
#   '무게': '302g',
#   '인터페이스': 'HDMI',
#   '부가기능': '색수차보정',
#   '품목': '미러리스'},
#  {'제품명': '소니 알파 A6400',
#   '가격': 839000,
#   '용도별': '입문자용',
#   '유효화소': '2420만화소',
#   'ISO': '100~32000',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '30프레임',
#   '디지털줌': '8배',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당11장',
#   '초점방식': '하이브리드AF',
#   '초점영역': '425개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '92만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': '블루투스',
#   '스마트': '무선전송',
#   'AF기능': 'EyeAF',
#   '확장': '100~102400',
#   '화질엔진': 'Bionz X',
#   '메모리카드': '듀얼슬롯',
#   '동영상부가기능': '타임랩스',
#   '최대촬영': '약410장(사진),약75분(동영상)',
#   '무게': '403g',
#   '인터페이스': 'HDMI',
#   '부가기능': '스마일셔터',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더'},
#  {'제품명': '소니 알파 A6000',
#   '가격': 410820,
#   '용도별': '중급자용',
#   '유효화소': '2430만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/4000초',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '11매',
#   '동영상프레임': '60프레임',
#   '저장매체': 'SD',
#   '프레임': '60프레임',
#   '디지털줌': '2배',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당11장',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '92만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': '파노라마',
#   '확장': '51200',
#   '화질엔진': 'Bionz X',
#   '최대촬영': '약360장(사진)',
#   '두께': '4.5cm',
#   '부피': '362cc',
#   '무게': '344g',
#   '인터페이스': 'HDMI',
#   '부가기능': '색수차보정',
#   '품목': '미러리스',
#   '뷰파인더 화소': '144만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '소니 알파 A5100',
#   '가격': 310090,
#   '용도별': '입문자용',
#   '유효화소': '2430만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'Full-HD',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '60프레임',
#   '디지털줌': '8배',
#   '특징': '플립(셀카)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당6장',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '92만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': 'HDR',
#   '화질엔진': 'Bionz X',
#   '메모리카드': 'UHS-I호환',
#   '최대촬영': '약400장(사진),약75분(동영상)',
#   '두께': '3.6cm',
#   '부피': '249cc',
#   '무게': '283g',
#   '인터페이스': 'HDMI',
#   '부가기능': '색수차보정',
#   '품목': '미러리스'},
#  {'제품명': '소니 DSC-W830',
#   '가격': 210000,
#   '최소셔터스피드': '1/1600초',
#   '디지털줌': '4배',
#   '최대조리개': 'F3.3',
#   'ISO': 'ISO 3200',
#   '최대연속촬영속도': '1매',
#   '저장매체': 'SD',
#   '부가기능': '손떨림방지'},
#  {'제품명': '캐논 EOS 200D',
#   '가격': 489400,
#   '유효화소수': '2420만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '부가기능': '얼굴인식',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '25600',
#   '초점영역': '9개',
#   '연사': '초당5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '초당5매',
#   '촬영기능': '역광보정',
#   '스마트': '블루투스',
#   '내장플래시': '팝업플래시',
#   '프레임': '60프레임',
#   '방식': '광학식',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '듀얼픽셀AF',
#   '화질엔진': 'DIGIC7',
#   '먼지제거': '가능',
#   '저장매체': 'SDHC',
#   '최대촬영': '약650장',
#   '부피': '794cc'},
#  {'제품명': '캐논 PowerShot G7X Mark 2',
#   '가격': 659640,
#   '디지털줌': '4배',
#   '최대조리개': 'F1.8',
#   'ISO': 'ISO 12800',
#   '최대연속촬영속도': '8매',
#   '저장매체': 'SD',
#   '부가기능': '손떨림방지'},
#  {'제품명': '소니 알파 A7 III',
#   '가격': 2008510,
#   '용도별': '전문가용',
#   '유효화소': '2420만화소',
#   'ISO': '100~51200',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당10장',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '바디(5축)',
#   '플래시': '플래시없음',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '92만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   'AF기능': '눈동자검출',
#   '확장': '50~204800',
#   '화질엔진': 'Bionz X',
#   '1회기록시간': '약29분',
#   '메모리카드': '듀얼슬롯',
#   '동영상부가기능': '타임코드',
#   '최대촬영': '약710장(사진),약125분(동영상)',
#   '두께': '6.3cm',
#   '부피': '768cc',
#   '무게': '650g',
#   '인터페이스': 'HDMI',
#   '부가기능': '이면조사',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '캐논 EOS 80D',
#   '가격': 742600,
#   '유효화소수': '2420만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '8000초',
#   '종류': 'DSLR',
#   '부가기능': '손떨림방지',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '25600',
#   '초점영역': '45개',
#   '연사': '초당7장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '7매',
#   '촬영기능': '역광보정',
#   '스마트': 'NFC',
#   '내장플래시': '팝업플래시',
#   '프레임': '60프레임',
#   '방식': '광학식',
#   '시야율': '100%시야율',
#   '스피드': '셔터(1/8000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '듀얼픽셀AF',
#   '화질엔진': 'DIGIC6',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '최대촬영': '약960장',
#   '부피': '1153cc',
#   '무게': '730g'},
#  {'제품명': '캐논 EOS 600D',
#   '가격': 212430,
#   '용도별': '입문자용',
#   '유효화소수': '1800만화소',
#   'ISO': '100~6400',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '부가기능': '얼굴인식',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '12800',
#   '초점영역': '9개',
#   '연사': '초당3.7장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '3.7매',
#   '촬영기능': '역광보정',
#   '내장플래시': '팝업플래시',
#   '기능': '동영상촬영불가',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '형태': '회전',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '라이브뷰,얼굴인식',
#   '화질엔진': 'DIGIC4',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약100분(동영상)',
#   '재질': '플라스틱',
#   '부피': '1040cc',
#   '무게': '570g',
#   '파일형식': 'MOV'},
#  {'제품명': '소니 알파 A6100',
#   '가격': 699490,
#   '용도별': '입문자용',
#   '유효화소': '2420만화소',
#   'ISO': '100~32000',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당11장',
#   '초점방식': '하이브리드AF',
#   '초점영역': '425개',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '92만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   'AF기능': 'EyeAF',
#   '확장': '51200',
#   '최대촬영': '약420장(사진),약75분(동영상)',
#   '무게(배터리제외)': '352g',
#   '무게': '396g',
#   '인터페이스': 'HDMI',
#   '부가기능': '스마일셔터',
#   '품목': '미러리스',
#   '뷰파인더 화소': '144만화소',
#   '뷰파인더 형태': '내장뷰파인더'},
#  {'제품명': '캐논 G7X Mark III',
#   '가격': 817980,
#   '유효화소': '2010만화소',
#   '동영상 해상도': 'UHD(4K)',
#   '화면': '3인치',
#   '접사거리': '5cm',
#   'ISO': 'ISO 12800',
#   '무게': '304g',
#   '저장매체': 'SDHC',
#   '부가기능': '적층형',
#   '단자': 'HDMI출력',
#   '동영상 프레임': '30프레임',
#   '두께': '4.14cm',
#   '부피': '236cc',
#   '블루투스': '블루투스4.2',
#   '품목': '하이엔드디카',
#   'CMOS': '1인치',
#   '스피드': '셔터(1/2000초)',
#   '스마트': '무선전송(WiFi)',
#   '화면특징': '터치',
#   '화질엔진': 'DIGIC8',
#   '확장 ISO': '25600',
#   '플래시': '플래시내장',
#   '충전': 'USB충전',
#   '광각범위': '24mm',
#   '손떨림기능': '광학식손떨림보정',
#   '셀카': '셀카가능',
#   '동영상부가기능': '타임랩스',
#   '줌배율': '4.2배줌',
#   '최대촬영': '약235장(사진)',
#   '밝기': 'F1.8',
#   '셀카액정기능': '틸트+플립'},
#  {'제품명': '캐논 EOS 800D',
#   '가격': 679900,
#   '유효화소수': '2420만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '부가기능': '전자수평계',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '51200',
#   '초점영역': '45개',
#   '연사': '초당6장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '초당6매',
#   '촬영기능': '역광보정',
#   '스마트': '블루투스',
#   '내장플래시': '팝업플래시',
#   '프레임': '60프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '듀얼픽셀AF',
#   '화질엔진': 'DIGIC7',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '최대촬영': '약600장',
#   '부피': '996cc'},
#  {'제품명': '소니 알파 A5000',
#   '가격': 243600,
#   '용도별': '입문자용',
#   '유효화소': '2010만화소',
#   'ISO': '100~16000',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '2.5매',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '60프레임',
#   '디지털줌': '8배',
#   '특징': '플립(셀카)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당3.5장',
#   '초점영역': '25개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '46만화소',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': 'HDR',
#   '화질엔진': 'Bionz X',
#   '메모리카드': 'UHS-I호환',
#   '최대촬영': '약420장',
#   '두께': '3.6cm',
#   '부피': '249cc',
#   '무게': '269g',
#   '인터페이스': 'HDMI',
#   '부가기능': '색수차보정',
#   '품목': '미러리스'},
#  {'제품명': '니콘 쿨픽스 A100',
#   '가격': 175000,
#   '최소셔터스피드': '1/2000초',
#   '디지털줌': '4배',
#   '최대조리개': 'F3.2',
#   'ISO': 'ISO 3200',
#   '저장매체': 'SD',
#   '부가기능': '손떨림방지'},
#  {'제품명': '캐논 EOS 5D Mark III',
#   '가격': 846750,
#   '용도별': '전문가용',
#   '유효화소수': '2230만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/8000초',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '뷰파인더': '뷰파인더',
#   '화면': '3.2인치(8.1cm)',
#   '확장ISO': '50~102400',
#   '초점영역': '61개',
#   '연사': '초당6장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '6매',
#   '촬영기능': '역광보정',
#   '내장플래시': '플래시없음',
#   '용량': '용량제한없음',
#   '기능': 'AF미세조정',
#   '프레임': '30프레임',
#   '방식': '광학식',
#   '시야율': '100%시야율',
#   '스피드': '셔터(1/8000초)',
#   '손떨림보정': '렌즈(별매)',
#   '영상출력': 'HDMI출력',
#   '파일형식': 'sRAW지원',
#   '라이브뷰': '라이브뷰,얼굴인식',
#   '화질엔진': 'DIGIC5+',
#   '먼지제거': '가능',
#   '저장매체': 'CF',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약950장',
#   '재질': '마그네슘',
#   '부피': '1300cc',
#   '무게': '950g',
#   '출시가': '3,500,000원'},
#  {'제품명': '정품 후지필름 X-H1 바디 (64GB메모리+청소도구)', '가격': 1190000},
#  {'제품명': '캐논 EOS 200D II',
#   '가격': 663200,
#   '용도별': '입문자용',
#   '유효화소수': '2420만화소',
#   'ISO': '100~25600',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '부가기능': '렌즈수차보정',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '51200',
#   '초점영역': '9개',
#   '연사': '초당5장',
#   '동영상 해상도': 'UHD(4K)',
#   '촬영기능': 'CA모드',
#   '스마트': '블루투스',
#   '내장플래시': '팝업플래시',
#   '프레임': '24프레임',
#   '방식': '광학식',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '형태': '회전',
#   '라이브뷰': '듀얼픽셀AF',
#   '먼지제거': '가능',
#   '저장매체': 'SDHC',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약110분(동영상)',
#   '부피': '794cc'},
#  {'제품명': '소니 미러리스 알파 A6000 L (SELP1650 킷)+SEL50F18', '가격': 1004860},
#  {'제품명': '캐논 EOS M3',
#   '가격': 258500,
#   '용도별': '중급자용',
#   '유효화소': '2420만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '초당4.2매',
#   '동영상프레임': '29.97프레임',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '특징': '플립(셀카)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당4.2장',
#   '초점방식': '하이브리드AF',
#   '초점영역': '49개',
#   '손떨림보정': '렌즈(별매)',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '확장': '100~25600',
#   '화질엔진': 'DIGIC 6',
#   '메모리카드': 'UHS-I호환',
#   '최대촬영': '약250장',
#   '두께': '4.5cm',
#   '부피': '340cc',
#   '무게': '366g',
#   '인터페이스': 'HDMI',
#   '부가기능': '색수차보정',
#   '품목': '미러리스'},
#  {'제품명': '캐논 EOS 6D Mark II',
#   '가격': 1540300,
#   '용도별': '중급자용',
#   '유효화소수': '2620만화소',
#   'ISO': '100~40000',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '50~102400',
#   '초점영역': '45개',
#   '연사': '초당6.5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '초당6.5매',
#   '촬영기능': '역광보정',
#   '스마트': '블루투스',
#   '내장플래시': '플래시없음',
#   '기능': 'AF미세조정',
#   '프레임': '60프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '영상출력': 'HDMI출력',
#   '파일형식': 'MP4',
#   '라이브뷰': '듀얼픽셀AF',
#   '화질엔진': 'DIGIC7',
#   '먼지제거': '가능',
#   '저장매체': 'SDHC',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약160분(동영상)',
#   '부피': '1188cc',
#   '무게': '765g',
#   '동영상부가기능': '전자식IS',
#   '출시가': '2,295,000원'},
#  {'제품명': '캐논 EOS 750D',
#   '가격': 288700,
#   '유효화소수': '2420만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '부가기능': '얼굴인식',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '25600',
#   '초점영역': '19개',
#   '연사': '초당5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '초당5매',
#   '촬영기능': '역광보정',
#   '스마트': 'NFC',
#   '내장플래시': '팝업플래시',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '하이브리드AFIII',
#   '화질엔진': 'DIGIC6',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '최대촬영': '약440장',
#   '부피': '1030cc'},
#  {'제품명': '캐논 익서스 IXUS 185', '가격': 179990},
#  {'제품명': '소니 DSC-W810',
#   '가격': 148000,
#   '최소셔터스피드': '1/1500초',
#   '디지털줌': '4배',
#   '최대조리개': 'F3.5',
#   'ISO': 'ISO 3200',
#   '최대연속촬영속도': '1매',
#   '저장매체': 'SD',
#   '부가기능': '손떨림방지'},
#  {'제품명': '캐논 EOS 70D',
#   '가격': 400600,
#   '용도별': '중급자용',
#   '유효화소수': '2020만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/8000초',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '부가기능': '전자수평계',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '25600',
#   '초점영역': '19개',
#   '연사': '초당7장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '7매',
#   '촬영기능': '역광보정',
#   '스마트': '무선전송(WiFi)',
#   '내장플래시': '팝업플래시',
#   '용량': '용량제한없음',
#   '기능': 'AF미세조정',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/8000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '형태': '회전',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '듀얼픽셀AF',
#   '화질엔진': 'DIGIC5+',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약80분(동영상)',
#   '재질': '플라스틱',
#   '부피': '1142cc',
#   '무게': '755g',
#   '파일형식': 'MOV',
#   '동영상부가기능': '타임코드'},
#  {'제품명': '캐논 EOS 100D',
#   '가격': 211000,
#   '용도별': '입문자용',
#   '유효화소수': '1800만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '부가기능': '벌브지원',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '25600',
#   '초점영역': '9개',
#   '연사': '초당4장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '4매',
#   '촬영기능': '역광보정',
#   '내장플래시': '팝업플래시',
#   '용량': '용량제한없음',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '하이브리드AFII',
#   '화질엔진': 'DIGIC5',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약100분(동영상)',
#   '재질': '플라스틱',
#   '부피': '735cc',
#   '무게': '407g',
#   '파일형식': 'MOV'},
#  {'제품명': '니콘 D750',
#   '가격': 899880,
#   '용도별': '중급자용',
#   '유효화소수': '2432만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면화소': '122만화소',
#   '뷰파인더': '뷰파인더',
#   '화면': '3.2인치(8.1cm)',
#   '확장ISO': '50~51200',
#   '초점영역': '51개',
#   '연사': '초당6.5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '초당6.5매',
#   '촬영기능': '역광보정',
#   '내장플래시': '팝업플래시',
#   '기능': 'AF미세조정',
#   '프레임': '60프레임',
#   '방식': '광학식',
#   '시야율': '100%시야율',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '형태': '틸트',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '라이브뷰',
#   '화질엔진': 'EXPEED4',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약55분(동영상)',
#   '부피': '1243cc',
#   '무게': '840g',
#   '1회기록시간': '29분59초',
#   '파일형식': 'MOV',
#   '동영상부가기능': '타임랩스',
#   '출시가': '2,080,000원'},
#  {'제품명': '니콘 D5600',
#   '가격': 479420,
#   '용도별': '입문자용',
#   '유효화소수': '2416만화소',
#   'ISO': '100~25600',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '부가기능': '얼굴인식',
#   '뷰파인더': '뷰파인더',
#   '화면': '3.2인치(8.1cm)',
#   '초점영역': '39개',
#   '연사': '초당5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '5매',
#   '촬영기능': '역광보정',
#   '특징': '로우패스필터제거',
#   '스마트': '블루투스',
#   '내장플래시': '팝업플래시',
#   '프레임': '60프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '형태': '회전',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '라이브뷰',
#   '화질엔진': 'EXPEED4',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약70분(동영상)',
#   '부피': '842cc',
#   '무게': '465g',
#   '1회기록시간': '29분59초',
#   '파일형식': 'MOV',
#   '동영상부가기능': '타임랩스',
#   '출시가': '1,048,000원'},
#  {'제품명': '소니 알파 A7 lll',
#   '가격': 2017000,
#   '최소셔터스피드': '1/8000초',
#   '최대연속촬영속도': '초당10매',
#   '동영상프레임': '30프레임',
#   '저장매체': '메모리스틱ProDuo',
#   '품목': '미러리스'},
#  {'제품명': '캐논 EOS 100D 화이트',
#   '가격': 227400,
#   '용도별': '입문자용',
#   '유효화소수': '1800만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '부가기능': '얼굴인식',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '25600',
#   '초점영역': '9개',
#   '연사': '초당4장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '4매',
#   '촬영기능': '역광보정',
#   '내장플래시': '팝업플래시',
#   '용량': '용량제한없음',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '하이브리드AFII',
#   '화질엔진': 'DIGIC5',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약100분(동영상)',
#   '재질': '플라스틱',
#   '부피': '735cc',
#   '무게': '410g',
#   '파일형식': 'MOV'},
#  {'제품명': '씽크리브 키즈 디지털카메라 타이니샷(TL-KC01)',
#   '가격': 44750,
#   '유효화소': '1800만화소',
#   '동영상 해상도': 'Full-HD',
#   '디지털줌': '3배',
#   '화면': '2"',
#   '저장매체': 'MICRO SDHC',
#   '품목': '일반디카',
#   '플래시': '플래시내장',
#   '사진효과': '필터효과'},
#  {'제품명': '니콘 Z6',
#   '가격': 1817020,
#   '용도별': '전문가용',
#   '유효화소': '2450만',
#   'ISO': '100~51200',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '12매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'XQD메모리',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당12장',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '바디(5축)',
#   '플래시': '플래시없음',
#   '화면크기': '3.2인치(8.1cm)',
#   '화면화소': '210만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   '확장': '50~204800',
#   '화질엔진': 'EXPEED6',
#   '1회기록시간': '약29분',
#   '동영상부가기능': '전자식IS',
#   '최대촬영': '약310장(사진),약85분(동영상)',
#   '두께': '6.75cm',
#   '부피': '909cc',
#   '이미지센서 부가기능': '로우패스필터제거',
#   '무게(배터리제외)': '585g',
#   '무게': '675g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스',
#   '뷰파인더 화소': '369만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '캐논 EOS 700D',
#   '가격': 212860,
#   '용도별': '입문자용',
#   '유효화소수': '1800만화소',
#   'ISO': '100~6400',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '부가기능': '벌브지원',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '12800',
#   '초점영역': '9개',
#   '연사': '초당5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '5매',
#   '촬영기능': '역광보정',
#   '내장플래시': '팝업플래시',
#   '용량': '용량제한없음',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '형태': '회전',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '하이브리드AF',
#   '화질엔진': 'DIGIC5',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약100분(동영상)',
#   '재질': '플라스틱',
#   '부피': '1051cc',
#   '무게': '580g',
#   '파일형식': 'MOV'},
#  {'제품명': '후지필름 X100V',
#   '가격': 1699000,
#   '유효화소': '2430만화소',
#   '동영상 해상도': 'UHD(4K)',
#   '화면': '3"',
#   '접사거리': '10cm',
#   'ISO': 'ISO 12800',
#   '무게': '478g',
#   '단자': 'USB-C',
#   '동영상 프레임': '30프레임',
#   '두께': '5.3cm',
#   '부피': '509cc',
#   '품목': '하이엔드디카',
#   'CMOS': 'APS-C',
#   '스피드': '셔터(1/4000초)',
#   '화면특징': '터치',
#   '연사': '초당11장',
#   '초점거리': '23mm',
#   '방식': '뷰파인더(광학식+전자식)',
#   '확장 ISO': '51200',
#   '밝기': 'F2'},
#  {'제품명': '소니 알파 A7 II',
#   '가격': 1051360,
#   '용도별': '전문가용',
#   '유효화소': '2430만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/8000초',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'Full-HD',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '60프레임',
#   '디지털줌': '8배',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당5장',
#   '재질': '마그네슘',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '바디(5축)',
#   '플래시': '플래시없음',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '123만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': '파노라마',
#   '확장': '50~25600',
#   '화질엔진': 'Bionz X',
#   '1회기록시간': '약29분',
#   '메모리카드': 'UHS-I호환',
#   '동영상부가기능': '타임코드',
#   '최대촬영': '약350장(사진),약65분(동영상)',
#   '두께': '6cm',
#   '부피': '732cc',
#   '무게': '599g',
#   '인터페이스': 'HDMI',
#   '부가기능': '색수차보정',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '삼성전자 삼성 NX2000',
#   '가격': 152400,
#   '유효화소': '2030만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '8매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당8장',
#   '초점영역': '21개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '외장플래시포함',
#   '화면크기': '3.7인치(9.3cm)',
#   '화면화소': '115.2만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': '3D사진(렌즈별매)',
#   '화질엔진': 'DRIMe Ⅳ',
#   '최대촬영': '약340장',
#   '두께': '3.6cm',
#   '부피': '278cc',
#   '무게': '274.8g',
#   '부가기능': 'iFn렌즈',
#   '품목': '미러리스'},
#  {'제품명': '[SONY] 카메라 렌즈 모음전 소니정품모음점', '가격': 2039840},
#  {'제품명': '캐논 EOS 5D Mark IV',
#   '가격': 2845600,
#   '유효화소수': '3040만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '8000초',
#   '종류': 'DSLR',
#   '화면': '3.2인치(8.1cm)',
#   '확장ISO': '50~102400',
#   '초점영역': '61개',
#   '연사': '초당7장',
#   '동영상 해상도': 'UHD(4K)',
#   'EISA 어워드': 'EISA 어워드',
#   '최대연속촬영속도': '7매',
#   '촬영기능': '역광보정',
#   '스마트': 'NFC',
#   '내장플래시': '플래시없음',
#   '기능': 'AF미세조정',
#   '프레임': '30프레임',
#   '방식': '광학식',
#   '시야율': '100%시야율',
#   '스피드': '셔터(1/8000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '영상출력': 'HDMI출력',
#   '파일형식': 'sRAW지원',
#   '라이브뷰': '듀얼픽셀AF',
#   '화질엔진': 'DIGIC6+',
#   '먼지제거': '가능',
#   '저장매체': 'CF',
#   '인터페이스': 'USB3.0',
#   '최대촬영': '약900장',
#   '부피': '1331cc',
#   '무게': '890g'},
#  {'제품명': '(4종 사은품) 정품 후지필름 X-T3 바디', '가격': 1798620},
#  {'제품명': '후지필름 X-T100',
#   '가격': 489730,
#   '용도별': '입문자용',
#   '유효화소': '2420만화소',
#   'ISO': '200~12800',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '초당6매',
#   '동영상프레임': '15프레임',
#   '저장매체': 'SD',
#   '프레임': '15프레임',
#   '특징': '셀카',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당6장',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': '블루투스4.1',
#   '스마트': '무선전송',
#   '촬영기능': '다이나믹레인지',
#   '확장': '100~51200',
#   '메모리카드': 'UHS-I호환',
#   '최대촬영': '약430장',
#   '두께': '3.3cm',
#   '부피': '452cc',
#   '무게(배터리제외)': '399g',
#   '무게': '448g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '씽크리브 키즈 디지털카메라 타이니샷(TL-KC01)',
#   '가격': 44750,
#   '유효화소': '1800만화소',
#   '동영상 해상도': 'Full-HD',
#   '디지털줌': '3배',
#   '화면': '2"',
#   '저장매체': 'MICRO SDHC',
#   '품목': '일반디카',
#   '플래시': '플래시내장',
#   '사진효과': '필터효과'},
#  {'제품명': '후지필름 XP140',
#   '가격': 255030,
#   '유효화소': '1640만화소',
#   '동영상 해상도': 'UHD(4K)',
#   '화면': '3인치',
#   '광학줌': '5배줌',
#   '접사거리': '9cm',
#   'ISO': 'ISO 12800',
#   '무게': '207.4g',
#   '저장매체': 'SDHC',
#   '단자': 'HDMI출력',
#   '동영상 프레임': '15프레임',
#   '두께': '2.78cm',
#   '방수시간': '최대120분',
#   '부피': '217cc',
#   '블루투스': '블루투스4.1',
#   '품목': '일반디카',
#   'CMOS': '0.43인치(1/2.3)',
#   '스피드': '셔터(1/2000초)',
#   '스마트': '무선전송(WiFi)',
#   '연사': '초당10장',
#   '초점거리': '28mm',
#   '충격흡수': '1.8m',
#   '플래시': '플래시내장',
#   '손떨림기능': '손떨림보정',
#   '줌배율': '5배줌',
#   '방수': '방수겸용',
#   '방수수심': '20m',
#   '밝기': 'F3.9'},
#  {'제품명': '후지필름 X-T30',
#   '가격': 1001890,
#   '용도별': '전문가용',
#   '유효화소': '2610만화소',
#   'ISO': '160~12800',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '8매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당8장',
#   '초점방식': '하이브리드AF',
#   '초점영역': '91개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   'AF기능': '동체추적AF',
#   '촬영기능': '인터벌촬영(타임랩스)',
#   '확장': '80~25600',
#   '화질엔진': 'X Processor 4',
#   '메모리카드': 'UHS-I호환',
#   '최대촬영': '약380장(사진),약45분(동영상)',
#   '두께': '4.7cm',
#   '부피': '460c',
#   '이미지센서 부가기능': '로우패스필터제거',
#   '무게(배터리제외)': '333g',
#   '무게': '383g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '캐논 EOS 90D',
#   '가격': 1411900,
#   '용도별': '중급자용',
#   '유효화소수': '3250만화소',
#   'ISO': '100~25600',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '부가기능': '렌즈수차보정',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '51200',
#   '초점영역': '45개',
#   '연사': '초당10장',
#   '동영상 해상도': 'UHD(4K)',
#   '촬영기능': '아트필터',
#   '스마트': '블루투스',
#   '내장플래시': '팝업플래시',
#   '기능': 'AF미세조정',
#   '프레임': '30프레임',
#   '방식': '광학식',
#   '시야율': '100%시야율',
#   '스피드': '셔터(1/8000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '형태': '회전',
#   '영상출력': 'HDMI출력',
#   '파일형식': 'MP4',
#   '라이브뷰': '듀얼픽셀AF',
#   '화질엔진': 'DIGIC8',
#   '먼지제거': '가능',
#   '저장매체': 'SDHC',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약210분(동영상)',
#   '부피': '1140cc',
#   '무게': '701g',
#   '동영상부가기능': '전자식IS',
#   '출시가': '1,549,000원'},
#  {'제품명': '트니트니 어린이 키즈 디지털 카메라 2600만화소 KC인증 당일출고', '가격': 49000, '디지털줌': '3배'},
#  {'제품명': '캐논 EOS 6D',
#   '가격': 383000,
#   '유효화소수': '2020만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '50~102400',
#   '초점영역': '11개',
#   '연사': '초당4.5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '4.5매',
#   '촬영기능': '역광보정',
#   '스마트': '무선전송(WiFi)',
#   '내장플래시': '플래시없음',
#   '용량': '용량제한없음',
#   '기능': 'AF미세조정',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '영상출력': 'HDMI출력',
#   '파일형식': 'sRAW지원',
#   '라이브뷰': '라이브뷰,얼굴인식',
#   '화질엔진': 'DIGIC5+',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '최대촬영': '약1090장',
#   '재질': '마그네슘',
#   '부피': '1132cc',
#   '무게': '755g'},
#  {'제품명': '리코 GR III',
#   '가격': 1091830,
#   '유효화소': '2424만화소',
#   '동영상 해상도': 'Full-HD',
#   '화면': '3인치',
#   '접사거리': '6cm',
#   '무게': '257g',
#   '저장매체': 'SDHC',
#   '내장메모리': '2G내장',
#   '단자': 'USB-C',
#   '동영상 프레임': '60프레임',
#   '두께': '3.32cm',
#   '부피': '224cc',
#   '품목': '하이엔드디카',
#   'CMOS': 'APS-C',
#   '화면특징': '터치',
#   '초점거리': '28mm',
#   '손떨림기능': '손떨림보정',
#   '밝기': 'F2.8'},
#  {'제품명': '니콘 쿨픽스 P1000',
#   '가격': 899970,
#   '유효화소': '1605만화소',
#   '동영상 해상도': 'UHD(4K)',
#   '화면': '3.2인치',
#   'ISO': 'ISO 6400',
#   '저장매체': 'SDHC',
#   '단자': 'HDMI출력',
#   '동영상 프레임': '30프레임',
#   '두께': '18.13cm',
#   '부피': '3,150cc',
#   '블루투스': '블루투스 가능',
#   '품목': '하이엔드디카',
#   'CMOS': '0.43인치(1/2.3)',
#   '스피드': '셔터(1/4000초)',
#   '스마트': '무선전송(WiFi)',
#   '초점거리': '24mm',
#   '방식': '뷰파인더(전자식)',
#   '손떨림기능': '손떨림보정',
#   '셀카': '셀카가능',
#   '줌배율': '125배줌',
#   '밝기': 'F2.8',
#   '셀카액정기능': '회전'},
#  {'제품명': '삼성전자 삼성 NX300M',
#   '가격': 174880,
#   '유효화소': '2030만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/6000초',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '8.6매',
#   '동영상프레임': '60프레임',
#   '저장매체': 'SD',
#   '프레임': '60프레임',
#   '특징': '틸트+플립(셀카)',
#   '스피드': '셔터(1/6000초)',
#   '연사': '초당8.6장',
#   '초점방식': '하이브리드AF',
#   '초점영역': '247+105개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '외장플래시포함',
#   '화면크기': '3.31인치(8.4cm)AM-OLED',
#   '화면화소': '76.8만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi,듀얼밴드)',
#   '촬영기능': '3D사진(렌즈별매)',
#   '내장메모리': '16G포함',
#   '최대촬영': '약330장',
#   '두께': '4.3cm',
#   '부피': '332cc',
#   '무게(배터리제외)': '310g',
#   '인터페이스': 'HDMI',
#   '부가기능': '먼지제거',
#   '품목': '미러리스'},
#  {'제품명': '파나소닉 루믹스 DMC-LX10',
#   '가격': 514270,
#   '최대조리개': 'F1.4',
#   'ISO': 'ISO 12800',
#   '최대연속촬영속도': '10매',
#   '부가기능': '손떨림방지'},
#  {'제품명': '캐논 EOS M10',
#   '가격': 263600,
#   '용도별': '입문자용',
#   '유효화소': '1800만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '4.6매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '특징': '플립(셀카)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당4.6장',
#   '초점방식': '하이브리드AF',
#   '초점영역': '49개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '확장': '100~25600',
#   '화질엔진': 'DIGIC 6',
#   '메모리카드': 'UHS-I호환',
#   '최대촬영': '약255장',
#   '두께': '3.5cm',
#   '부피': '258cc',
#   '무게': '301g',
#   '인터페이스': 'HDMI',
#   '부가기능': '색수차보정',
#   '품목': '미러리스'},
#  {'제품명': '소니 사이버샷 DSC-RX100 VII',
#   '가격': 1278750,
#   '유효화소': '2010만화소',
#   '동영상 해상도': 'UHD(4K)',
#   '화면': '3인치',
#   '접사거리': '8cm',
#   'ISO': 'ISO 12800',
#   '무게': '302g',
#   '저장매체': 'SDHC',
#   '부가기능': '적층형',
#   '단자': 'HDMI출력',
#   '동영상 프레임': '30프레임',
#   '두께': '4.28cm',
#   '렌즈': '칼자이스렌즈',
#   '부피': '253cc',
#   '블루투스': '블루투스4.1',
#   '품목': '하이엔드디카',
#   'CMOS': '1인치',
#   '스피드': '셔터(1/2000초)',
#   '스마트': '무선전송(WiFi)',
#   '화면특징': '터치',
#   '연사': '초당20장',
#   '초점거리': '24mm',
#   '화질엔진': 'Bionz X',
#   'AF종류': '하이브리드AF',
#   '무선기능': 'NFC',
#   '방식': '뷰파인더(전자식)',
#   '확장 ISO': '25600',
#   '플래시': '플래시내장',
#   '충전': 'USB충전',
#   '광각범위': '24mm',
#   '손떨림기능': '광학식손떨림보정',
#   '촬영모드': '수동모드',
#   '셀카': '셀카가능',
#   '줌배율': '8배줌',
#   '최대촬영': '약70분(동영상)',
#   '촬영기능': 'HDR',
#   '밝기': 'F2.8',
#   '셀카액정기능': '틸트+플립'},
#  {'제품명': '라이카 D-LUX 7',
#   '가격': 1613900,
#   '유효화소': '1700만화소',
#   '동영상 해상도': 'UHD(4K)',
#   '화면': '3인치',
#   '광학줌': '4배줌',
#   '접사거리': '3cm',
#   'ISO': 'ISO 25600',
#   '무게': '403g',
#   '최대연속촬영속도': '초당11매',
#   '저장매체': 'SDHC',
#   '부가기능': '손떨림방지',
#   '단자': 'HDMI출력',
#   '동영상 프레임': '30프레임',
#   '두께': '6.4cm',
#   '부피': '498cc',
#   '블루투스': '블루투스4.2',
#   '품목': '하이엔드디카',
#   '스피드': '셔터(1/4000초)',
#   '스마트': '무선전송(WiFi)',
#   '화면특징': '터치',
#   '연사': '초당11장',
#   '방식': '뷰파인더',
#   '광각범위': '24mm',
#   '손떨림기능': '광학식손떨림보정',
#   '줌배율': '4배줌',
#   '밝기': 'F1.7'},
#  {'제품명': '소니 알파 A6600',
#   '가격': 1644990,
#   '용도별': '중급자용',
#   '유효화소': '2420만화소',
#   'ISO': '100~32000',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당11장',
#   '초점방식': '하이브리드AF',
#   '초점영역': '425개',
#   '손떨림보정': '바디(5축)',
#   '플래시': '플래시없음',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '92만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   'AF기능': 'EyeAF',
#   '확장': '50~102400',
#   '화질엔진': 'Bionz X',
#   '메모리카드': 'UHS-I호환',
#   '동영상부가기능': '타임코드',
#   '최대촬영': '약810매(사진),약150분(동영상)',
#   '무게(배터리제외)': '418g',
#   '무게': '503g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더'},
#  {'제품명': '캐논 EOS M6',
#   '가격': 545660,
#   '용도별': '중급자용',
#   '유효화소': '2420만화소',
#   'ISO': '100~6400',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'Full-HD',
#   '저장매체': 'SD',
#   '프레임': '60프레임',
#   '특징': '틸트+플립(셀카)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당9장',
#   '초점방식': '듀얼픽셀AF',
#   '손떨림보정': '렌즈(별매)',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   '확장': '25600',
#   '화질엔진': 'DIGIC 7',
#   '1회기록시간': '약29분',
#   '메모리카드': 'UHS-I호환',
#   '동영상부가기능': '전자식IS',
#   '최대촬영': '약295장(사진),약85분(동영상)',
#   '두께': '4.5cm',
#   '부피': '343cc',
#   '무게': '390g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스'},
#  {'제품명': '캐논 EOS M6 Mark II',
#   '가격': 1172320,
#   '용도별': '중급자용',
#   '유효화소': '3250만화소',
#   'ISO': '100~25600',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당14장',
#   '초점방식': '듀얼픽셀AF',
#   '초점영역': '143개',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   'AF기능': '동체추적AF',
#   '확장': '51200',
#   '화질엔진': 'DIGIC 8',
#   '메모리카드': 'UHS-I호환',
#   '동영상AF': '동영상서보AF',
#   '동영상부가기능': '전자식IS',
#   '최대촬영': '약305장(사진),약80분(동영상)',
#   '부피': '412cc',
#   '이미지센서 부가기능': '로우패스필터제거',
#   '무게(배터리제외)': '361g',
#   '무게': '408g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스'},
#  {'제품명': '캐논 EOS 650D',
#   '가격': 166900,
#   '용도별': '입문자용',
#   '유효화소수': '1800만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '부가기능': '얼굴인식',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '25600',
#   '초점영역': '9개',
#   '연사': '초당5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '5매',
#   '촬영기능': '역광보정',
#   '내장플래시': '팝업플래시',
#   '기능': '동영상촬영불가',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '형태': '회전',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '하이브리드AF',
#   '화질엔진': 'DIGIC5',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약100분(동영상)',
#   '재질': '플라스틱',
#   '부피': '1040cc',
#   '무게': '575g',
#   '파일형식': 'MOV'},
#  {'제품명': '올림푸스 터프 TG-6',
#   '가격': 388800,
#   '유효화소': '1200만화소',
#   '동영상 해상도': 'UHD(4K)',
#   '화면': '3인치',
#   '광학줌': '4배줌',
#   '접사거리': '1cm',
#   'ISO': 'ISO 12800',
#   '무게': '253g',
#   '저장매체': 'SDHC',
#   '단자': 'HDMI출력',
#   '동영상 프레임': '30프레임',
#   '두께': '3.2cm',
#   'GPS': 'GPS내장',
#   '부피': '239cc',
#   '품목': '일반디카',
#   'CMOS': '0.43인치(1/2.3)',
#   '스피드': '셔터(1/2000초)',
#   '스마트': '무선전송(WiFi)',
#   '연사': '초당5장',
#   '충격흡수': '2.1m',
#   'AF종류': 'AF트래킹',
#   '줌종류': '이너줌',
#   '광각범위': '25mm',
#   '동영상부가기능': '타임랩스',
#   '줌배율': '4배줌',
#   '방수': '방수겸용',
#   '최대촬영': '약340장(사진),약110분(동영상)',
#   '방수수심': '15m',
#   '밝기': 'F2'},
#  {'제품명': '후지필름 X-T30',
#   '가격': 1001890,
#   '용도별': '전문가용',
#   '유효화소': '2610만화소',
#   'ISO': '160~12800',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '8매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당8장',
#   '초점방식': '하이브리드AF',
#   '초점영역': '91개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   'AF기능': '동체추적AF',
#   '촬영기능': '인터벌촬영(타임랩스)',
#   '확장': '80~25600',
#   '화질엔진': 'X Processor 4',
#   '메모리카드': 'UHS-I호환',
#   '최대촬영': '약380장(사진),약45분(동영상)',
#   '두께': '4.7cm',
#   '부피': '460c',
#   '이미지센서 부가기능': '로우패스필터제거',
#   '무게(배터리제외)': '333g',
#   '무게': '383g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '소니 알파 NEX-3N',
#   '가격': 117010,
#   '용도별': '입문자용',
#   '유효화소': '1610만화소',
#   'ISO': '200~16000',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '4매',
#   '동영상프레임': '30프레임',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '60프레임',
#   '디지털줌': '4배',
#   '특징': '플립(셀카)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당4장',
#   '재질': '플라스틱',
#   '초점영역': '25개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '46만화소',
#   '촬영기능': 'HDR',
#   '화질엔진': 'Bionz',
#   '최대촬영': '약480장',
#   '두께': '3.5cm',
#   '부피': '239cc',
#   '무게': '269g',
#   '인터페이스': 'HDMI',
#   '부가기능': 'USB충전',
#   '품목': '미러리스'},
#  {'제품명': '(4종 사은품) 정품 후지필름 X-T3 바디', '가격': 1798620},
#  {'제품명': '니콘 쿨픽스 W150',
#   '가격': 183000,
#   '유효화소': '1317만화소',
#   '동영상 해상도': 'Full-HD',
#   '화면': '2.7인치',
#   '광학줌': '3배줌',
#   'ISO': 'ISO 1600',
#   '무게': '177g',
#   '저장매체': 'SDHC',
#   '단자': 'HDMI출력',
#   '동영상 프레임': '30프레임',
#   '두께': '3.8cm',
#   '방수시간': '최대60분',
#   '부피': '280cc',
#   '블루투스': '블루투스4.1',
#   '품목': '일반디카',
#   'CMOS': '0.32인치(1/3.1)',
#   '스피드': '셔터(1/2000초)',
#   '스마트': '무선전송(WiFi)',
#   '충격흡수': '1.8m',
#   '플래시': '플래시내장',
#   '줌배율': '3배줌',
#   '방수': '방수겸용',
#   '방수수심': '10m',
#   '밝기': 'F3.3'},
#  {'제품명': '정품 후지필름 X-H1 바디 (64GB메모리+청소도구)', '가격': 1190000},
#  {'제품명': '니콘 D810',
#   '가격': 750790,
#   '용도별': '전문가용',
#   '유효화소수': '3635만화소',
#   'ISO': '64~12800',
#   '최소셔터스피드': '1/8000초',
#   '종류': 'DSLR',
#   '화면화소': '123만화소',
#   '부가기능': '손떨림방지',
#   '뷰파인더': '뷰파인더',
#   '화면': '3.2인치(8.1cm)',
#   '확장ISO': '32~51200',
#   '초점영역': '51개',
#   '연사': '초당5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '초당5매',
#   '특징': '로우패스필터제거',
#   '내장플래시': '팝업플래시',
#   '프레임': '60프레임',
#   '방식': '광학식',
#   '시야율': '100%시야율',
#   '스피드': '전자선막',
#   '영상출력': 'HDMI출력',
#   '파일형식': 'MOV',
#   '라이브뷰': '라이브뷰',
#   '화질엔진': 'EXPEED4',
#   '먼지제거': '가능',
#   '저장매체': 'CF',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약40분(동영상)',
#   '재질': '마그네슘',
#   '부피': '1473cc',
#   '무게': '980g',
#   '1회기록시간': '29분59초',
#   '동영상부가기능': '타임랩스',
#   '출시가': '3,580,000원'},
#  {'제품명': '캐논 SX740 HS',
#   '가격': 397430,
#   '유효화소': '2030만화소',
#   '최소셔터스피드': '3200초',
#   '동영상 해상도': 'UHD(4K)',
#   '화면': '3"',
#   '접사거리': '1cm',
#   '무게': '299g',
#   '최대연속촬영속도': '10매',
#   '부가기능': '손떨림방지',
#   '단자': 'HDMI출력',
#   '두께': '4cm',
#   '부피': '282cc',
#   '블루투스': '블루투스4.1',
#   '품목': '일반디카',
#   'CMOS': '0.43인치(1/2.3)',
#   '스피드': '셔터(1/3200초)',
#   '스마트': '무선전송(WiFi)',
#   '연사': '초당10장',
#   '화질엔진': 'DIGIC8',
#   '무선기능': 'NFC',
#   '광각범위': '24mm',
#   '셀카': '셀카가능',
#   '줌배율': '40배줌',
#   '밝기': 'F3.3',
#   '셀카액정기능': '플립'},
#  {'제품명': '소니 알파 A7R III',
#   '가격': 2299000,
#   '용도별': '전문가용',
#   '유효화소': '4240만화소',
#   'ISO': '100~32000',
#   '최소셔터스피드': '1/8000초',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '10매',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당10장',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '바디',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '144만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   '확장': '50~102400',
#   '화질엔진': 'Bionz X',
#   '1회기록시간': '약29분',
#   '메모리카드': '듀얼슬롯',
#   '동영상부가기능': '타임코드',
#   '최대촬영': '약650장(사진),약115분(동영상)',
#   '두께': '7.4cm',
#   '부피': '890cc',
#   '무게': '673g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스',
#   '뷰파인더 화소': '369만화소',
#   '뷰파인더 형태': '내장뷰파인더'},
#  {'제품명': '파나소닉 루믹스 DC-LX100 II',
#   '가격': 822200,
#   '유효화소': '1700만화소',
#   '동영상 해상도': 'UHD(4K)',
#   '화면': '3"',
#   '광학줌': '3.1배줌',
#   '접사거리': '3cm',
#   'ISO': 'ISO 25600',
#   '무게': '392g',
#   '저장매체': 'SDHC',
#   '부가기능': '로우패스필터제거',
#   '단자': 'HDMI출력',
#   '동영상 프레임': '30프레임',
#   '두께': '6.4cm',
#   '부피': '486cc',
#   '블루투스': '블루투스4.2',
#   '품목': '하이엔드디카',
#   '스피드': '셔터(1/4000초)',
#   '스마트': '무선전송(WiFi)',
#   '화면특징': '터치',
#   '연사': '초당11장',
#   '화질엔진': 'VENUS엔진',
#   '방식': '뷰파인더(전자식)',
#   '충전': 'USB충전',
#   '광각범위': '24mm',
#   '손떨림기능': '광학식손떨림보정',
#   '촬영모드': '수동모드',
#   '사진효과': '필터효과',
#   '줌배율': '3.1배줌',
#   '밝기': 'F1.7'},
#  {'제품명': '캐논 EOS RP',
#   '가격': 1306590,
#   '용도별': '전문가용',
#   '유효화소': '2620만화소',
#   'ISO': '100~40000',
#   '최소셔터스피드': '1/4000초',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '5매',
#   '동영상프레임': '25프레임',
#   '저장매체': 'SD',
#   '프레임': '24프레임',
#   '특징': '스위블(회전)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당5장',
#   '초점방식': '하이브리드AF',
#   '초점영역': '4,779개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '플래시없음',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   'AF기능': '터치&드래그',
#   '확장': '50~102400',
#   '화질엔진': 'DIGIC 8',
#   '메모리카드': 'UHS-II호환',
#   '동영상부가기능': '전자식IS',
#   '최대촬영': '약250장(사진),약100분(동영상)',
#   '두께': '8.5cm',
#   '부피': '819cc',
#   '이미지센서 부가기능': '로우패스필터제거',
#   '무게(배터리제외)': '440g',
#   '무게': '485g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '캐논 SX70 HS',
#   '가격': 479810,
#   '유효화소': '2030만화소',
#   '동영상 해상도': 'UHD(4K)',
#   '화면': '3인치',
#   '접사거리': '0cm',
#   'ISO': 'ISO 3200',
#   '무게': '610g',
#   '저장매체': 'SDHC',
#   '부가기능': '이면조사',
#   '단자': 'HDMI출력',
#   '동영상 프레임': '30프레임',
#   '두께': '11.66cm',
#   '부피': '1,348cc',
#   '블루투스': '블루투스4.1',
#   '품목': '하이엔드디카',
#   'CMOS': '0.43인치(1/2.3)',
#   '스피드': '셔터(1/2000초)',
#   '스마트': '무선전송(WiFi)',
#   '연사': '초당10장',
#   '화질엔진': 'DIGIC8',
#   '방식': '뷰파인더(전자식)',
#   '기타': '프레이밍어시스트',
#   '광각범위': '21mm',
#   '손떨림기능': '광학식손떨림보정',
#   '촬영모드': '수동모드',
#   '셀카': '셀카가능',
#   '1회기록시간': '약29분59',
#   '동영상부가기능': '타임랩스',
#   '줌배율': '65배줌',
#   '밝기': 'F3.4',
#   '셀카액정기능': '회전'},
#  {'제품명': '삼성전자 삼성 NX Mini',
#   '가격': 158000,
#   '유효화소': '2050만화소',
#   'CMOS': '1인치',
#   'ISO': '160~12800',
#   '최소셔터스피드': '1/16000초',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '6매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'microSDXC',
#   '프레임': '30프레임',
#   '특징': '플립(셀카)',
#   '스피드': '셔터(1/16000초)',
#   '연사': '초당6장',
#   '초점영역': '35개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '디스플레이 형태': '터치',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': '파노라마',
#   '확장': '100~25600',
#   '메모리카드': 'UHS-I호환',
#   '내장메모리': '16G포함',
#   '최대촬영': '약650장',
#   '두께': '2.3cm',
#   '부피': '150cc',
#   '무게': '196g',
#   '부가기능': '이면조사',
#   '품목': '미러리스'},
#  {'제품명': '니콘 D850',
#   '가격': 2725790,
#   '용도별': '전문가용',
#   '유효화소수': '4575만화소',
#   'ISO': '64~25600',
#   '최소셔터스피드': '1/8000초',
#   '종류': 'DSLR',
#   '화면화소': '236만화소',
#   '부가기능': '방진, 방습',
#   '뷰파인더': '뷰파인더',
#   '화면': '3.2인치(8.1cm)',
#   '확장ISO': '32~102400',
#   '초점영역': '153개',
#   '연사': '초당7장',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '초당7매',
#   '촬영기능': 'HDR',
#   '특징': '로우패스필터제거',
#   '스마트': '블루투스',
#   '내장플래시': '팝업플래시',
#   '프레임': '30프레임',
#   '방식': '광학식',
#   '시야율': '100%시야율',
#   '스피드': '셔터(1/8000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '형태': '틸트',
#   '영상출력': 'HDMI출력',
#   '파일형식': 'MP4',
#   '화질엔진': 'EXPEED5',
#   '먼지제거': '가능',
#   '저장매체': 'XQD메모리',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약70분(동영상)',
#   '재질': '마그네슘',
#   '부피': '1430cc',
#   '무게': '1kg',
#   '1회기록시간': '29분59초',
#   '동영상부가기능': '전자식IS',
#   '출시가': '3,980,000원'},
#  {'제품명': '오늘 출발 한글패치 어린이 카메라 미니 캠코더 크리스마스 어린이날 조카 선물',
#   '가격': 25200,
#   '저장매체': 'MICRO SD',
#   '부가기능': '한글지원',
#   '배터리용량': '600mAh'},
#  {'제품명': '소니 DSC-RX100M3',
#   '가격': 539800,
#   '최소셔터스피드': '1/2000초',
#   '디지털줌': '5.8배',
#   '최대조리개': 'F1.8',
#   'ISO': 'ISO 12800',
#   '최대연속촬영속도': '10매',
#   '저장매체': 'SD',
#   '부가기능': '얼굴인식AF'},
#  {'제품명': '리코 GR II',
#   '가격': 23000,
#   '최소셔터스피드': '1/4000초',
#   '최대조리개': 'F2.8',
#   'ISO': 'ISO 25600',
#   '최대연속촬영속도': '4m/sec',
#   '저장매체': 'SDXC'},
#  {'제품명': '후지필름 XF10',
#   '가격': 482160,
#   '최소셔터스피드': '1/4000초',
#   '최대조리개': 'F2.8',
#   'ISO': 'ISO 51200',
#   '최대연속촬영속도': '초당6매',
#   '저장매체': 'SD',
#   '부가기능': '얼굴인식AF'},
#  {'제품명': '삼성전자 삼성 NX3000',
#   '가격': 204090,
#   '유효화소': '2030만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '5매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'SDXC',
#   '프레임': '30프레임',
#   '특징': '플립(셀카)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당5장',
#   '초점영역': '35개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '외장플래시포함',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '46만화소',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': '스마트레인지',
#   '메모리카드': 'UHS-I호환',
#   '내장메모리': '16G포함',
#   '최대촬영': '약370장',
#   '두께': '3.9cm',
#   '부피': '301cc',
#   '무게(배터리제외)': '230g',
#   '인터페이스': 'HDMI',
#   '부가기능': 'iFn렌즈',
#   '품목': '미러리스'},
#  {'제품명': '캐논 EOS 60D',
#   '가격': 189650,
#   '용도별': '중급자용',
#   '유효화소수': '1800만화소',
#   'ISO': '100~6400',
#   '최소셔터스피드': '1/8000',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '부가기능': '전자수평계',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '12800',
#   '초점영역': '9개',
#   '연사': '초당5.3장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '5.3매',
#   '촬영기능': '역광보정',
#   '내장플래시': '팝업플래시',
#   '기능': '동영상촬영불가',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/8000초)',
#   '손떨림보정': '렌즈(별매)',
#   '형태': '회전',
#   '영상출력': 'HDMI출력',
#   '파일형식': 'MOV',
#   '라이브뷰': '라이브뷰,얼굴인식',
#   '화질엔진': 'DIGIC4',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약120분(동영상)',
#   '재질': '플라스틱',
#   '부피': '1214cc',
#   '무게': '755g'},
#  {'제품명': '소니 알파 A7R IV',
#   '가격': 3350000,
#   '용도별': '전문가용',
#   '유효화소': '6100만 화소',
#   'ISO': '100~32000',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당10장',
#   '초점방식': '하이브리드AF',
#   '초점영역': '567개',
#   '손떨림보정': '바디(5축)',
#   '플래시': '플래시없음',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '144만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': '블루투스',
#   '스마트': '무선전송',
#   'AF기능': 'EyeAF',
#   '확장': '50~102400',
#   '화질엔진': 'Bionz X',
#   '메모리카드': '듀얼슬롯',
#   '최대촬영': '약 670장(사진),약 105분(동영상)',
#   '부피': '966cc',
#   '무게': '665g',
#   '인터페이스': '마이크(3.5mm)',
#   '부가기능': '저소음촬영',
#   '품목': '미러리스',
#   '뷰파인더 화소': '576만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '파나소닉 DC-GF10',
#   '가격': 303070,
#   '용도별': '입문자용',
#   '유효화소': '1600만화소',
#   'ISO': '200~25600',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': 'microSDXC',
#   '프레임': '30프레임',
#   '특징': '플립(셀카)',
#   '연사': '초당5.8장',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '터치',
#   '스마트': '무선전송(WiFi)',
#   '확장': '100~25600',
#   '최대촬영': '약210장',
#   '두께': '3.3cm',
#   '부피': '230cc',
#   '이미지센서 부가기능': '로우패스필터제거',
#   '무게': '270g',
#   '인터페이스': 'HDMI',
#   '부가기능': '먼지제거',
#   '품목': '미러리스'},
#  {'제품명': '후지필름 X-T100',
#   '가격': 489730,
#   '용도별': '입문자용',
#   '유효화소': '2420만화소',
#   'ISO': '200~12800',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '초당6매',
#   '동영상프레임': '15프레임',
#   '저장매체': 'SD',
#   '프레임': '15프레임',
#   '특징': '셀카',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당6장',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': '블루투스4.1',
#   '스마트': '무선전송',
#   '촬영기능': '다이나믹레인지',
#   '확장': '100~51200',
#   '메모리카드': 'UHS-I호환',
#   '최대촬영': '약430장',
#   '두께': '3.3cm',
#   '부피': '452cc',
#   '무게(배터리제외)': '399g',
#   '무게': '448g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '소니 미러리스 알파 A6100 바디 + ACC-TRW', '가격': 1114840},
#  {'제품명': '소니 DSC-RX100M4',
#   '가격': 640000,
#   '최소셔터스피드': '1/2000초',
#   '최대조리개': 'F1.8',
#   'ISO': 'ISO 12800',
#   '저장매체': 'SDHC'},
#  {'제품명': '(HKC)캐논 EOS R 바디+SD 32G 메모리증정/당일발송', '가격': 2274800},
#  {'제품명': '후지필름 파인픽스 XP120',
#   '가격': 231990,
#   '디지털줌': '2배',
#   '최대조리개': 'F3.9',
#   'ISO': 'ISO 3200',
#   '최대연속촬영속도': '10매',
#   '저장매체': 'SD',
#   '부가기능': '손떨림방지'},
#  {'제품명': '후지필름 파인픽스 XP130',
#   '가격': 246290,
#   '디지털줌': '10배',
#   'ISO': 'ISO 6400',
#   '최대연속촬영속도': '초당10매',
#   '저장매체': 'SD',
#   '부가기능': '손떨림방지'},
#  {'제품명': '니콘 D7500',
#   '가격': 737300,
#   '용도별': '중급자용',
#   '유효화소수': '2088만화소',
#   'ISO': '100~51200',
#   '종류': 'DSLR',
#   '화면화소': '92만화소',
#   '뷰파인더': '뷰파인더',
#   '화면': '3.2인치(8.1cm)',
#   '확장ISO': '50~1640000',
#   '초점영역': '51개',
#   '연사': '초당8장',
#   '동영상 해상도': 'UHD(4K)',
#   'EISA 어워드': 'EISA 어워드',
#   '촬영기능': '아트필터',
#   '스마트': '블루투스',
#   '프레임': '30프레임',
#   '방식': '광학식',
#   '시야율': '100%시야율',
#   '스피드': '셔터(1/8000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '형태': '틸트',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '라이브뷰',
#   '화질엔진': 'EXPEED5',
#   '저장매체': 'SDHC',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약80분(동영상)',
#   '부피': '1033cc',
#   '무게': '640g',
#   '1회기록시간': '29분59초',
#   '파일형식': 'MP4',
#   '동영상부가기능': '전자식IS',
#   '출시가': '1,480,000원'},
#  {'제품명': '캐논 EOS 450D',
#   '가격': 100510,
#   '용도별': '입문자용',
#   '유효화소수': '1220만화소',
#   'ISO': '100~1600',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면화소': '23만화소',
#   '부가기능': '벌브지원',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '초점영역': '9개',
#   '연사': '초당3.5장',
#   '최대연속촬영속도': '3.5매',
#   '촬영기능': '역광보정',
#   '내장플래시': '팝업플래시',
#   '기능': '동영상촬영불가',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '라이브뷰': '라이브뷰',
#   '화질엔진': 'DIGIC3',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '재질': '플라스틱',
#   '부피': '784cc',
#   '무게': '522g'},
#  {'제품명': '캐논 EOS R',
#   '가격': 2180740,
#   '용도별': '전문가용',
#   '유효화소': '3030만화소',
#   'ISO': '100~40000',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '초당 8매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '특징': '스위블(회전)',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당8장',
#   '초점방식': '듀얼픽셀AF',
#   '초점영역': '5,655개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '플래시없음',
#   '화면크기': '3.15인치(8cm)',
#   '화면화소': '210만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   'AF기능': '터치&드래그',
#   '촬영기능': 'HDR',
#   '확장': '50~102400',
#   '화질엔진': 'DIGIC 8',
#   '메모리카드': 'UHS-II호환',
#   '동영상AF': '동영상서보AF',
#   '동영상부가기능': '전자식IS',
#   '최대촬영': '약 370장(사진),약 140분(동영상)',
#   '부피': '1120cc',
#   '이미지센서 부가기능': '로우패스필터제거',
#   '무게(배터리제외)': '580g',
#   '무게': '660g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스',
#   '뷰파인더 화소': '369만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '니콘 D5500',
#   '가격': 308190,
#   '용도별': '입문자용',
#   '유효화소수': '2416만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '4000초',
#   '종류': 'DSLR',
#   '화면화소': '103.7만화소',
#   '뷰파인더': '뷰파인더',
#   '화면': '3.2인치(8.1cm)',
#   '초점영역': '39개',
#   '연사': '초당5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '5매',
#   '촬영기능': '역광보정',
#   '특징': '로우패스필터제거',
#   '스마트': '무선전송(WiFi)',
#   '내장플래시': '팝업플래시',
#   '프레임': '60프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '형태': '회전',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '라이브뷰',
#   '화질엔진': 'EXPEED4',
#   '먼지제거': '가능',
#   '저장매체': 'SDHC',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약820장',
#   '부피': '842cc',
#   '무게': '470g',
#   '출시가': '898,000원'},
#  {'제품명': '소니 알파 NEX-5T',
#   '가격': 202300,
#   '용도별': '중급자용',
#   '유효화소': '1610만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '10매',
#   '동영상프레임': '60프레임',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '60프레임',
#   '디지털줌': '4배',
#   '특징': '틸트+플립(셀카)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당10장',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '외장플래시포함',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '92만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': 'HDR',
#   '화질엔진': 'Bionz',
#   '최대촬영': '약330장',
#   '두께': '3.9cm',
#   '부피': '253cc',
#   '무게': '276g',
#   '인터페이스': 'HDMI',
#   '부가기능': 'USB충전',
#   '품목': '미러리스'},
#  {'제품명': '삼성전자 삼성 NX300',
#   '가격': 187900,
#   '유효화소': '2030만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/6000',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '9매',
#   '동영상프레임': '60프레임',
#   '저장매체': 'SD',
#   '프레임': '60프레임',
#   '스피드': '셔터(1/6000초)',
#   '연사': '초당8.6장',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '외장플래시포함',
#   '화면크기': '3.31인치(8.4cm)AM-OLED',
#   '화면화소': '76.8만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi,듀얼밴드)',
#   '촬영기능': '3D사진(렌즈별매)',
#   '화질엔진': 'DRIMe Ⅳ',
#   '최대촬영': '약330장',
#   '두께': '4.1cm',
#   '부피': '320cc',
#   '무게(배터리제외)': '284g',
#   '인터페이스': 'HDMI',
#   '부가기능': 'iFn렌즈',
#   '품목': '미러리스'},
#  {'제품명': '소니 사이버샷 DSC-RX100 VI',
#   '가격': 950240,
# ...
#   '라이브뷰': '라이브뷰,얼굴인식',
#   '화질엔진': 'EXPEED4',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약1200장(사진)',
#   '부피': '924cc',
#   '무게': '395g',
#   '1회기록시간': '29분59초',
#   '파일형식': 'MOV',
#   '출시가': '548,000원'},
#  {'제품명': '캐논 EOS 5Ds',
#   '가격': 2060900,
#   '용도별': '전문가용',
#   '유효화소수': '5060만화소',
#   'ISO': '100~6400',
#   '최소셔터스피드': '1/8000초',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '뷰파인더': '뷰파인더',
#   '화면': '3.2인치(8.1cm)',
#   '확장ISO': '50~12800',
#   '초점영역': '61개',
#   '연사': '초당5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '5매',
#   '촬영기능': '다중노출',
#   '내장플래시': '플래시없음',
#   '기능': 'AF미세조정',
#   '프레임': '30프레임',
#   '방식': '광학식',
#   '시야율': '100%시야율',
#   '스피드': '셔터(1/8000초)',
#   '손떨림보정': '렌즈(별매)',
#   '영상출력': 'HDMI출력',
#   '파일형식': 'MOV',
#   '라이브뷰': '라이브뷰,얼굴인식',
#   '화질엔진': '듀얼DIGIC6',
#   '먼지제거': '가능',
#   '저장매체': 'CF',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약90분(동영상)',
#   '부피': '1300cc',
#   '무게': '930g',
#   '동영상부가기능': '타임코드',
#   '출시가': '4,748,000원'},
#  {'제품명': '소니 알파 A7R II',
#   '가격': 1778970,
#   '용도별': '전문가용',
#   '유효화소': '4240만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '8000초',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당5장',
#   '재질': '마그네슘',
#   '초점방식': '하이브리드AF',
#   '초점영역': '399+25개',
#   '손떨림보정': '바디(5축)',
#   '플래시': '플래시없음',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '123만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': '다이나믹레인지',
#   '확장': '50~102400',
#   '화질엔진': 'Bionz X',
#   '1회기록시간': '약29분',
#   '메모리카드': 'UHS-I호환',
#   '동영상부가기능': '타임코드',
#   '최대촬영': '약340장(사진),약55분(동영상)',
#   '두께': '6cm',
#   '부피': '732cc',
#   '이미지센서 부가기능': '로우패스필터제거',
#   '무게': '625g',
#   '인터페이스': 'HDMI',
#   '부가기능': '이면조사',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '소니 DSC-RX0',
#   '가격': 457310,
#   '유효화소': '1530만화소',
#   '최소셔터스피드': '1/32000초',
#   '동영상 해상도': 'Full-HD',
#   '화면': '1.5"',
#   '형태': '초소형',
#   '최대조리개': 'F4.0',
#   '접사거리': '50cm',
#   'ISO': 'ISO 12800',
#   '무게': '110g',
#   '최대연속촬영속도': '초당16매',
#   '저장매체': '메모리스틱',
#   '부가기능': '손떨림방지',
#   '단자': 'HDMI출력',
#   '두께': '2.98cm',
#   '렌즈': '칼자이스렌즈',
#   '부피': '71cc',
#   '블루투스': '블루투스4.1',
#   '품목': '하이엔드디카',
#   'CMOS': '1인치',
#   '스피드': '셔터(1/3200초)',
#   '스마트': '무선전송(WiFi)',
#   '연사': '초당16장',
#   '충격흡수': '2m',
#   '화질엔진': 'Bionz X',
#   '무선기능': 'NFC',
#   '확장 ISO': '25600',
#   '플래시': '플래시내장',
#   '기타': 'RAW지원',
#   '충전': 'USB충전',
#   '방수': '방수겸용',
#   '최대촬영': '약240장(사진),약60분(동영상)',
#   '방수수심': '10m',
#   '밝기': 'F4'},
#  {'제품명': '니콘 D5000',
#   '가격': 124810,
#   '용도별': '입문자용',
#   '유효화소수': '1230만화소',
#   'ISO': '200~3200',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면화소': '23만화소',
#   '부가기능': '얼굴인식',
#   '뷰파인더': '뷰파인더',
#   '화면': '2.7인치(6.8cm)',
#   '확장ISO': '6400',
#   '초점영역': '11개',
#   '연사': '초당4장',
#   '동영상 해상도': 'HD',
#   '최대연속촬영속도': '4.0매',
#   '촬영기능': '역광보정',
#   '내장플래시': '플래시없음',
#   '기능': 'AF트래킹',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '형태': '회전',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '라이브뷰,얼굴인식',
#   '화질엔진': 'EXPEED1',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '인터페이스': 'HDMI',
#   '재질': '플라스틱',
#   '부피': '1057cc',
#   '무게': '611g'},
#  {'제품명': '캐논 EOS M',
#   '가격': 154070,
#   '용도별': '중급자용',
#   '유효화소': '1800만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '4.3매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당4.3장',
#   '재질': '알루미늄',
#   '초점방식': '하이브리드AF',
#   '초점영역': '31개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '플래시없음',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '터치',
#   '촬영기능': 'HDR',
#   '확장': '25600',
#   '화질엔진': 'DIGIC 5',
#   '메모리카드': 'UHS-I호환',
#   '최대촬영': '약230장',
#   '두께': '3.2cm',
#   '부피': '233cc',
#   '무게': '298g',
#   '인터페이스': 'HDMI',
#   '부가기능': '색수차보정',
#   '품목': '미러리스'},
#  {'제품명': '파나소닉 DC-GH5',
#   '가격': 1834470,
#   '용도별': '전문가용',
#   '유효화소': '2030만화소',
#   'ISO': '200~25600',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': 'SDHC',
#   '프레임': '60프레임',
#   '특징': '스위블(회전)',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당12장',
#   '재질': '마그네슘',
#   '초점영역': '225개',
#   '손떨림보정': '바디(5축)+렌즈(2축)',
#   '화면크기': '3.2인치(8.1cm)',
#   '화면화소': '162만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   '확장': '100~25600',
#   '메모리카드': '듀얼슬롯',
#   '최대촬영': '약410장',
#   '두께': '8.7cm',
#   '부피': '1,185cc',
#   '무게': '725g',
#   '인터페이스': 'HDMI',
#   '부가기능': '먼지제거',
#   '품목': '미러리스',
#   '뷰파인더 화소': '368만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '올림푸스 E-M5 Mark III',
#   '가격': 1250000,
#   '용도별': '중급자용',
#   '유효화소': '2200만화소',
#   'CMOS': 'LiveMOS(4/3인치)',
#   'ISO': '200~25600',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'C4K(DCI 4K)',
#   '저장매체': 'SD',
#   '프레임': '24프레임',
#   '특징': '스위블(회전)',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당30장',
#   '초점방식': '하이브리드AF',
#   '초점영역': '121개',
#   '손떨림보정': '바디(5축)',
#   '플래시': '플래시없음',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': '아트필터',
#   '확장': '60~25600',
#   '화질엔진': 'TruePic VIII',
#   '1회기록시간': '약29분',
#   '메모리카드': 'UHS-II호환',
#   '동영상부가기능': '전자식IS',
#   '최대촬영': '약310장(사진),약60분(동영상)',
#   '부피': '531cc',
#   '이미지센서 부가기능': '초음파방진필터',
#   '무게(배터리제외)': '366g',
#   '무게': '414g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더'},
#  {'제품명': '소니 사이버샷 DSC-RX100',
#   '가격': 421990,
#   '최소셔터스피드': '1/2000초',
#   '디지털줌': '7.2배',
#   '최대조리개': 'F1.8',
#   'ISO': 'ISO 6400',
#   '최대연속촬영속도': '10매',
#   '저장매체': 'SD',
#   '부가기능': '손떨림방지'},
#  {'제품명': '올림푸스 E-M1 Mark II',
#   '가격': 1450000,
#   '용도별': '전문가용',
#   '유효화소': '2037만화소',
#   'ISO': '200~25600',
#   '최소셔터스피드': '1/8000초',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '초당60매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'SD',
#   '특징': '스위블(회전)',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당15장',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '바디(5축)',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '터치',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': 'HDR',
#   '화질엔진': 'TruePic VIII',
#   '메모리카드': '듀얼슬롯',
#   '최대촬영': '약950장',
#   '두께': '6.9cm',
#   '부피': '841cc',
#   '무게': '574g',
#   '인터페이스': 'HDMI',
#   '부가기능': '먼지제거',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더'},
#  {'제품명': '삼성전자 삼성 NX10',
#   '가격': 109290,
#   '유효화소': '1460만화소',
#   'ISO': '3200',
#   '최소셔터스피드': '1/4000초',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'HD',
#   '최대연속촬영속도': '3매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'SD',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당3장',
#   '재질': '플라스틱',
#   '초점영역': '15개',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)AM-OLED',
#   '화면화소': '61만화소',
#   '촬영기능': '파노라마',
#   '두께': '3.9cm',
#   '부피': '426cc',
#   '무게': '409.2g',
#   '인터페이스': 'HDMI',
#   '부가기능': '먼지제거',
#   '품목': '미러리스',
#   '뷰파인더 형태': '내장뷰파인더'},
#  {'제품명': '삼성전자 삼성 NX200',
#   '가격': 151190,
#   '유효화소': '2030만화소',
#   'ISO': '12800',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '11매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당7장',
#   '재질': '알루미늄',
#   '초점영역': '15개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '외장플래시포함',
#   '화면크기': '3인치(7.6cm)AM-OLED',
#   '화면화소': '61만화소',
#   '촬영기능': '파노라마',
#   '두께': '3.6cm',
#   '부피': '272cc',
#   '무게': '266.8g',
#   '인터페이스': 'HDMI',
#   '부가기능': 'iFn렌즈',
#   '품목': '미러리스'},
#  {'제품명': '[행사]소니 알파 A6400L(SEL1650 포함)/ILCE-6400', '가격': 1140000},
#  {'제품명': '니콘 Z50',
#   '가격': 1100000,
#   '용도별': '중급자용',
#   '유효화소': '2151만화소',
#   'ISO': '100~51200',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당11장',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3.2인치(8.1cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '터치',
#   '확장': '204800',
#   '화질엔진': 'EXPEED6',
#   '1회기록시간': '약29분',
#   '메모리카드': 'UHS-I호환',
#   '최대촬영': '약320장(사진),약75분(동영상)',
#   '무게(배터리제외)': '395g',
#   '무게': '450g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더'},
#  {'제품명': '캐논 EOS M100 (본체 / 15-45mm 렌즈) 정품 주)클락', '가격': 465500},
#  {'제품명': '소니 알파 NEX-F3', '가격': 197000},
#  {'제품명': '소니 사이버샷 DSC-HX99',
#   '가격': 500540,
#   '유효화소': '1820만화소',
#   '동영상 해상도': 'UHD(4K)',
#   '화면': '3인치',
#   '접사거리': '5cm',
#   'ISO': 'ISO 3200',
#   '무게': '242cc',
#   '저장매체': 'SDHC',
#   '부가기능': '이면조사',
#   '단자': 'HDMI출력',
#   '동영상 프레임': '30프레임',
#   '두께': '3.6cm',
#   '렌즈': '칼자이스렌즈',
#   '부피': '213cc',
#   '블루투스': '블루투스4.1',
#   '품목': '하이엔드디카',
#   'CMOS': '0.43인치(1/2.3)',
#   '스피드': '셔터(1/2000초)',
#   '스마트': '무선전송(WiFi)',
#   '화면특징': '터치',
#   '연사': '초당10장',
#   '초점거리': '24mm',
#   '화질엔진': 'Bionz X',
#   '방식': '뷰파인더(전자식)',
#   '확장 ISO': '12800',
#   '플래시': '플래시내장',
#   '광각범위': '24mm',
#   '손떨림기능': '광학식손떨림보정',
#   '사진효과': '필터효과',
#   '셀카': '셀카가능',
#   '1회기록시간': '약29분',
#   '줌배율': '28배줌',
#   '최대촬영': '약55분(동영상)',
#   '촬영기능': 'HDR',
#   '밝기': 'F3.5',
#   '셀카액정기능': '플립'},
#  {'제품명': '니콘 D3000',
#   '가격': 126150,
#   '용도별': '입문자용',
#   '유효화소수': '1020만화소',
#   'ISO': '100~1600',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면화소': '23만화소',
#   '부가기능': '벌브지원',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '3200',
#   '초점영역': '11개',
#   '연사': '초당3장',
#   '최대연속촬영속도': '3매',
#   '촬영기능': '역광보정',
#   '내장플래시': '플래시없음',
#   '기능': '동영상촬영불가',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화질엔진': 'EXPEED1',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '재질': '플라스틱',
#   '부피': '782cc',
#   '무게': '536g'},
#  {'제품명': '파나소닉 DC-GX9',
#   '가격': 691190,
#   '용도별': '입문자용',
#   '유효화소': '1600만화소',
#   'ISO': '200~25600',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '초당30매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'SD',
#   '프레임': '30프레임',
#   '특징': '플립(셀카)',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당5.8장',
#   '초점방식': '컨트라스트AF',
#   '초점영역': '49개',
#   '손떨림보정': '바디(5축)+렌즈(2축)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   'AF기능': 'DFD동체추적',
#   '확장': '100~25600',
#   '화질엔진': '비너스',
#   '메모리카드': 'UHS-I호환',
#   '최대촬영': '약210장',
#   '두께': '3.3cm',
#   '부피': '230cc',
#   '이미지센서 부가기능': '로우패스필터제거',
#   '무게': '270g',
#   '인터페이스': 'HDMI',
#   '부가기능': '먼지제거',
#   '품목': '미러리스',
#   '뷰파인더 화소': '276만화소',
#   '뷰파인더 형태': '내장뷰파인더'},
#  {'제품명': '캐논 EOS 760D',
#   '가격': 578300,
#   '용도별': '준중급자용',
#   '유효화소수': '2420만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면화소': '104만화소',
#   '부가기능': '전자수평계',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '25600',
#   '초점영역': '19개',
#   '연사': '초당5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '초당5매',
#   '촬영기능': '역광보정',
#   '스마트': 'NFC',
#   '내장플래시': '팝업플래시',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '화면특징': '터치',
#   '형태': '회전',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '하이브리드AFIII',
#   '화질엔진': 'DIGIC6',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '초점종류': '위상차AF',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약440장',
#   '부피': '1030cc',
#   '무게': '565g'},
#  {'제품명': '니콘 D3500',
#   '가격': 445820,
#   '용도별': '입문자용',
#   '유효화소수': '2416만화소',
#   'ISO': '100~25600',
#   '종류': 'DSLR',
#   '화면화소': '92만화소',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '초점영역': '11개',
#   '연사': '초당5장',
#   '동영상 해상도': 'Full-HD',
#   '스마트': '블루투스',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '영상출력': 'HDMI출력',
#   '화질엔진': 'EXPEED4',
#   '저장매체': 'SDHC',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약1550장(사진)',
#   '부피': '842cc',
#   '무게': '415g',
#   '1회기록시간': '29분59초',
#   '파일형식': 'MOV'},
#  {'제품명': '소니 알파 A7R',
#   '가격': 856820,
#   '용도별': '전문가용',
#   '유효화소': '3640만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/8000초',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '4매',
#   '동영상프레임': '60프레임',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '60프레임',
#   '디지털줌': '4배',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당4장',
#   '재질': '마그네슘',
#   '초점영역': '25개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '플래시없음',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '92만화소',
#   '디스플레이 형태': '틸트',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': '파노라마',
#   '확장': '50~25600',
#   '화질엔진': 'Bionz X',
#   '최대촬영': '약340장(사진),약65분(동영상)',
#   '두께': '4.8cm',
#   '부피': '579cc',
#   '이미지센서 부가기능': '로우패스필터제거',
#   '무게': '465g',
#   '인터페이스': 'HDMI',
#   '부가기능': '색수차보정',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '니콘 Nikon1 J5',
#   '가격': 320000,
#   '용도별': '입문자용',
#   '유효화소': '2081만화소',
#   'ISO': '160~12800',
#   '최소셔터스피드': '6000초',
#   '동영상 해상도': 'UHD(4K)',
#   '저장매체': 'microSDXC',
#   '프레임': '15프레임',
#   '특징': '틸트+플립(셀카)',
#   '스피드': '셔터(1/16000초)',
#   '연사': '초당20장',
#   '초점방식': '하이브리드AF',
#   '초점영역': '171개',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '104만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': 'NFC',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': '파노라마',
#   '화질엔진': 'EXPEED 5A',
#   '두께': '3.2cm',
#   '부피': '188cc',
#   '무게': '265g',
#   '인터페이스': 'HDMI',
#   '품목': '미러리스'},
#  {'제품명': '[국내배송] 아카라치 어린이카메라 국내최초 wifi기능 한국어지원', '가격': 48900},
#  {'제품명': '파나소닉 DC-GH5s',
#   '가격': 2322740,
#   '용도별': '중급자용',
#   '유효화소': '1028만화소',
#   'ISO': '160~51200',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'UHD(4K)',
#   '최대연속촬영속도': '초당7매',
#   '동영상프레임': '60프레임',
#   '저장매체': 'SDHC',
#   '프레임': '60프레임',
#   '특징': '스위블(회전)',
#   '스피드': '셔터(1/8000초)',
#   '연사': '초당7장',
#   '재질': '마그네슘',
#   '초점방식': '컨트라스트AF',
#   '플래시': '플래시없음',
#   '화면크기': '3.2인치(8.1cm)',
#   '화면화소': '162만화소',
#   '디스플레이 형태': '터치',
#   '무선기능': '블루투스',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': 'HDR',
#   '확장': '80~204800',
#   '화질엔진': '비너스',
#   '메모리카드': '듀얼슬롯',
#   '부피': '1188cc',
#   '무게(배터리제외)': '580g',
#   '인터페이스': 'HDMI',
#   '부가기능': '방진방습',
#   '품목': '미러리스',
#   '뷰파인더 형태': '내장뷰파인더'},
#  {'제품명': '삼성전자 삼성 WB150F', '가격': 238760},
#  {'제품명': '소니 DSC-HX400V',
#   '가격': 483000,
#   '최대조리개': 'F2.8',
#   '저장매체': 'SD',
#   '부가기능': '손떨림방지'},
#  {'제품명': '뉴앤핫 적외선 초소형 카메라 미니 카메라 초미니 카메라 Full HD 1080P 소형', '가격': 26900},
#  {'제품명': '니콘 D3300',
#   '가격': 248840,
#   '용도별': '입문자용',
#   '유효화소수': '2416만화소',
#   'ISO': '100~12800',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면화소': '92만화소',
#   '부가기능': '손떨림방지',
#   '뷰파인더': '뷰파인더',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '25600',
#   '초점영역': '11개',
#   '연사': '초당5장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '5매',
#   '촬영기능': '역광보정',
#   '특징': '로우패스필터제거',
#   '내장플래시': '팝업플래시',
#   '프레임': '60프레임',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '라이브뷰,얼굴인식',
#   '화질엔진': 'EXPEED4',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '인터페이스': 'HDMI',
#   '최대촬영': '약700장',
#   '부피': '924cc',
#   '무게': '460g'},
#  {'제품명': '올림푸스 E-PL2',
#   '가격': 162620,
#   '용도별': '중급자용',
#   '유효화소': '1230만화소',
#   'ISO': '6400',
#   '최소셔터스피드': '1/4000초',
#   '동영상 해상도': 'HD',
#   '최대연속촬영속도': '3매',
#   '동영상프레임': '30프레임',
#   '저장매체': 'SD',
#   '촬영시간': '1회7분',
#   '프레임': '30프레임',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당3장',
#   '재질': '플라스틱',
#   '초점영역': '11개',
#   '손떨림보정': '바디',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '46만화소',
#   '무선기능': '블루투스(별매)',
#   'AF기능': '눈동자검출',
#   '촬영기능': '아트필터',
#   '두께': '4.2cm',
#   '부피': '353cc',
#   '무게': '362g',
#   '인터페이스': 'HDMI',
#   '부가기능': '먼지제거',
#   '품목': '미러리스'},
#  {'제품명': '캐논 EOS 7D Mark II',
#   '가격': 785000,
#   '유효화소수': '2020만화소',
#   'ISO': '100~16000',
#   '최소셔터스피드': '1/8000초',
#   '종류': 'DSLR',
#   '부가기능': '방진, 방습',
#   '화면': '3인치(7.6cm)',
#   '확장ISO': '51200',
#   '초점영역': '65개',
#   '연사': '초당10장',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '초당10매',
#   '촬영기능': '다중노출',
#   '내장플래시': '팝업플래시',
#   '프레임': '60프레임',
#   '방식': '광학식',
#   '시야율': '100%시야율',
#   '스피드': '셔터(1/8000초)',
#   '손떨림보정': '렌즈(별매)',
#   '영상출력': 'HDMI출력',
#   '라이브뷰': '듀얼픽셀AF',
#   '화질엔진': '듀얼DIGIC6',
#   '저장매체': 'CF',
#   '인터페이스': 'USB3.0',
#   '최대촬영': '약670장',
#   '재질': '마그네슘(전,후면)',
#   '부피': '1302cc',
#   '무게': '910g'},
#  {'제품명': '캐논 EOS 1000D',
#   '가격': 128080,
#   '용도별': '입문자용',
#   '유효화소수': '1010만화소',
#   'ISO': '100~1600',
#   '최소셔터스피드': '1/4000초',
#   '종류': 'DSLR',
#   '화면화소': '23만화소',
#   '부가기능': '벌브지원',
#   '뷰파인더': '뷰파인더',
#   '화면': '2.5인치(6.3cm)',
#   '초점영역': '7개',
#   '연사': '초당3장',
#   '최대연속촬영속도': '3.0매',
#   '촬영기능': '역광보정',
#   '내장플래시': '팝업플래시',
#   '기능': '동영상촬영불가',
#   '스피드': '셔터(1/4000초)',
#   '손떨림보정': '렌즈(별매)',
#   '라이브뷰': '라이브뷰',
#   '화질엔진': 'DIGIC3',
#   '먼지제거': '가능',
#   '저장매체': 'SD',
#   '재질': '플라스틱',
#   '부피': '764cc',
#   '무게': '500g'},
#  {'제품명': '소니 미러리스 알파 A5100 16+50mm 렌즈kit', '가격': 469060},
#  {'제품명': '소니 알파 NEX-6',
#   '가격': 213800,
#   '용도별': '중급자용',
#   '유효화소': '1610만화소',
#   'ISO': '100~25600',
#   '최소셔터스피드': '1/4000초',
#   '뷰파인더 방식': '전자식',
#   '동영상 해상도': 'Full-HD',
#   '최대연속촬영속도': '10매',
#   '동영상프레임': '60프레임',
#   '저장매체': '메모리스틱ProDuo',
#   '프레임': '60프레임',
#   '디지털줌': '4배',
#   '스피드': '셔터(1/4000초)',
#   '연사': '초당10장',
#   '재질': '플라스틱',
#   '초점방식': '하이브리드AF',
#   '손떨림보정': '렌즈(별매)',
#   '플래시': '팝업플래시',
#   '화면크기': '3인치(7.6cm)',
#   '화면화소': '92만화소',
#   '디스플레이 형태': '틸트',
#   '스마트': '무선전송(WiFi)',
#   '촬영기능': '3D파노라마',
#   '화질엔진': 'Bionz',
#   '최대촬영': '약360장',
#   '두께': '4.3cm',
#   '무게': '345g',
#   '인터페이스': 'HDMI',
#   '부가기능': '먼지제거',
#   '품목': '미러리스',
#   '뷰파인더 화소': '236만화소',
#   '뷰파인더 형태': '내장뷰파인더',
#   '뷰파인더 종류': 'OLED'},
#  {'제품명': '소니 알파 A6400 BODY 렌즈미포함', '가격': 957860}]

# %% [markdown]
# ### #05. 수집 결과를 데이터 프레임으로 변환

# %%
df = DataFrame(data_list)
df
# Out:
#                                 제품명       가격   용도별     유효화소        ISO  \
# 0                   파나소닉 루믹스 DC-S1H  6069990  전문가용  2420만화소  100~51200
# 1                         후지필름 XF10   482160   NaN      NaN  ISO 51200
# 2                         후지필름 X-A7   839990  입문자용  2420만화소  200~12800
# 3                       후지필름 X-T200   943040  중급자용  2420만화소  200~12800
# 4                        캐논 EOS M50   622420  중급자용  2410만화소  100~25600
# ..                              ...      ...   ...      ...        ...
# 205               캐논 EOS 7D Mark II   785000   NaN      NaN  100~16000
# 206                    캐논 EOS 1000D   128080  입문자용      NaN   100~1600
# 207  소니 미러리스 알파 A5100 16+50mm 렌즈kit   469060   NaN      NaN        NaN
# 208                     소니 알파 NEX-6   213800  중급자용  1610만화소  100~25600
# 209          소니 알파 A6400 BODY 렌즈미포함   957860   NaN      NaN        NaN
#
#     뷰파인더 방식  동영상 해상도         저장매체    프레임         특징  ...   기타 배터리용량  MOS 촬영시간  \
# 0       전자식       6K           SD  24프레임    스위블(회전)  ...  NaN   NaN  NaN  NaN
# 1       NaN      NaN           SD    NaN        NaN  ...  NaN   NaN  NaN  NaN
# 2       NaN  UHD(4K)           SD  30프레임    스위블(회전)  ...  NaN   NaN  NaN  NaN
# 3       전자식  UHD(4K)           SD  30프레임  틸트+플립(셀카)  ...  NaN   NaN  NaN  NaN
# 4       전자식  UHD(4K)           SD  24프레임    스위블(회전)  ...  NaN   NaN  NaN  NaN
# ..      ...      ...          ...    ...        ...  ...  ...   ...  ...  ...
# 205     NaN  Full-HD           CF  60프레임        NaN  ...  NaN   NaN  NaN  NaN
# 206     NaN      NaN           SD    NaN        NaN  ...  NaN   NaN  NaN  NaN
# 207     NaN      NaN          NaN    NaN        NaN  ...  NaN   NaN  NaN  NaN
# 208     전자식  Full-HD  메모리스틱ProDuo  60프레임        NaN  ...  NaN   NaN  NaN  NaN
# 209     NaN      NaN          NaN    NaN        NaN  ...  NaN   NaN  NaN  NaN
#
#      CCD  줌기능 셔터기능  가이드 전자식뷰파인더종류 바디재질
# 0    NaN  NaN  NaN  NaN       NaN  NaN
# 1    NaN  NaN  NaN  NaN       NaN  NaN
# 2    NaN  NaN  NaN  NaN       NaN  NaN
# 3    NaN  NaN  NaN  NaN       NaN  NaN
# 4    NaN  NaN  NaN  NaN       NaN  NaN
# ..   ...  ...  ...  ...       ...  ...
# 205  NaN  NaN  NaN  NaN       NaN  NaN
# 206  NaN  NaN  NaN  NaN       NaN  NaN
# 207  NaN  NaN  NaN  NaN       NaN  NaN
# 208  NaN  NaN  NaN  NaN       NaN  NaN
# 209  NaN  NaN  NaN  NaN       NaN  NaN
#
# [210 rows x 102 columns]

# %% [markdown]
# ### #06. 엑셀로 저장하기

# %%
df.to_excel(keyword + ".xlsx")
